# %% [markdown]
# # **Create Single Monkey Surfaces**

# %% [markdown]
# This notebook will guide you through the procedure to create single monkey surface representations in four steps (some are optional):
#
# 1. **(OPTIONAL)** Average multiple T1 scans from the same animal. (takes seconds)
# 2. Segment the (averaged) T1 of an individual animal using the NMT template as a prior. (takes many hours)
# 3. Create surfaces and flatmaps using Freesurfer. (takes up to to several hours depending on segmentation quality at the start)
# 4. **(OPTIONAL)** Create additional surfaces with Connectome Workbench. (takes minutes)

# %% [markdown]
# ## Initiate
# Setting a few environment variables here so we can actually run code from this notebook

# %%
SUBJ=NMT  # Name of the animal you are going to process
NMT_path=/NHP_MRI/Template/NMT # path to the template folder
startpath=pwd # current directory
# Out:
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.white
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.white
# Application asked to unregister timer 0x43000003 which is not registered in this thread. Fix application.
# [1]+  Done                    freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated

# %% [markdown]
# ----
# ----
# ## **Step 1 (OPTIONAL): Average multiple T1 scans**
#
# ----
# ----
#
# ### Requirements:
# - Freesurfer installation (https://surfer.nmr.mgh.harvard.edu/)
# - NIH Macaque Template (https://github.com/jms290/NMT)
# - One or more high resolution anatomical scans
#
# - The `average_multiple_t1.sh ` script
#
# ### Procedure
# - Create a folder for your subject in the NIH Macaque Template folder as
#
# `<>/NHP_MRI/Template/NMT/single_subject_scans/<SUBJECT>`
#
# - Inside this folder, create a subfolder with all individual T1 scan for this subject, e.g.
#
# `<>/NHP_MRI/Template/NMT/single_subject_scans/<SUBJECT>/<T1_FLD>/*.nii.gz`
#
# - Copy the script `average_multiple_t1.sh` to the `<SUBJECT>` folder as well.
#
# - Run this script with the name of the `<T1_FLD>` as input:
#
# `$ ./average_multiple_t1.sh <T1_FLD>`
#
#
# - The script will:
#
#     - Correct for having the monkey in the sphinx position
#     - Resample each T1 to 0.5 mm isotropic voxels
#     - Reorient the colume for correct display in FSL (e.g., with FSLEyes)
#     - Normalize the contrast gradient
#     - Average the multiple T1's together using motion correction to account for small differences
#
#
# - When the script is done, there should be a `<SUBJECT>.nii.gz` file in the root `<SUBJECT>` folder.

# %%
# Get path and make folders
NMT_ss_path=${NMT_path}/single_subject_scans/${SUBJ}
mkdir -p ${NMT_ss_path}
mkdir -p ${NMT_path}/single_subject_scans/${SUBJ}/T1s
echo Copy the T1 files to ${NMT_path}/single_subject_scans/${SUBJ}/T1s

# %%
# Copy averaging script
cp ${NMT_path}/single_subject_scans/average_multiple_t1.sh \
    ${NMT_path}/single_subject_scans/${SUBJ}/
cd ${NMT_path}/single_subject_scans/${SUBJ}/
# Run script
./average_multiple_t1.sh T1s

# %% [markdown]
# ----
# ----
# ## **Step 2: Segment the single subject anatomy using the NMT template as a prior**
#
# ----
# ----
#
# ### Requirements
#   - NIH Macaque Template (https://github.com/jms290/NMT)
#   - ANTS (http://stnava.github.io/ANTs/)
#   - AFNI (https://afni.nimh.nih.gov/)
#
# ### Procedure
# This will segment and process the single-subject anatomical and warp the D99 atlas (https://afni.nimh.nih.gov/Macaque) to your individual anatomy.
#
# - Navigate to `<>/NHP_MRI/Template/NMT/single_subject_scans` in your terminal
#
# - There should be a folder `<SUBJECT>` containing a T1 named `<SUBJECT>.nii.gz` (Step 1 produces this)
#
# - Run the `align_and_process_singlesubject.sh` script with input `<SUBJECT>`:
#
# - The following 2 steps can be executed together by running: `$ ./create_ss_atlas.sh <SUBJECT>`
#
#     - Extracting single ROI masks from the warped atlas: `./extract_ROI.sh <SUBJECT>`
#
#     - Creating a label-file that makes the warped atlas usable in FSLEyes: `./create_xml.sh <SUBJECT>`

# %%
# Go to the single subject folder in NMT
cd ${NMT_path}/single_subject_scans
# Run script to align and segment. This will take a long time (~8-10 hours)
./align_and_process_singlesubject.sh ${SUBJ}

# %% [markdown]
# You may already want to perform some manual adjustments here (e.g., white matter tends to be overestimated in the occipital lobe). There are many ways to do this but one easy way is with `ITK-SNAP` (http://www.itksnap.org/pmwiki/pmwiki.php). Whenever you decide to make adjustments, dot it on a copy of the original results and leave the original results intact.
#
# In `ITK-SNAP` you can open the brain volume as the `Main Image` and load the segmentation volume as segmentation.
#
# ![ITKSNAP](pics/itksnap_loaded.png)
#
# Voxels in the segmentation are labeled red (value 1) for CSF, green (value 2) for grey matter, and blue (value 3) for white matter. You can use the paintbrush tool to change labels and save the adjusted segmentation file.
#
# To generate separate CSF/GM/WM masks you can run
# ```
# fslmaths <SUBJECT>_segmentation.nii.gz -thr 0.9 -uthr 1.1 -bin <SUBJECT>_CSF.nii.gz
# fslmaths <SUBJECT>_segmentation.nii.gz -thr 1.9 -uthr 2.1 -bin <SUBJECT>_GM.nii.gz
# fslmaths <SUBJECT>_segmentation.nii.gz -thr 2.9 -uthr 3.1 -bin <SUBJECT>_WM.nii.gz
# fslmaths <SUBJECT>_segmentation.nii.gz -thr 0.5 -uthr 3.1 -bin <SUBJECT>_brainmask.nii.gz
# ```
#
# In addtion you can create atlas files so you use the warped D99 atlas for this individual in `FSLEyes`

# %%
# Create usability files for the warped D99 atlas in individual space
./create_ss_atlas ${SUBJ}

# %% [markdown]
# ----
# ----
# ## **Step 3: Create surfaces and flatmaps using Freesurfer**
#
# ----
# ----

# %% [markdown]
# ### Requirements
# - Freesurfer installation (https://surfer.nmr.mgh.harvard.edu/)
# - Segmented individual subject T1
#
# ### Procedure
# #### Create folders & copy files

# %%
# Path to the single_subjects folder in NMT where this subject's segmentation is located
#NMT_src=${NMT_path}/single_subject_scans/${SUBJ}/NMT_${SUBJ}_process 
# adjust this path if you have manually adjusted and saved to a different folder, e.g.
NMT_src=${NMT_path}/single_subject_scans/${SUBJ}

# create a folder for the freesurfer surfaces we will eventually end up with
fsSurf=${NMT_path}/single_subject_scans/${SUBJ}/fsSurf
mkdir -p ${fsSurf}

# make subfolders for structure
fsSurf_src=${fsSurf}/src
fsSurf_mgz=${fsSurf}/mgz
fsSurf_temp=${fsSurf}/temp
mkdir -p ${fsSurf_src}
mkdir -p ${fsSurf_mgz}
mkdir -p ${fsSurf_temp}

# initialize an array to be able to loop over hemispheres
HEMI=(lh rh)

# %%
# copy the source files from the NMT segmentation to the freesurfer folders you just created
cp ${NMT_src}/${SUBJ}_N4.nii.gz ${fsSurf_src}/T1.nii.gz
cp ${NMT_src}/${SUBJ}_brain.nii.gz ${fsSurf_src}/brain.nii.gz
cp ${NMT_src}/${SUBJ}_brain.nii.gz ${fsSurf_src}/brainmask.nii.gz # freesurfer brainmask aren't actually masks
cp ${NMT_src}/${SUBJ}_WM.nii.gz ${fsSurf_src}/wm.nii.gz

# copy source files again but keep these in original state 
# (for others the header will be changed to 'fake' 1 mm voxels, which is necessary for freesurfer)
mkdir -p ${fsSurf_src}/org
cp ${fsSurf_src}/*.nii.gz ${fsSurf_src}/org/

# %% [markdown]
# #### Change headers to mimic 1mm isotropic voxels & make mgz files

# %%
# change headers
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/T1.nii.gz &
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brain.nii.gz &
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brainmask.nii.gz &
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/wm.nii.gz &
wait
# convert to mgz files for freesurfer
mri_convert -c ${fsSurf_src}/T1.nii.gz ${fsSurf_mgz}/T1.mgz &
mri_convert -c ${fsSurf_src}/brain.nii.gz ${fsSurf_mgz}/brain.mgz &
mri_convert -c ${fsSurf_src}/brain.nii.gz ${fsSurf_mgz}/brainmask.mgz &
mri_convert -c ${fsSurf_src}/brainmask.nii.gz ${fsSurf_mgz}/brainmask_binary.mgz &
mri_convert -c ${fsSurf_src}/wm.nii.gz ${fsSurf_mgz}/wm.mgz &
wait
# create brain.finalsurfs.mgz
mri_mask -T 5 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/brainmask.mgz ${fsSurf_mgz}/brain.finalsurfs.mgz &
# Out:
# ERROR: Read 176, expected 253
# niiRead(): error reading from /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/T1.nii.gz
# ++ 3drefit processed 1 datasets
# ++ 3drefit processed 1 datasets
# ++ 3drefit processed 1 datasets
# DoAbs = 0
# Found 5214430 voxels in mask (pct= 12.48)
# Writing masked volume to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/brain.finalsurfs.mgz...done.
# ++ 3drefit processed 1 datasets
# [1]   Done                    3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/T1.nii.gz
# [2]   Done                    3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brain.nii.gz
# [3]   Done                    3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brainmask.nii.gz
# [4]   Done                    3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/wm.nii.gz
# [5]-  Exit 1                  mri_convert -c ${fsSurf_src}/T1.nii.gz ${fsSurf_mgz}/T1.mgz
# [9]+  Done                    mri_mask -T 5 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/brainmask.mgz ${fsSurf_mgz}/brain.finalsurfs.mgz
# [1] 26448
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/T1.nii.gz
#  + applying -keepcen
#  + deoblique
#  + loading and re-writing dataset /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/T1.nii.gz (/NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/T1.nii.gz in NIFTI storage)
# [2] 26449
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brain.nii.gz
#  + applying -keepcen
#  + deoblique
#  + loading and re-writing dataset /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brain.nii.gz (/NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brain.nii.gz in NIFTI storage)
# [3] 26450
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brainmask.nii.gz
#  + applying -keepcen
#  + deoblique
#  + loading and re-writing dataset /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brainmask.nii.gz (/NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brainmask.nii.gz in NIFTI storage)
# [4] 26451
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/wm.nii.gz
#  + applying -keepcen
#  + deoblique
#  + loading and re-writing dataset /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/wm.nii.gz (/NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/wm.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# ++ 3drefit processed 1 datasets
# ++ 3drefit processed 1 datasets
# ++ 3drefit processed 1 datasets
# [1]   Done                    3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/T1.nii.gz
# [2]   Done                    3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brain.nii.gz
# [3]-  Done                    3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brainmask.nii.gz
# [4]+  Done                    3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/wm.nii.gz
# [1] 26454
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/T1.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/T1.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/T1.nii.gz...
# [2] 26459
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brain.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/brain.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brain.nii.gz...
# [3] 26463
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brain.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/brainmask.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brain.nii.gz...
# [4] 26467
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brainmask.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/brainmask_binary.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/brainmask.nii.gz...
# [5] 26471
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/wm.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/wm.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/src/wm.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# WARNING ==================++++++++++++++++++++++++=======================================
# The physical sizes are (253.00 mm, 347.00 mm, 245.00 mm), which cannot fit in 256^3 mm^3 volume.
# The resulting volume will have 347 slices.
# If you find problems, please let us know (freesurfer@nmr.mgh.harvard.edu).
# ==================================================++++++++++++++++++++++++===============
#
# changing data type from float to uchar (noscale = 0)...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# WARNING ==================++++++++++++++++++++++++=======================================
# The physical sizes are (253.00 mm, 347.00 mm, 245.00 mm), which cannot fit in 256^3 mm^3 volume.
# The resulting volume will have 347 slices.
# If you find problems, please let us know (freesurfer@nmr.mgh.harvard.edu).
# ==================================================++++++++++++++++++++++++===============
#
# changing data type from float to uchar (noscale = 0)...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# WARNING ==================++++++++++++++++++++++++=======================================
# The physical sizes are (253.00 mm, 347.00 mm, 245.00 mm), which cannot fit in 256^3 mm^3 volume.
# The resulting volume will have 347 slices.
# If you find problems, please let us know (freesurfer@nmr.mgh.harvard.edu).
# ==================================================++++++++++++++++++++++++===============
#
# changing data type from float to uchar (noscale = 0)...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# WARNING ==================++++++++++++++++++++++++=======================================
# The physical sizes are (253.00 mm, 347.00 mm, 245.00 mm), which cannot fit in 256^3 mm^3 volume.
# The resulting volume will have 347 slices.
# If you find problems, please let us know (freesurfer@nmr.mgh.harvard.edu).
# ==================================================++++++++++++++++++++++++===============
#
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# MRIchangeType: Building histogram
# MRIchangeType: Building histogram
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# WARNING ==================++++++++++++++++++++++++=======================================
# The physical sizes are (253.00 mm, 347.00 mm, 245.00 mm), which cannot fit in 256^3 mm^3 volume.
# The resulting volume will have 347 slices.
# If you find problems, please let us know (freesurfer@nmr.mgh.harvard.edu).
# ==================================================++++++++++++++++++++++++===============
#
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# Reslicing using trilinear interpolation
# Reslicing using trilinear interpolation
# Reslicing using trilinear interpolation
# Reslicing using trilinear interpolation
# writing to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/brainmask_binary.mgz...
# writing to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/wm.mgz...
# writing to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/brain.mgz...
# writing to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/brainmask.mgz...
# writing to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/T1.mgz...
# [1]   Done                    mri_convert -c ${fsSurf_src}/T1.nii.gz ${fsSurf_mgz}/T1.mgz
# [2]   Done                    mri_convert -c ${fsSurf_src}/brain.nii.gz ${fsSurf_mgz}/brain.mgz
# [3]   Done                    mri_convert -c ${fsSurf_src}/brain.nii.gz ${fsSurf_mgz}/brainmask.mgz
# [4]-  Done                    mri_convert -c ${fsSurf_src}/brainmask.nii.gz ${fsSurf_mgz}/brainmask_binary.mgz
# [5]+  Done                    mri_convert -c ${fsSurf_src}/wm.nii.gz ${fsSurf_mgz}/wm.mgz
# [1] 26482
# : 1

# %% [markdown]
# #### Get corpus callosum and pons voxel coordinates
# These will later define the cutting planes for the surface generation so make sure that 1) the corpus callosum is in the middle, and 2) the pons coordinates are low enough to not cut through cortex.
#
# Corpus callosum:
# ![CC](pics/CC_coordinates.png)
#
# Pons:
# ![PONS](pics/PONS_coordinates.png)

# %%
# Inspect volume to get voxel coordinates
freeview -v ${fsSurf_mgz}/brain.mgz &
# Out:
# DoAbs = 0
# Found 5214430 voxels in mask (pct= 12.48)
# Writing masked volume to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/brain.finalsurfs.mgz...done.
# [1]+  Done                    mri_mask -T 5 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/brainmask.mgz ${fsSurf_mgz}/brain.finalsurfs.mgz
# [1] 26548

# %%
#NMT
CC=(174 152 173) # corpus callosum
PONS=(174 226 139) # pons
# Out:
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.white
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.white
# /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/wm.mgz saved successfully.
# [1]+  Done                    freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated

# %% [markdown]
# #### Fill the white matter volume & copy for backup before fixing

# %%
# Fill WM
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/filled.mgz
# copy the original white matter before applying fixes    
cp ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/wm_nofix.mgz
# Out:
# using voxel position (174, 152, 173) as corpus callosum seed point
# using voxel position (174, 215, 139) as pons seed point
# reading input volume...done.
# searching for cutting planes...INFO: volume does not have linear_transform set nor lta is given by option.-xform.
# INFO: use identity matrix as the talairach transform.
# INFO: use src volume parameters for the talairach volume.
# voxel to talairach voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Calculated talairach cc position (-0.25, -7.25, 25.50)
# Using the seed to calculate the cutting plane
# Looking for area (min, max) = (350, 1400)
# area[0] = 1677 (min = 350, max = 1400), aspect = 0.42 (min = 0.10, max = 0.75)
# need search nearby
# using seed (174, 152, 173), TAL = (-0.2, -7.2, 25.5)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# talairach cc position changed to (-0.25, -7.25, 25.50)
# Using voxel pons seed point, calculated talairach pons position (-0.25, -41.25, -37.50)
# Looking for area (min, max) = (350, 790)
# area[0] = 7050 (min = 350, max = 790), aspect = 0.87 (min = 0.60, max = 1.20)
# need search nearby
# using seed (174, 215, 139), TAL = (-0.2, -41.2, -37.5)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# done.
# seed_search_size = 9, min_neighbors = 5
# search rh wm seed point around talairach space:(17.75, -7.25, 25.50) SRC: (156.00, 152.00, 173.00)
# search lh wm seed point around talairach space (-18.25, -7.25, 25.50), SRC: (192.00, 152.00, 173.00)
# filling left hemisphere...
# filling volume: pass 3 of 3...total of 1614212 voxels filled...done.
# filling right hemisphere...
# filling volume: pass 3 of 3...total of 1614212 voxels filled...done.
# filling degenerate left hemisphere surface locations...
# 2131 voxels filled
# 16 voxels filled
# 2 voxels filled
# 1 voxels filled
# 1 voxels filled
# 0 voxels filled
# filling degenerate right hemisphere surface locations...
# 2131 voxels filled
# 16 voxels filled
# 2 voxels filled
# 1 voxels filled
# 1 voxels filled
# 0 voxels filled
# refilling left hemisphere...
# filling volume: pass 3 of 3...total of 1616363 voxels filled...done.
# refilling right hemisphere...
# filling volume: pass 3 of 3...total of 1616363 voxels filled...done.
# combining hemispheres...
# using variable coefficient diffusion to correct hemispheric overlap...
# 26:  1616016 ambiguous voxels remaining
# 9:  37033 ambiguous voxels remaining
# 8:  15776 ambiguous voxels remaining
# 7:  5419 ambiguous voxels remaining
# 6:  2009 ambiguous voxels remaining
# 5:  824 ambiguous voxels remaining
# 4:  403 ambiguous voxels remaining
# 3:  236 ambiguous voxels remaining
# 2:  96 ambiguous voxels remaining
# 1:  0 ambiguous voxels remaining
# writing output to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/filled.mgz...
# filling took 1.3 minutes

# %% [markdown]
# #### Tesselate volumes & fix topology (First run)

# %%
# Tesselate
mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz &
mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz &
wait
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig.nofix &
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig.nofix &
wait

# for both hemispheres
for xh in ${HEMI[@]}; do
    # create a version we can edit
    cp ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.orig

    # post-process tesselation
    mris_extract_main_component ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.orig.nofix
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.smoothwm.nofix
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm.nofix ${fsSurf_temp}/${xh}.inflated.nofix
    mris_sphere -q ${fsSurf_temp}/${xh}.inflated.nofix ${fsSurf_temp}/${xh}.qsphere.nofix
    cp ${fsSurf_temp}/${xh}.inflated.nofix ${fsSurf_temp}/${xh}.inflated

    # fix topology
    mris_euler_number ${fsSurf_temp}/${xh}.orig
    mris_remove_intersection ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
done
# Out:
# [2] 26871
# [3] 26872
# Ambiguous edge configurations...
#
# Iteration Number : 1Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy+):   1 found -   1 modified     |    TOTAL:   1
# pass   1 (xy-):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (xy+):   0 found -   1 modified     |    TOTAL:   1
# pass   2 (xy-):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (yz+):   2 found -   2 modified     |    TOTAL:   3
# pass   1 (yz+):   1 found -   1 modified     |    TOTAL:   2
# pass   2 (yz+):   0 found -   2 modified     |    TOTAL:   3
# pass   2 (yz+):   0 found -   1 modified     |    TOTAL:   2
# pass   1 (yz-):   2 found -   2 modified     |    TOTAL:   5
# pass   1 (yz-):   5 found -   5 modified     |    TOTAL:   7
# pass   2 (yz-):   0 found -   2 modified     |    TOTAL:   5
# pass   2 (yz-):   0 found -   5 modified     |    TOTAL:   7
# pass   1 (xz+):   4 found -   4 modified     |    TOTAL:   9
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   7
# pass   2 (xz+):   0 found -   4 modified     |    TOTAL:   9
# pass   1 (xz-):   4 found -   4 modified     |    TOTAL:  11
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   9
# Iteration Number : 1
# pass   2 (xz-):   0 found -   4 modified     |    TOTAL:  11
# Iteration Number : 1
# pass   1 (+++):   9 found -   9 modified     |    TOTAL:   9
# pass   1 (+++):   4 found -   4 modified     |    TOTAL:   4
# pass   2 (+++):   0 found -   9 modified     |    TOTAL:   9
# pass   2 (+++):   0 found -   4 modified     |    TOTAL:   4
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   9
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   4
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   9
# pass   1 (+++):   2 found -   2 modified     |    TOTAL:   6
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   9
# Iteration Number : 1
# pass   2 (+++):   0 found -   2 modified     |    TOTAL:   6
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   6
# Iteration Number : 1
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (++):   3 found -   3 modified     |    TOTAL:   3
# pass   1 (--):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (++):   0 found -   3 modified     |    TOTAL:   3
# pass   2 (--):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   3
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 2
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   3
# pass   1 (xy+):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (xy+):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   3
# Iteration Number : 2
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xy+):   1 found -   1 modified     |    TOTAL:   1
# pass   1 (yz+):   2 found -   2 modified     |    TOTAL:   3
# pass   2 (yz+):   0 found -   2 modified     |    TOTAL:   3
# pass   2 (xy+):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   3
# pass   1 (xy-):   1 found -   1 modified     |    TOTAL:   2
# pass   1 (xz+):   1 found -   1 modified     |    TOTAL:   4
# pass   2 (xy-):   0 found -   1 modified     |    TOTAL:   2
# pass   2 (xz+):   0 found -   1 modified     |    TOTAL:   4
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   2
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   4
# Iteration Number : 2
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   2
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   1 found -   1 modified     |    TOTAL:   1
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   2 (-+):   0 found -   1 modified     |    TOTAL:   1
# Iteration Number : 3
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 23 (out of 806037: 0.002853)
#
#
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 23 (out of 810373: 0.002838)
#
# mri_pretess done
#
# mri_pretess done
#
# [1]   Done                    freeview -v ${fsSurf_mgz}/brain.mgz
# [2]-  Done                    mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz
# [3]+  Done                    mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz
# [1] 27120
# [2] 27124
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 30: 461 vertices, 513 faces
# slice 40: 4929 vertices, 5109 faces
# slice 30: 426 vertices, 479 faces
# slice 50: 11450 vertices, 11681 faces
# slice 40: 4820 vertices, 4977 faces
# slice 60: 22482 vertices, 22940 faces
# slice 50: 11410 vertices, 11649 faces
# slice 70: 39410 vertices, 39994 faces
# slice 60: 22644 vertices, 23090 faces
# slice 80: 56841 vertices, 57393 faces
# slice 70: 38517 vertices, 39057 faces
# slice 90: 70978 vertices, 71431 faces
# slice 80: 54036 vertices, 54563 faces
# slice 100: 84998 vertices, 85503 faces
# slice 90: 68544 vertices, 69032 faces
# slice 110: 101144 vertices, 101699 faces
# slice 100: 83883 vertices, 84437 faces
# slice 120: 115872 vertices, 116356 faces
# slice 110: 100744 vertices, 101338 faces
# slice 120: 116866 vertices, 117396 faces
# slice 130: 133565 vertices, 134162 faces
# slice 140: 151259 vertices, 151866 faces
# slice 130: 134851 vertices, 135452 faces
# slice 140: 152449 vertices, 153052 faces
# slice 150: 168911 vertices, 169529 faces
#
# counting number of connected components...slice 150: 169795 vertices, 170413 faces
# slice 160: 186990 vertices, 187619 faces
# slice 160: 187851 vertices, 188494 faces
# slice 170: 204443 vertices, 205077 faces
# slice 170: 205231 vertices, 205864 faces
# slice 180: 221164 vertices, 221830 faces
# slice 180: 221643 vertices, 222308 faces
# slice 190: 237286 vertices, 237894 faces
#
#    229414 voxel in cpt #1: X=-532 [v=229414,e=689838,f=459892] located at (-47.866936, -18.438103, 8.479988)
# For the whole surface: X=-532 [v=229414,e=689838,f=459892]
# One single component has been found
# nothing to doslice 190: 237626 vertices, 238250 faces
# slice 200: 253240 vertices, 253843 faces
# slice 200: 253541 vertices, 254160 faces
# slice 210: 268333 vertices, 268856 faces
# slice 210: 268704 vertices, 269245 faces
# slice 220: 279549 vertices, 279935 faces
# slice 230: 288827 vertices, 289217 faces
# slice 220: 280063 vertices, 280453 faces
# slice 240: 298538 vertices, 298883 faces
# slice 230: 289511 vertices, 289918 faces
# slice 250: 306334 vertices, 306630 faces
# slice 240: 299419 vertices, 299775 faces
# slice 260: 311924 vertices, 312159 faces
# slice 250: 307137 vertices, 307442 faces
# slice 270: 316308 vertices, 316522 faces
# slice 260: 312699 vertices, 312948 faces
#
# done
#
# slice 280: 320079 vertices, 320266 faces
# slice 270: 317089 vertices, 317315 faces
# slice 290: 323138 vertices, 323276 faces
# slice 280: 320903 vertices, 321108 faces
# slice 300: 325028 vertices, 325124 faces
# slice 290: 324174 vertices, 324330 faces
# slice 310: 325604 vertices, 325650 faces
# slice 300: 326089 vertices, 326197 faces
# slice 320: 325604 vertices, 325650 faces
# slice 310: 326698 vertices, 326756 faces
# slice 330: 325604 vertices, 325650 faces
# slice 320: 326698 vertices, 326756 faces
# slice 340: 325604 vertices, 325650 faces
# slice 330: 326698 vertices, 326756 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.orig.nofix
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   173.50000;
#  0.00000   0.00000   1.00000  -173.50000;
#  0.00000  -1.00000   0.00000   173.50000;
#  0.00000   0.00000   0.00000   1.00000;
# slice 340: 326698 vertices, 326756 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.orig.nofix
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   173.50000;
#  0.00000   0.00000   1.00000  -173.50000;
#  0.00000  -1.00000   0.00000   173.50000;
#  0.00000   0.00000   0.00000   1.00000;
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# [1]-  Done                    mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig.nofix
# [2]+  Done                    mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig.nofix
# Reading /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.smoothwm.nofix
# avg radius = 64.0 mm, total surface area = 132646 mm^2
# step 060: RMS=0.096 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.inflated.nofix
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.sulc
# mris_inflate utimesec    42.504253
# mris_inflate stimesec    0.140079
# mris_inflate ru_maxrss   297404
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   72657
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  112
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    4853
# mris_inflate ru_nivcsw   833
# inflation took 0.7 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.212...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=181.763, avgs=0
# 005/300: dt: 0.9000, rms radial error=181.495, avgs=0
# 010/300: dt: 0.9000, rms radial error=180.926, avgs=0
# 015/300: dt: 0.9000, rms radial error=180.186, avgs=0
# 020/300: dt: 0.9000, rms radial error=179.345, avgs=0
# 025/300: dt: 0.9000, rms radial error=178.446, avgs=0
# 030/300: dt: 0.9000, rms radial error=177.514, avgs=0
# 035/300: dt: 0.9000, rms radial error=176.566, avgs=0
# 040/300: dt: 0.9000, rms radial error=175.610, avgs=0
# 045/300: dt: 0.9000, rms radial error=174.653, avgs=0
# 050/300: dt: 0.9000, rms radial error=173.696, avgs=0
# 055/300: dt: 0.9000, rms radial error=172.742, avgs=0
# 060/300: dt: 0.9000, rms radial error=171.791, avgs=0
# 065/300: dt: 0.9000, rms radial error=170.842, avgs=0
# 070/300: dt: 0.9000, rms radial error=169.896, avgs=0
# 075/300: dt: 0.9000, rms radial error=168.956, avgs=0
# 080/300: dt: 0.9000, rms radial error=168.020, avgs=0
# 085/300: dt: 0.9000, rms radial error=167.089, avgs=0
# 090/300: dt: 0.9000, rms radial error=166.165, avgs=0
# 095/300: dt: 0.9000, rms radial error=165.246, avgs=0
# 100/300: dt: 0.9000, rms radial error=164.333, avgs=0
# 105/300: dt: 0.9000, rms radial error=163.424, avgs=0
# 110/300: dt: 0.9000, rms radial error=162.520, avgs=0
# 115/300: dt: 0.9000, rms radial error=161.620, avgs=0
# 120/300: dt: 0.9000, rms radial error=160.726, avgs=0
# 125/300: dt: 0.9000, rms radial error=159.837, avgs=0
# 130/300: dt: 0.9000, rms radial error=158.952, avgs=0
# 135/300: dt: 0.9000, rms radial error=158.072, avgs=0
# 140/300: dt: 0.9000, rms radial error=157.197, avgs=0
# 145/300: dt: 0.9000, rms radial error=156.327, avgs=0
# 150/300: dt: 0.9000, rms radial error=155.461, avgs=0
# 155/300: dt: 0.9000, rms radial error=154.600, avgs=0
# 160/300: dt: 0.9000, rms radial error=153.744, avgs=0
# 165/300: dt: 0.9000, rms radial error=152.892, avgs=0
# 170/300: dt: 0.9000, rms radial error=152.045, avgs=0
# 175/300: dt: 0.9000, rms radial error=151.203, avgs=0
# 180/300: dt: 0.9000, rms radial error=150.374, avgs=0
# 185/300: dt: 0.9000, rms radial error=149.549, avgs=0
# 190/300: dt: 0.9000, rms radial error=148.729, avgs=0
# 195/300: dt: 0.9000, rms radial error=147.914, avgs=0
# 200/300: dt: 0.9000, rms radial error=147.102, avgs=0
# 205/300: dt: 0.9000, rms radial error=146.296, avgs=0
# 210/300: dt: 0.9000, rms radial error=145.493, avgs=0
# 215/300: dt: 0.9000, rms radial error=144.695, avgs=0
# 220/300: dt: 0.9000, rms radial error=143.902, avgs=0
# 225/300: dt: 0.9000, rms radial error=143.112, avgs=0
# 230/300: dt: 0.9000, rms radial error=142.327, avgs=0
# 235/300: dt: 0.9000, rms radial error=141.547, avgs=0
# 240/300: dt: 0.9000, rms radial error=140.770, avgs=0
# 245/300: dt: 0.9000, rms radial error=139.998, avgs=0
# 250/300: dt: 0.9000, rms radial error=139.231, avgs=0
# 255/300: dt: 0.9000, rms radial error=138.467, avgs=0
# 260/300: dt: 0.9000, rms radial error=137.708, avgs=0
# 265/300: dt: 0.9000, rms radial error=136.952, avgs=0
# 270/300: dt: 0.9000, rms radial error=136.200, avgs=0
# 275/300: dt: 0.9000, rms radial error=135.453, avgs=0
# 280/300: dt: 0.9000, rms radial error=134.710, avgs=0
# 285/300: dt: 0.9000, rms radial error=133.971, avgs=0
# 290/300: dt: 0.9000, rms radial error=133.236, avgs=0
# 295/300: dt: 0.9000, rms radial error=132.505, avgs=0
# 300/300: dt: 0.9000, rms radial error=131.778, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 0.89 +- 0.81 (0.00-->14.33) (max @ vno 108773 --> 108792)
# face area 0.01 +- 0.05 (-0.67-->2.02)
# epoch 1 (K=10.0), pass 1, starting sse = 29997.61
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00022
# epoch 2 (K=40.0), pass 1, starting sse = 7107.73
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.01/10 = 0.00149
# epoch 3 (K=160.0), pass 1, starting sse = 2047.42
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.06/10 = 0.00556
# epoch 4 (K=640.0), pass 1, starting sse = 1044.50
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.11/11 = 0.00983
# final distance error %54.91
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.qsphere.nofix
# mris_sphere utimesec    266.478532
# mris_sphere stimesec    0.280040
# mris_sphere ru_maxrss   297400
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   72657
# mris_sphere ru_majflt   0
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    4147
# mris_sphere ru_nivcsw   1732
# spherical transformation took 0.07 hours
# FSRUNTIME@ mris_sphere  0.0741 hours 1 threads
# euler # = v-e+f = 2g-2: 229414 - 689838 + 459892 = -532 --> 267 holes
#       F =2V-4:          459892 != 458828-4 (-1068)
#       2E=3F:            1379676 = 1379676 (0)
#
# total defect index = 534
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.smoothwm
# avg radius = 64.0 mm, total surface area = 132646 mm^2
# step 060: RMS=0.096 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.sulc
# mris_inflate utimesec    42.356998
# mris_inflate stimesec    0.124049
# mris_inflate ru_maxrss   297456
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   72655
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    4853
# mris_inflate ru_nivcsw   185
# inflation took 0.7 minutes
#
# counting number of connected components...
#    326698 voxel in cpt #1: X=-58 [v=326698,e=980268,f=653512] located at (45.161148, -25.934824, 5.836347)
# For the whole surface: X=-58 [v=326698,e=980268,f=653512]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.smoothwm.nofix
# avg radius = 73.1 mm, total surface area = 197184 mm^2
# step 060: RMS=0.045 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.inflated.nofix
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.sulc
# mris_inflate utimesec    60.137017
# mris_inflate stimesec    0.156054
# mris_inflate ru_maxrss   417728
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   102761
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  112
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    6757
# mris_inflate ru_nivcsw   164
# inflation took 1.0 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.203...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=179.465, avgs=0
# 005/300: dt: 0.9000, rms radial error=179.206, avgs=0
# 010/300: dt: 0.9000, rms radial error=178.651, avgs=0
# 015/300: dt: 0.9000, rms radial error=177.923, avgs=0
# 020/300: dt: 0.9000, rms radial error=177.094, avgs=0
# 025/300: dt: 0.9000, rms radial error=176.207, avgs=0
# 030/300: dt: 0.9000, rms radial error=175.288, avgs=0
# 035/300: dt: 0.9000, rms radial error=174.356, avgs=0
# 040/300: dt: 0.9000, rms radial error=173.420, avgs=0
# 045/300: dt: 0.9000, rms radial error=172.481, avgs=0
# 050/300: dt: 0.9000, rms radial error=171.543, avgs=0
# 055/300: dt: 0.9000, rms radial error=170.606, avgs=0
# 060/300: dt: 0.9000, rms radial error=169.672, avgs=0
# 065/300: dt: 0.9000, rms radial error=168.738, avgs=0
# 070/300: dt: 0.9000, rms radial error=167.809, avgs=0
# 075/300: dt: 0.9000, rms radial error=166.883, avgs=0
# 080/300: dt: 0.9000, rms radial error=165.963, avgs=0
# 085/300: dt: 0.9000, rms radial error=165.047, avgs=0
# 090/300: dt: 0.9000, rms radial error=164.136, avgs=0
# 095/300: dt: 0.9000, rms radial error=163.230, avgs=0
# 100/300: dt: 0.9000, rms radial error=162.328, avgs=0
# 105/300: dt: 0.9000, rms radial error=161.431, avgs=0
# 110/300: dt: 0.9000, rms radial error=160.539, avgs=0
# 115/300: dt: 0.9000, rms radial error=159.651, avgs=0
# 120/300: dt: 0.9000, rms radial error=158.768, avgs=0
# 125/300: dt: 0.9000, rms radial error=157.889, avgs=0
# 130/300: dt: 0.9000, rms radial error=157.015, avgs=0
# 135/300: dt: 0.9000, rms radial error=156.146, avgs=0
# 140/300: dt: 0.9000, rms radial error=155.281, avgs=0
# 145/300: dt: 0.9000, rms radial error=154.421, avgs=0
# 150/300: dt: 0.9000, rms radial error=153.565, avgs=0
# 155/300: dt: 0.9000, rms radial error=152.713, avgs=0
# 160/300: dt: 0.9000, rms radial error=151.866, avgs=0
# 165/300: dt: 0.9000, rms radial error=151.024, avgs=0
# 170/300: dt: 0.9000, rms radial error=150.186, avgs=0
# 175/300: dt: 0.9000, rms radial error=149.352, avgs=0
# 180/300: dt: 0.9000, rms radial error=148.522, avgs=0
# 185/300: dt: 0.9000, rms radial error=147.698, avgs=0
# 190/300: dt: 0.9000, rms radial error=146.877, avgs=0
# 195/300: dt: 0.9000, rms radial error=146.061, avgs=0
# 200/300: dt: 0.9000, rms radial error=145.249, avgs=0
# 205/300: dt: 0.9000, rms radial error=144.442, avgs=0
# 210/300: dt: 0.9000, rms radial error=143.638, avgs=0
# 215/300: dt: 0.9000, rms radial error=142.840, avgs=0
# 220/300: dt: 0.9000, rms radial error=142.045, avgs=0
# 225/300: dt: 0.9000, rms radial error=141.255, avgs=0
# 230/300: dt: 0.9000, rms radial error=140.469, avgs=0
# 235/300: dt: 0.9000, rms radial error=139.687, avgs=0
# 240/300: dt: 0.9000, rms radial error=138.910, avgs=0
# 245/300: dt: 0.9000, rms radial error=138.136, avgs=0
# 250/300: dt: 0.9000, rms radial error=137.367, avgs=0
# 255/300: dt: 0.9000, rms radial error=136.602, avgs=0
# 260/300: dt: 0.9000, rms radial error=135.841, avgs=0
# 265/300: dt: 0.9000, rms radial error=135.084, avgs=0
# 270/300: dt: 0.9000, rms radial error=134.332, avgs=0
# 275/300: dt: 0.9000, rms radial error=133.583, avgs=0
# 280/300: dt: 0.9000, rms radial error=132.839, avgs=0
# 285/300: dt: 0.9000, rms radial error=132.099, avgs=0
# 290/300: dt: 0.9000, rms radial error=131.362, avgs=0
# 295/300: dt: 0.9000, rms radial error=130.630, avgs=0
# 300/300: dt: 0.9000, rms radial error=129.902, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 0.72 +- 0.51 (0.00-->5.79) (max @ vno 169588 --> 169597)
# face area 0.01 +- 0.02 (-0.40-->0.44)
# epoch 1 (K=10.0), pass 1, starting sse = 41684.30
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00014
# epoch 2 (K=40.0), pass 1, starting sse = 8551.44
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00021
# epoch 3 (K=160.0), pass 1, starting sse = 1482.01
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.02/10 = 0.00235
# epoch 4 (K=640.0), pass 1, starting sse = 346.17
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.09/11 = 0.00852
# final distance error %41.40
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.qsphere.nofix
# mris_sphere utimesec    383.504680
# mris_sphere stimesec    0.383984
# mris_sphere ru_maxrss   418220
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   102762
# mris_sphere ru_majflt   0
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    5858
# mris_sphere ru_nivcsw   7559
# spherical transformation took 0.11 hours
# FSRUNTIME@ mris_sphere  0.1067 hours 1 threads
# euler # = v-e+f = 2g-2: 326698 - 980268 + 653512 = -58 --> 30 holes
#       F =2V-4:          653512 != 653396-4 (-120)
#       2E=3F:            1960536 = 1960536 (0)
#
# total defect index = 60
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.smoothwm
# avg radius = 73.2 mm, total surface area = 199894 mm^2
# step 060: RMS=0.048 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.sulc
# mris_inflate utimesec    57.615320
# mris_inflate stimesec    0.135979
# mris_inflate ru_maxrss   417780
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   102762
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    4830
# mris_inflate ru_nivcsw   355
# inflation took 1.0 minutes

# %% [markdown]
# #### Iterate manual adjustments and doing tesselation & topology fix again
# Should look something like this. Keep going (adjust `wm.mgz` using the recon-edit function of Freeview) until you are happy with the result.
#
# ![LH_wm_inflated_lateral](pics/LH_wm_inflated_lateral.png) ![LH_wm_inflated_medial](pics/LH_wm_inflated_medial.png)

# %%
# look at the result and apply fixes in WM definition
# you will want to get rid of weird 'stalks' and 'bridges'
freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz \
    -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated \
    ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated &
# Out:
# [1] 3245

# %%
# redo the tesselation with the freshly fixed WM volume
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/filled.mgz
    
mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz &
mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz &
wait
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig &
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig &
wait

for xh in ${HEMI[@]}; do
    mris_extract_main_component ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
    mris_sphere -q ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.qsphere
    
    mris_euler_number ${fsSurf_temp}/${xh}.orig
    mris_remove_intersection ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
    mris_curvature -thresh .999 -n -a 5 -w -distances 10 10 ${fsSurf_temp}/${xh}.inflated
done
# Out:
# using voxel position (174, 152, 173) as corpus callosum seed point
# using voxel position (174, 226, 139) as pons seed point
# reading input volume...done.
# searching for cutting planes...INFO: volume does not have linear_transform set nor lta is given by option.-xform.
# INFO: use identity matrix as the talairach transform.
# INFO: use src volume parameters for the talairach volume.
# voxel to talairach voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Calculated talairach cc position (-0.25, -7.25, 25.50)
# Using the seed to calculate the cutting plane
# Looking for area (min, max) = (350, 1400)
# area[0] = 1677 (min = 350, max = 1400), aspect = 0.42 (min = 0.10, max = 0.75)
# need search nearby
# using seed (174, 152, 173), TAL = (-0.2, -7.2, 25.5)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# talairach cc position changed to (-0.25, -7.25, 25.50)
# Using voxel pons seed point, calculated talairach pons position (-0.25, -41.25, -48.50)
# Looking for area (min, max) = (350, 790)
# area[0] = 5181 (min = 350, max = 790), aspect = 0.61 (min = 0.60, max = 1.20)
# need search nearby
# using seed (174, 226, 139), TAL = (-0.2, -41.2, -48.5)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# done.
# seed_search_size = 9, min_neighbors = 5
# search rh wm seed point around talairach space:(17.75, -7.25, 25.50) SRC: (156.00, 152.00, 173.00)
# search lh wm seed point around talairach space (-18.25, -7.25, 25.50), SRC: (192.00, 152.00, 173.00)
# filling left hemisphere...
# filling volume: pass 3 of 3...total of 1691131 voxels filled...done.
# filling right hemisphere...
# filling volume: pass 3 of 3...total of 1691131 voxels filled...done.
# filling degenerate left hemisphere surface locations...
# 2297 voxels filled
# 19 voxels filled
# 3 voxels filled
# 1 voxels filled
# 1 voxels filled
# 0 voxels filled
# filling degenerate right hemisphere surface locations...
# 2297 voxels filled
# 19 voxels filled
# 3 voxels filled
# 1 voxels filled
# 1 voxels filled
# 0 voxels filled
# refilling left hemisphere...
# filling volume: pass 3 of 3...total of 1693452 voxels filled...done.
# refilling right hemisphere...
# filling volume: pass 3 of 3...total of 1693452 voxels filled...done.
# combining hemispheres...
# using variable coefficient diffusion to correct hemispheric overlap...
# 26:  1693105 ambiguous voxels remaining
# 9:  38743 ambiguous voxels remaining
# 8:  15383 ambiguous voxels remaining
# 7:  5116 ambiguous voxels remaining
# 6:  1812 ambiguous voxels remaining
# 5:  657 ambiguous voxels remaining
# 4:  275 ambiguous voxels remaining
# 3:  142 ambiguous voxels remaining
# 2:  97 ambiguous voxels remaining
# 1:  0 ambiguous voxels remaining
# writing output to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/mgz/filled.mgz...
# filling took 1.4 minutes
# badRH = 13/831198, badLH=17101/862255
# Please check filled volume.  Cerebellum may be included.
#
# [1] 27118
# [2] 27119
# Ambiguous edge configurations...
#
# Iteration Number : 1Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   2 found -   2 modified     |    TOTAL:   2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   2 (xy+):   0 found -   2 modified     |    TOTAL:   2
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   2
# pass   1 (yz+):   2 found -   2 modified     |    TOTAL:   2
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   2
# pass   2 (yz+):   0 found -   2 modified     |    TOTAL:   2
# pass   1 (yz-):   5 found -   5 modified     |    TOTAL:   7
# pass   1 (yz-):   5 found -   5 modified     |    TOTAL:   7
# pass   2 (yz-):   0 found -   5 modified     |    TOTAL:   7
# pass   2 (yz-):   0 found -   5 modified     |    TOTAL:   7
# pass   1 (xz+):   1 found -   1 modified     |    TOTAL:   8
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   7
# pass   1 (xz-):   3 found -   3 modified     |    TOTAL:  10
# pass   2 (xz+):   0 found -   1 modified     |    TOTAL:   8
# pass   2 (xz-):   0 found -   3 modified     |    TOTAL:  10
# Iteration Number : 1
# pass   1 (xz-):   7 found -   7 modified     |    TOTAL:  15
# pass   2 (xz-):   0 found -   7 modified     |    TOTAL:  15
# Iteration Number : 1
# pass   1 (+++):   9 found -   9 modified     |    TOTAL:   9
# pass   2 (+++):   0 found -   9 modified     |    TOTAL:   9
# pass   1 (+++):  24 found -  24 modified     |    TOTAL:  24
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   9
# pass   2 (+++):   0 found -  24 modified     |    TOTAL:  24
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   9
# pass   1 (+++):   3 found -   3 modified     |    TOTAL:  27
# pass   2 (+++):   0 found -   3 modified     |    TOTAL:  27
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   9
# Iteration Number : 1
# pass   1 (+++):   6 found -   6 modified     |    TOTAL:  33
# pass   1 (++):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (+++):   0 found -   6 modified     |    TOTAL:  33
# pass   1 (+++):   2 found -   2 modified     |    TOTAL:  35
# pass   2 (++):   0 found -   1 modified     |    TOTAL:   1
# pass   2 (+++):   0 found -   2 modified     |    TOTAL:  35
# Iteration Number : 1
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (++):   3 found -   3 modified     |    TOTAL:   3
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   1
# pass   2 (++):   0 found -   3 modified     |    TOTAL:   3
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 2
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   3
# pass   1 (xy+):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (xy+):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (--):   4 found -   4 modified     |    TOTAL:   7
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (yz+):   2 found -   2 modified     |    TOTAL:   3
# pass   2 (--):   0 found -   4 modified     |    TOTAL:   7
# pass   2 (yz+):   0 found -   2 modified     |    TOTAL:   3
# pass   1 (yz-):   1 found -   1 modified     |    TOTAL:   4
# pass   1 (-+):   2 found -   2 modified     |    TOTAL:   9
# pass   2 (yz-):   0 found -   1 modified     |    TOTAL:   4
# pass   1 (xz+):   1 found -   1 modified     |    TOTAL:   5
# pass   2 (-+):   0 found -   2 modified     |    TOTAL:   9
# Iteration Number : 2
# pass   2 (xz+):   0 found -   1 modified     |    TOTAL:   5
# pass   1 (xy+):   6 found -   6 modified     |    TOTAL:   6
# pass   1 (xz-):   1 found -   1 modified     |    TOTAL:   6
# pass   2 (xy+):   0 found -   6 modified     |    TOTAL:   6
# pass   2 (xz-):   0 found -   1 modified     |    TOTAL:   6
# Iteration Number : 2
# pass   1 (xy-):   1 found -   1 modified     |    TOTAL:   7
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   2 (xy-):   0 found -   1 modified     |    TOTAL:   7
# pass   1 (yz+):   1 found -   1 modified     |    TOTAL:   8
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   2 (yz+):   0 found -   1 modified     |    TOTAL:   8
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   1 found -   1 modified     |    TOTAL:   9
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   2 (yz-):   0 found -   1 modified     |    TOTAL:   9
# pass   1 (++):   1 found -   1 modified     |    TOTAL:   1
# pass   1 (xz+):   3 found -   3 modified     |    TOTAL:  12
# pass   2 (xz+):   0 found -   3 modified     |    TOTAL:  12
# pass   2 (++):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (xz-):   1 found -   1 modified     |    TOTAL:  13
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   1
# pass   2 (xz-):   0 found -   1 modified     |    TOTAL:  13
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 3
# pass   1 (+++):   2 found -   2 modified     |    TOTAL:   2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   2 (+++):   0 found -   2 modified     |    TOTAL:   2
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   2
# Iteration Number : 2
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   2 found -   2 modified     |    TOTAL:   2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   2 (--):   0 found -   2 modified     |    TOTAL:   2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   1 found -   1 modified     |    TOTAL:   3
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   2 (-+):   0 found -   1 modified     |    TOTAL:   3
# Iteration Number : 3
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   1 found -   1 modified     |    TOTAL:   1
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 27 (out of 862282: 0.003131)
#
#
# pass   2 (yz+):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 3
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3mri_pretess done
#
# [1]-  Done                    mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz
#
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 4
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 4
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 4
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 78 (out of 831276: 0.009383)
#
# mri_pretess done
#
# [2]+  Done                    mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz
# [1] 27142
# [2] 27143
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 30: 426 vertices, 479 faces
# slice 40: 4820 vertices, 4977 faces
# slice 30: 461 vertices, 513 faces
# slice 40: 4929 vertices, 5109 faces
# slice 50: 10978 vertices, 11180 faces
# slice 50: 11834 vertices, 12098 faces
# slice 60: 20543 vertices, 20988 faces
# slice 60: 25051 vertices, 25572 faces
# slice 70: 36411 vertices, 36982 faces
# slice 70: 45605 vertices, 46376 faces
# slice 80: 52426 vertices, 52944 faces
# slice 80: 67282 vertices, 67907 faces
# slice 90: 66138 vertices, 66630 faces
# slice 90: 83887 vertices, 84403 faces
# slice 100: 80783 vertices, 81375 faces
# slice 100: 101122 vertices, 101740 faces
# slice 110: 98059 vertices, 98709 faces
# slice 110: 121152 vertices, 121863 faces
# slice 120: 114121 vertices, 114718 faces
# slice 120: 139560 vertices, 140134 faces
# slice 130: 132977 vertices, 133643 faces
# slice 130: 158443 vertices, 159077 faces
# slice 140: 151140 vertices, 151810 faces
# slice 140: 176686 vertices, 177323 faces
# slice 150: 169043 vertices, 169724 faces
# slice 150: 194713 vertices, 195366 faces
# slice 160: 187578 vertices, 188272 faces
# slice 160: 213473 vertices, 214144 faces
# slice 170: 205256 vertices, 205931 faces
# slice 170: 231496 vertices, 232154 faces
# slice 180: 221693 vertices, 222400 faces
# slice 180: 248262 vertices, 248942 faces
# slice 190: 237676 vertices, 238342 faces
# slice 200: 253591 vertices, 254252 faces
# slice 190: 264384 vertices, 265006 faces
# slice 210: 268754 vertices, 269337 faces
# slice 200: 280338 vertices, 280955 faces
# slice 220: 280113 vertices, 280545 faces
# slice 210: 295431 vertices, 295968 faces
# slice 230: 289561 vertices, 290010 faces
# slice 220: 306647 vertices, 307047 faces
# slice 240: 299469 vertices, 299867 faces
# slice 230: 315925 vertices, 316329 faces
# slice 250: 307187 vertices, 307534 faces
# slice 240: 325636 vertices, 325995 faces
# slice 260: 312749 vertices, 313040 faces
# slice 250: 333432 vertices, 333742 faces
# slice 270: 317139 vertices, 317407 faces
# slice 260: 339022 vertices, 339271 faces
# slice 280: 320953 vertices, 321200 faces
# slice 270: 343406 vertices, 343634 faces
# slice 290: 324224 vertices, 324422 faces
# slice 280: 347177 vertices, 347378 faces
# slice 300: 326139 vertices, 326289 faces
# slice 290: 350236 vertices, 350388 faces
# slice 310: 326748 vertices, 326848 faces
# slice 300: 352126 vertices, 352236 faces
# slice 320: 326748 vertices, 326848 faces
# slice 310: 352702 vertices, 352762 faces
# slice 330: 326748 vertices, 326848 faces
# slice 320: 352702 vertices, 352762 faces
# slice 340: 326748 vertices, 326848 faces
# slice 330: 352702 vertices, 352762 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.orig
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   173.50000;
#  0.00000   0.00000   1.00000  -173.50000;
#  0.00000  -1.00000   0.00000   173.50000;
#  0.00000   0.00000   0.00000   1.00000;
# slice 340: 352702 vertices, 352762 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.orig
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   173.50000;
#  0.00000   0.00000   1.00000  -173.50000;
#  0.00000  -1.00000   0.00000   173.50000;
#  0.00000   0.00000   0.00000   1.00000;
# [1]-  Done                    mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig
# [2]+  Done                    mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig
#
# counting number of connected components...
#    352702 voxel in cpt #1: X=-60 [v=352702,e=1058286,f=705524] located at (-43.588398, -30.472410, 1.986601)
# For the whole surface: X=-60 [v=352702,e=1058286,f=705524]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.smoothwm
# avg radius = 74.9 mm, total surface area = 211177 mm^2
# step 060: RMS=0.044 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.sulc
# mris_inflate utimesec    74.410204
# mris_inflate stimesec    0.411967
# mris_inflate ru_maxrss   450336
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   110877
# mris_inflate ru_majflt   3
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  344
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    7266
# mris_inflate ru_nivcsw   262
# inflation took 1.3 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.201...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.981, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.723, avgs=0
# 010/300: dt: 0.9000, rms radial error=178.168, avgs=0
# 015/300: dt: 0.9000, rms radial error=177.439, avgs=0
# 020/300: dt: 0.9000, rms radial error=176.607, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.717, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.795, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.854, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.905, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.955, avgs=0
# 050/300: dt: 0.9000, rms radial error=171.021, avgs=0
# 055/300: dt: 0.9000, rms radial error=170.090, avgs=0
# 060/300: dt: 0.9000, rms radial error=169.156, avgs=0
# 065/300: dt: 0.9000, rms radial error=168.227, avgs=0
# 070/300: dt: 0.9000, rms radial error=167.301, avgs=0
# 075/300: dt: 0.9000, rms radial error=166.380, avgs=0
# 080/300: dt: 0.9000, rms radial error=165.463, avgs=0
# 085/300: dt: 0.9000, rms radial error=164.551, avgs=0
# 090/300: dt: 0.9000, rms radial error=163.643, avgs=0
# 095/300: dt: 0.9000, rms radial error=162.740, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.842, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.948, avgs=0
# 110/300: dt: 0.9000, rms radial error=160.058, avgs=0
# 115/300: dt: 0.9000, rms radial error=159.173, avgs=0
# 120/300: dt: 0.9000, rms radial error=158.293, avgs=0
# 125/300: dt: 0.9000, rms radial error=157.417, avgs=0
# 130/300: dt: 0.9000, rms radial error=156.545, avgs=0
# 135/300: dt: 0.9000, rms radial error=155.678, avgs=0
# 140/300: dt: 0.9000, rms radial error=154.816, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.958, avgs=0
# 150/300: dt: 0.9000, rms radial error=153.104, avgs=0
# 155/300: dt: 0.9000, rms radial error=152.255, avgs=0
# 160/300: dt: 0.9000, rms radial error=151.410, avgs=0
# 165/300: dt: 0.9000, rms radial error=150.570, avgs=0
# 170/300: dt: 0.9000, rms radial error=149.734, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.903, avgs=0
# 180/300: dt: 0.9000, rms radial error=148.076, avgs=0
# 185/300: dt: 0.9000, rms radial error=147.253, avgs=0
# 190/300: dt: 0.9000, rms radial error=146.435, avgs=0
# 195/300: dt: 0.9000, rms radial error=145.621, avgs=0
# 200/300: dt: 0.9000, rms radial error=144.812, avgs=0
# 205/300: dt: 0.9000, rms radial error=144.007, avgs=0
# 210/300: dt: 0.9000, rms radial error=143.206, avgs=0
# 215/300: dt: 0.9000, rms radial error=142.410, avgs=0
# 220/300: dt: 0.9000, rms radial error=141.617, avgs=0
# 225/300: dt: 0.9000, rms radial error=140.829, avgs=0
# 230/300: dt: 0.9000, rms radial error=140.046, avgs=0
# 235/300: dt: 0.9000, rms radial error=139.266, avgs=0
# 240/300: dt: 0.9000, rms radial error=138.491, avgs=0
# 245/300: dt: 0.9000, rms radial error=137.720, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.953, avgs=0
# 255/300: dt: 0.9000, rms radial error=136.190, avgs=0
# 260/300: dt: 0.9000, rms radial error=135.431, avgs=0
# 265/300: dt: 0.9000, rms radial error=134.677, avgs=0
# 270/300: dt: 0.9000, rms radial error=133.926, avgs=0
# 275/300: dt: 0.9000, rms radial error=133.180, avgs=0
# 280/300: dt: 0.9000, rms radial error=132.438, avgs=0
# 285/300: dt: 0.9000, rms radial error=131.700, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.966, avgs=0
# 295/300: dt: 0.9000, rms radial error=130.236, avgs=0
# 300/300: dt: 0.9000, rms radial error=129.510, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 0.70 +- 0.50 (0.00-->5.59) (max @ vno 197215 --> 199076)
# face area 0.01 +- 0.02 (-0.16-->0.42)
# epoch 1 (K=10.0), pass 1, starting sse = 45077.40
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00013
# epoch 2 (K=40.0), pass 1, starting sse = 9262.25
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00010
# epoch 3 (K=160.0), pass 1, starting sse = 1659.52
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.02/10 = 0.00245
# epoch 4 (K=640.0), pass 1, starting sse = 441.00
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.06/10 = 0.00618
# final distance error %41.79
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.qsphere
# mris_sphere utimesec    433.972161
# mris_sphere stimesec    1.267918
# mris_sphere ru_maxrss   450660
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   110879
# mris_sphere ru_majflt   7
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  600
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    6319
# mris_sphere ru_nivcsw   2359
# spherical transformation took 0.12 hours
# FSRUNTIME@ mris_sphere  0.1210 hours 1 threads
# euler # = v-e+f = 2g-2: 352702 - 1058286 + 705524 = -60 --> 31 holes
#       F =2V-4:          705524 != 705404-4 (-124)
#       2E=3F:            2116572 = 2116572 (0)
#
# total defect index = 62
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.smoothwm
# avg radius = 74.9 mm, total surface area = 211177 mm^2
# step 060: RMS=0.044 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.sulc
# mris_inflate utimesec    76.225886
# mris_inflate stimesec    0.487935
# mris_inflate ru_maxrss   450540
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   110878
# mris_inflate ru_majflt   3
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  344
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    7261
# mris_inflate ru_nivcsw   7297
# inflation took 1.3 minutes
# thresholding curvature at 99.90% level
# normalizing curvature values.
# averaging curvature patterns 5 times.
# sampling 10 neighbors out to a distance of 10 mm
# 1087 vertices thresholded to be in k1 ~ [-6.42 1.02], k2 ~ [-0.63 0.44]
# total integrated curvature = -9.007*4pi (-113.186) --> 10 handles
# ICI = 5.0, FI = 155.6, variation=2270.072
# 607 vertices thresholded to be in [-0.37 1.04]
# writing Gaussian curvature to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.inflated.K...curvature mean = 0.001, std = 0.033
# 373 vertices thresholded to be in [-3.15 0.51]
# curvature mean = -0.038, std = 0.148
# done.
# writing mean curvature to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/lh.inflated.H...done.
#
# counting number of connected components...
#    326748 voxel in cpt #1: X=-100 [v=326748,e=980544,f=653696] located at (46.440212, -25.276381, 4.359136)
# For the whole surface: X=-100 [v=326748,e=980544,f=653696]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.smoothwm
# avg radius = 73.0 mm, total surface area = 196983 mm^2
# step 060: RMS=0.042 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.sulc
# mris_inflate utimesec    61.978413
# mris_inflate stimesec    0.140023
# mris_inflate ru_maxrss   418932
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   102972
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  112
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    6758
# mris_inflate ru_nivcsw   230
# inflation took 1.0 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.204...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=179.575, avgs=0
# 005/300: dt: 0.9000, rms radial error=179.317, avgs=0
# 010/300: dt: 0.9000, rms radial error=178.763, avgs=0
# 015/300: dt: 0.9000, rms radial error=178.035, avgs=0
# 020/300: dt: 0.9000, rms radial error=177.207, avgs=0
# 025/300: dt: 0.9000, rms radial error=176.320, avgs=0
# 030/300: dt: 0.9000, rms radial error=175.402, avgs=0
# 035/300: dt: 0.9000, rms radial error=174.469, avgs=0
# 040/300: dt: 0.9000, rms radial error=173.532, avgs=0
# 045/300: dt: 0.9000, rms radial error=172.591, avgs=0
# 050/300: dt: 0.9000, rms radial error=171.651, avgs=0
# 055/300: dt: 0.9000, rms radial error=170.713, avgs=0
# 060/300: dt: 0.9000, rms radial error=169.776, avgs=0
# 065/300: dt: 0.9000, rms radial error=168.842, avgs=0
# 070/300: dt: 0.9000, rms radial error=167.912, avgs=0
# 075/300: dt: 0.9000, rms radial error=166.987, avgs=0
# 080/300: dt: 0.9000, rms radial error=166.066, avgs=0
# 085/300: dt: 0.9000, rms radial error=165.150, avgs=0
# 090/300: dt: 0.9000, rms radial error=164.238, avgs=0
# 095/300: dt: 0.9000, rms radial error=163.331, avgs=0
# 100/300: dt: 0.9000, rms radial error=162.429, avgs=0
# 105/300: dt: 0.9000, rms radial error=161.531, avgs=0
# 110/300: dt: 0.9000, rms radial error=160.638, avgs=0
# 115/300: dt: 0.9000, rms radial error=159.750, avgs=0
# 120/300: dt: 0.9000, rms radial error=158.866, avgs=0
# 125/300: dt: 0.9000, rms radial error=157.986, avgs=0
# 130/300: dt: 0.9000, rms radial error=157.111, avgs=0
# 135/300: dt: 0.9000, rms radial error=156.241, avgs=0
# 140/300: dt: 0.9000, rms radial error=155.375, avgs=0
# 145/300: dt: 0.9000, rms radial error=154.514, avgs=0
# 150/300: dt: 0.9000, rms radial error=153.657, avgs=0
# 155/300: dt: 0.9000, rms radial error=152.804, avgs=0
# 160/300: dt: 0.9000, rms radial error=151.956, avgs=0
# 165/300: dt: 0.9000, rms radial error=151.113, avgs=0
# 170/300: dt: 0.9000, rms radial error=150.273, avgs=0
# 175/300: dt: 0.9000, rms radial error=149.439, avgs=0
# 180/300: dt: 0.9000, rms radial error=148.608, avgs=0
# 185/300: dt: 0.9000, rms radial error=147.782, avgs=0
# 190/300: dt: 0.9000, rms radial error=146.960, avgs=0
# 195/300: dt: 0.9000, rms radial error=146.143, avgs=0
# 200/300: dt: 0.9000, rms radial error=145.330, avgs=0
# 205/300: dt: 0.9000, rms radial error=144.521, avgs=0
# 210/300: dt: 0.9000, rms radial error=143.717, avgs=0
# 215/300: dt: 0.9000, rms radial error=142.917, avgs=0
# 220/300: dt: 0.9000, rms radial error=142.121, avgs=0
# 225/300: dt: 0.9000, rms radial error=141.329, avgs=0
# 230/300: dt: 0.9000, rms radial error=140.542, avgs=0
# 235/300: dt: 0.9000, rms radial error=139.759, avgs=0
# 240/300: dt: 0.9000, rms radial error=138.980, avgs=0
# 245/300: dt: 0.9000, rms radial error=138.205, avgs=0
# 250/300: dt: 0.9000, rms radial error=137.434, avgs=0
# 255/300: dt: 0.9000, rms radial error=136.668, avgs=0
# 260/300: dt: 0.9000, rms radial error=135.906, avgs=0
# 265/300: dt: 0.9000, rms radial error=135.148, avgs=0
# 270/300: dt: 0.9000, rms radial error=134.394, avgs=0
# 275/300: dt: 0.9000, rms radial error=133.644, avgs=0
# 280/300: dt: 0.9000, rms radial error=132.898, avgs=0
# 285/300: dt: 0.9000, rms radial error=132.156, avgs=0
# 290/300: dt: 0.9000, rms radial error=131.418, avgs=0
# 295/300: dt: 0.9000, rms radial error=130.685, avgs=0
# 300/300: dt: 0.9000, rms radial error=129.955, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 0.73 +- 0.50 (0.00-->5.30) (max @ vno 171561 --> 173421)
# face area 0.01 +- 0.02 (-0.11-->0.38)
# epoch 1 (K=10.0), pass 1, starting sse = 41590.88
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00012
# epoch 2 (K=40.0), pass 1, starting sse = 8408.14
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00009
# epoch 3 (K=160.0), pass 1, starting sse = 1394.05
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.02/10 = 0.00241
# epoch 4 (K=640.0), pass 1, starting sse = 303.53
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.09/11 = 0.00778
# final distance error %40.75
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.qsphere
# mris_sphere utimesec    385.810502
# mris_sphere stimesec    0.352009
# mris_sphere ru_maxrss   418952
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   102969
# mris_sphere ru_majflt   3
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  376
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    5864
# mris_sphere ru_nivcsw   989
# spherical transformation took 0.11 hours
# FSRUNTIME@ mris_sphere  0.1073 hours 1 threads
# euler # = v-e+f = 2g-2: 326748 - 980544 + 653696 = -100 --> 51 holes
#       F =2V-4:          653696 != 653496-4 (-204)
#       2E=3F:            1961088 = 1961088 (0)
#
# total defect index = 102
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.smoothwm
# avg radius = 73.0 mm, total surface area = 196983 mm^2
# step 060: RMS=0.042 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/NMT/fsSurf/temp/rh.sulc
# mris_inflate utimesec    61.937213
# mris_inflate stimesec    0.140084
# mris_inflate ru_maxrss   418892
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   102971
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    6752
# mris_inflate ru_nivcsw   471
# inflation took 1.0 minutes
# thresholding curvature at 99.90% level
# normalizing curvature values.
# averaging curvature patterns 5 times.
# sampling 10 neighbors out to a distance of 10 mm

# %%
# create the spheres (this takes longer so do it only when you're happy with the inflated)
for xh in ${HEMI[@]}; do
    mris_sphere ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.sphere
done

# %% [markdown]
# #### Create a subject directory in your freesurfer subject directory

# %%
# create a freesurfer SUBJECT with the correct folder structure
# NB! $SUBJECTS_DIR should be defined in your ~/.bashrc as the Freesurfer subjects directory
echo 'Creating a subject directory for '${SUBJ}'in:'
echo ${SUBJECTS_DIR}/${SUBJ}
mksubjdirs ${SUBJECTS_DIR}/${SUBJ}

# %% [markdown]
# #### Move files to the Freesurfer subjects directory

# %%
# copy the necessary files for cutting to the subject directory
for xh in ${HEMI[@]}; do
    cp ${fsSurf_temp}/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.smoothwm ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.orig ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.qsphere ${SUBJECTS_DIR}/${SUBJ}/surf/
done

cp ${fsSurf_mgz}/T1.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/T1.mgz
cp ${fsSurf_mgz}/filled.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/filled.mgz
cp ${fsSurf_mgz}/wm.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/wm.mgz
cp ${fsSurf_mgz}/brain.finalsurfs.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brain.finalsurfs.mgz
cp ${fsSurf_mgz}/brainmask.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brainmask.mgz

# %% [markdown]
# Before we can start making the final surfaces we need a little trick to compensate for the low grey/white matter contrast in monkeys. Now that we have a white matter volume we are happy with (if not go back and fix it) we can use it to enhance the GM/WM contrast artificially and bring the voxel values into the range that Freesurfer expects. The difference looks somewhat like this (Left: normal brain, Right: contrast enhanced brain).
#
# ![Brain](pics/brain.png) ![Brain_enh](pics/brain_enhanced.png)

# %% [markdown]
# #### Make a contrast-enhanced brain volume to aid in getting the pial surface

# %%
# Make a folder for this procedure and convert the necessary files to nifti so we can use `fslmaths`
mkdir -p $fsSurf/enh
mri_convert ${fsSurf_mgz}/brain.mgz $fsSurf/enh/brain.nii.gz
mri_convert ${fsSurf_mgz}/wm.mgz $fsSurf/enh/wm.nii.gz

# binarize the wm volume
fslmaths $fsSurf/enh/wm.nii.gz -bin $fsSurf/enh/wm_bin.nii.gz

# divide the voxel value in the original brain volume by **some** value and add **another** value to the white matter only 
# which values you need here is up to you but we want to end with white matter voxels having a value ~110 and grey matter ~60-80
# alternative ways are definitely possible as long as your end result is similar
fslmaths $fsSurf/enh/brain.nii.gz -div 2 $fsSurf/enh/brain2.nii.gz
fslmaths $fsSurf/enh/wm_bin.nii.gz -mul 20 $fsSurf/enh/wm_add.nii.gz
fslmaths $fsSurf/enh/brain2.nii.gz -add $fsSurf/enh/wm_add.nii.gz $fsSurf/enh/brain_enh.nii.gz

# convert the 'enhanced' brain back to mgz
mri_convert $fsSurf/enh/brain_enh.nii.gz ${SUBJECTS_DIR}/${SUBJ}/mri/brain_enh.mgz

# %% [markdown]
# #### Create the surfaces

# %%
# create surfaces
# this will take a while. don't wait for it. go get a coffee, call your mother, or read a paper.
for xh in ${HEMI[@]}; do
    mris_make_surfaces -noaseg -noaparc -T1 brain_enh -orig_wm orig ${SUBJ} ${xh}
    mris_sphere ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.sphere
done

# %% [markdown]
# You should now have nicely looking inflated white matter surfaces and a projection of it onto a sphere surface. They should look somewhat like the following images.
# `freeview -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/lh.sphere &`
#
# ![surfaces_leged](pics/final_surf_legend.png)

# %%
# freeview -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/lh.sphere &
freeview -f ${SUBJECTS_DIR}/${SUBJ}/surf/lh.smoothwm ${SUBJECTS_DIR}/${SUBJ}/surf/lh.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/lh.sphere &

# %%
# check and edit the pial surface
mkdir -p ${SUBJECTS_DIR}/${SUBJ}/pial_edits # create a folder for pial edits
cp -R ${SUBJECTS_DIR}/${SUBJ}/mri ${SUBJECTS_DIR}/${SUBJ}/pial_edits/ 
cp -R ${SUBJECTS_DIR}/${SUBJ}/surf ${SUBJECTS_DIR}/${SUBJ}/pial_edits/

# %%
freeview -v ${SUBJECTS_DIR}/${SUBJ}/pial_edits/mri/T1.mgz ${SUBJECTS_DIR}/${SUBJ}/pial_edits/mri/brain_enh.mgz \
    -f ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/lh.white:edgecolor=yellow ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/lh.pial:edgecolor=red \
    ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/rh.white:edgecolor=yellow ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/rh.pial:edgecolor=red &

# %%
# NB! If you adjustments to the brainmask (which probably isn't necessary if NMT segmentation worked well) 
# don't forget to copy back the adjusted brain_enh for re-generation of the pial surface 
cp ${SUBJECTS_DIR}/${SUBJ}/pial_edits/mri/brain_enh.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brain_enh.mgz

# %%
# regenerate the pial surface
for xh in ${HEMI[@]}; do
    mris_make_surfaces  -noaseg -noaparc -orig_white white -orig_pial white -nowhite -mgz -T1 brain_enh ${SUBJ} ${xh}
done

# %%
# create midcortical surface by growing the white matter halfway towards the pial surface
for xh in ${HEMI[@]}; do
    mris_expand -thickness ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white 0.5 ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid
done

# %%
# Fix topology, smooth & inflate the final surfaces
for xh in ${HEMI[@]}; do    
    mris_euler_number ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white
    mris_remove_intersection ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white
    mris_smooth -n 3 -nw ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.smoothwm
    
    mris_euler_number ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.pial
    mris_remove_intersection ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.pial ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.pial
    mris_smooth -n 3 -nw ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.pial ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.smoothpial
    
    mris_euler_number ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid
    mris_remove_intersection ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid
    mris_smooth -n 3 -nw ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.smoothgraymid
    
    mris_inflate ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.smoothwm ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated
    mris_curvature -thresh .999 -n -a 5 -w -distances 10 10 ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated
    mris_sphere ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.sphere
done

# %% [markdown]
# #### Cut surfaces and create flatmaps
#
# The cells below will load the inflated hemispheres in tksurfer where you can make the cuts to create the flatmaps.
#
# For the full hemisphere make cuts on the medial wall. One cut enclosing the midline and five additional relaxation cuts.
# Mark a point on the part of the surface you want to keep and save patch as `?h.full.patch.3d` (replace '?' with 'l' and 'r' respectively)
#
# ![Cut_full](pics/Cut_full.png)
#
# For an occipital patch make one cut on the medial wall along the calcarine sulcus. Use 3 points to select a coronal cutting plane, and a fourth point to select which part of the surface you want to keep and save as `?h.occip.patch.3d`
#
# ![Cut_occip1](pics/Cut_occip1.png) ![Cut_occip1](pics/Cut_occip2.png)

# %%
# left
#tksurfer ${SUBJ} lh inflated -curv
tksurfer ${SUBJ} lh inflated -gray

# %%
# right
#tksurfer ${SUBJ} rh inflated -curv
tksurfer ${SUBJ} rh inflated -gray

# %%
# Time for another coffee, you are not going to want to wait for this to finish while staring at its progress
cd ${SUBJECTS_DIR}/${SUBJ}/surf/
for xh in ${HEMI[@]}; do
    mris_flatten -w 0 -distances 20 7 ${xh}.full.patch.3d  ${xh}.full.patch.flat
    mris_flatten -w 0 -distances 20 7 ${xh}.occip.patch.3d  ${xh}.occip.patch.flat
done

# %% [markdown]
# If everything went well, you now have flatmaps of the white matter surface.
# They should look somewhat like this:
#
# **Full hemisphere (rh)**
# ![RH_flatmap](pics/RH_Flat_Sulci_gray_nolegend.png) ![RH_flatmap_legend](pics/RH_Flat_Sulci_gray_legend.png)
#
# **Occipital (rh)** (functional areas are guesstimates based on anatomy)
# ![RH_occip](pics/RH_Flat_occip_gray_nolegend.png) ![RH_occip_gray_legend](pics/RH_Flat_occip_gray_legend.png)
#
# It is of course also possible to make **any** other funtionally relevant cutting pattern to extract a flatmap of a piece of cortex. The method is the same.

# %%
# check your result
#tksurfer ${SUBJ} rh inflated -patch rh.full.patch.flat -curv # for a red/green curvature map
tksurfer ${SUBJ} lh inflated -patch lh.full.patch.flat -gray # for a gray curvature map

# %% [markdown]
# #### Convert Freesurfer surfaces to Gifti
# Other software may like this better.

# %%
mkdir -p gii
for xh in ${HEMI[@]}; do
    mris_convert ${xh}.white ./gii/${xh}.white.gii
    mris_convert ${xh}.graymid ./gii/${xh}.graymid.gii
    mris_convert ${xh}.pial ./gii/${xh}.pial.gii
    mris_convert ${xh}.inflated ./gii/${xh}.inflated.gii

    mris_convert ${xh}.smoothwm ./gii/${xh}.smoothwm.gii
    mris_convert ${xh}.smoothgraymid ./gii/${xh}.smoothgraymid.gii
    mris_convert ${xh}.smoothpial ./gii/${xh}.smoothpial.gii
    
    mris_convert -p -c ${xh}.curv ${xh}.full.patch.flat ./gii/${xh}.full.patch.flat.gii
    mris_convert -p -c ${xh}.curv ${xh}.occip.patch.flat ./gii/${xh}.occip.patch.flat.gii
done

# %% [markdown]
# #### Copy Freesurfer results back to NMT template folder

# %%
cp -r ${SUBJECTS_DIR}/${SUBJ}/surf ${fsSurf}/surf

# %%
# return to startpath
cd ${startpath}

# %% [markdown]
# ----
# ----
# ## **Step 4 (OPTIONAL): Create additional surfaces using Connectome Workbench.**
# This should not be necessary at all. Try the Freesurfer approach and a conversion to gifti with `mris_convert` first (as explained above)
#
# ----
# ----
#
# ### Requirements
#   - Connectome Workbench (https://www.humanconnectome.org/software/connectome-workbench)

# %%
# THIS SHOULDN'T BE NECESSARY SINCE WE'RE GETTINGS THESE OUTPUTS ALSO FROM THE FREESURFER PIPELINE !! #

# set path to where you want the results
wbSurf_path=${NMT_path}/single_subject_scans/${SUBJ}/wbSurf

echo 'Extracting surfaces from segmentation'
cd ${wbSurf_path}

# create surfaces
IsoSurface -input ${NMT_ss_path}/NMT_${SUBJ}_process/${SUBJ}_segmentation.nii.gz \
    -isorois -o_gii surf

# rename to something recognizable
mv surf.k2.gii gm.surf.gii # gm surface
mv surf.k3.gii wm.surf.gii # wm surface

# Smooth the surfaces a bit
echo 'Smoothing the surfaces a bit' 
wb_command -surface-smoothing wm.surf.gii 0.5 1 wm_sm.surf.gii
wb_command -surface-smoothing gm.surf.gii 0.5 1 gm_sm.surf.gii

# inflate the surfaces
echo 'Inflating the surfaces'
wb_command -surface-generate-inflated \
    wm_sm.surf.gii infl_wm_sm.surf.gii vinfl_wm_sm.surf.gii
wb_command -surface-generate-inflated \
    gm_sm.surf.gii infl_gm_sm.surf.gii vinfl_gm_sm.surf.gii

# view the result in your favorite viewer
echo 'Inspect the surfaces in a viewer'
freeview -f wm_sm.surf.gii infl_wm_sm.surf.gii vinfl_wm_sm.surf.gii \
    gm_sm.surf.gii infl_gm_sm.surf.gii vinfl_gm_sm.surf.gii
