# %% [markdown]
# ## CREATE FS-SURFACES FROM NMT-SEGMENTED ANATOMICALS

# %% [markdown]
# ### Initiate files and paths

# %%
# Subject name
SUBJ=Danny

# paths
src_path=~/Desktop/FS_ALT/${SUBJ}
src_vol=${src_path}/${SUBJ}_N4
src_brain=${src_path}/${SUBJ}_brain
src_brainmask=${src_path}/${SUBJ}_brainmask
src_WM=${src_path}/${SUBJ}_WM
out_path=~/Desktop/FS_ALT/${SUBJ}/fs
mkdir -p ${out_path}

# facilitate doing hemispheres in a for loop
HEMI=(lh rh)

# %% [markdown]
# ### Change headers to fake 1 mm voxels

# %%
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen $src_vol.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen $src_brain.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen $src_brainmask.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen $src_WM.nii.gz
# Out:
# ++ 3drefit: AFNI version=AFNI_17.2.08 (Aug 18 2017) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /Users/chris/Desktop/FS_ALT/Danny/Danny_N4.nii.gz
#  + loading and re-writing dataset /Users/chris/Desktop/FS_ALT/Danny/Danny_N4.nii.gz (/Users/chris/Desktop/FS_ALT/Danny/Danny_N4.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# ++ 3drefit: AFNI version=AFNI_17.2.08 (Aug 18 2017) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /Users/chris/Desktop/FS_ALT/Danny/Danny_brain.nii.gz
#  + loading and re-writing dataset /Users/chris/Desktop/FS_ALT/Danny/Danny_brain.nii.gz (/Users/chris/Desktop/FS_ALT/Danny/Danny_brain.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# ++ 3drefit: AFNI version=AFNI_17.2.08 (Aug 18 2017) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /Users/chris/Desktop/FS_ALT/Danny/Danny_brainmask.nii.gz
#  + loading and re-writing dataset /Users/chris/Desktop/FS_ALT/Danny/Danny_brainmask.nii.gz (/Users/chris/Desktop/FS_ALT/Danny/Danny_brainmask.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# ++ 3drefit: AFNI version=AFNI_17.2.08 (Aug 18 2017) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /Users/chris/Desktop/FS_ALT/Danny/Danny_WM.nii.gz
#  + loading and re-writing dataset /Users/chris/Desktop/FS_ALT/Danny/Danny_WM.nii.gz (/Users/chris/Desktop/FS_ALT/Danny/Danny_WM.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets

# %% [markdown]
# ### Convert volumes to mgz

# %%
mri_convert -c $src_vol.nii.gz $src_vol.mgz
mri_convert -c $src_brain.nii.gz $src_brain.mgz
mri_convert -c $src_brainmask.nii.gz $src_brainmask.mgz
mri_convert -c $src_WM.nii.gz $src_WM.mgz
# Out:
# mri_convert.bin -c /Users/chris/Desktop/FS_ALT/Danny/Danny_N4.nii.gz /Users/chris/Desktop/FS_ALT/Danny/Danny_N4.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /Users/chris/Desktop/FS_ALT/Danny/Danny_N4.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /Users/chris/Desktop/FS_ALT/Danny/Danny_N4.mgz...
# mri_convert.bin -c /Users/chris/Desktop/FS_ALT/Danny/Danny_brain.nii.gz /Users/chris/Desktop/FS_ALT/Danny/Danny_brain.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /Users/chris/Desktop/FS_ALT/Danny/Danny_brain.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /Users/chris/Desktop/FS_ALT/Danny/Danny_brain.mgz...
# mri_convert.bin -c /Users/chris/Desktop/FS_ALT/Danny/Danny_brainmask.nii.gz /Users/chris/Desktop/FS_ALT/Danny/Danny_brainmask.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /Users/chris/Desktop/FS_ALT/Danny/Danny_brainmask.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /Users/chris/Desktop/FS_ALT/Danny/Danny_brainmask.mgz...
# mri_convert.bin -c /Users/chris/Desktop/FS_ALT/Danny/Danny_WM.nii.gz /Users/chris/Desktop/FS_ALT/Danny/Danny_WM.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /Users/chris/Desktop/FS_ALT/Danny/Danny_WM.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /Users/chris/Desktop/FS_ALT/Danny/Danny_WM.mgz...

# %% [markdown]
# ### Get corpus callosum and pons coordinates & fill WM

# %%
# Inspect volume to get voxel coordinates
freeview -v $src_brain.mgz &
# Out:
# objc[49262]: Class FIFinderSyncExtensionHost is implemented in both /System/Library/PrivateFrameworks/FinderKit.framework/Versions/A/FinderKit (0x7fff8e993210) and /System/Library/PrivateFrameworks/FileProvider.framework/OverrideBundles/FinderSyncCollaborationFileProviderOverride.bundle/Contents/MacOS/FinderSyncCollaborationFileProviderOverride (0x11e9e3dc8). One of the two will be used. Which one is undefined.

# %%
# Fill in WM and check result
CC=(127 114 129)
PONS=(124 148 129)

# Fill WM
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    $src_WM.mgz $out_path/WM_filled.mgz

# Check the result
freeview $out_path/WM_filled.mgz &
# Out:
# using voxel position (127, 114, 129) as corpus callosum seed point
# using voxel position (124, 148, 129) as pons seed point
# reading input volume...done.
# searching for cutting planes...INFO: volume does not have linear_transform set nor lta is given by option.-xform.
# INFO: use identity matrix as the talairach transform.
# INFO: use src volume parameters for the talairach volume.
# voxel to talairach voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Calculated talairach cc position (2.51, 5.66, 145.03)
# Using the seed to calculate the cutting plane
# Looking for area (min, max) = (350, 1400)
# area[0] = 579 (min = 350, max = 1400), aspect = 0.39 (min = 0.10, max = 0.75)
# no need to search
# using seed (127, 114, 129), TAL = (2.5, 5.7, 145.0)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# talairach cc position changed to (2.51, 5.66, 145.03)
# Using voxel pons seed point, calculated talairach pons position (5.51, 5.66, 111.03)
# find_cutting_plane:seed point not in structure! Searching neighborhood...
# Looking for area (min, max) = (350, 790)
# area[0] = 604 (min = 350, max = 790), aspect = 0.79 (min = 0.60, max = 1.20)
# no need to search
# using seed (124, 148, 129), TAL = (5.5, 5.7, 111.0)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# done.
# seed_search_size = 9, min_neighbors = 5
# search rh wm seed point around talairach space:(20.51, 5.66, 145.03) SRC: (109.00, 114.00, 129.00)
# search lh wm seed point around talairach space (-15.49, 5.66, 145.03), SRC: (145.00, 114.00, 129.00)
# filling left hemisphere...
# filling volume: pass 3 of 3...total of 137810 voxels filled...done.
# filling right hemisphere...
# filling volume: pass 3 of 3...total of 137263 voxels filled...done.
# filling degenerate left hemisphere surface locations...
# 73 voxels filled
# 0 voxels filled
# filling degenerate right hemisphere surface locations...
# 102 voxels filled
# 0 voxels filled
# refilling left hemisphere...
# filling volume: pass 3 of 3...total of 137883 voxels filled...done.
# refilling right hemisphere...
# filling volume: pass 3 of 3...total of 137365 voxels filled...done.
# combining hemispheres...
# writing output to /Users/chris/Desktop/FS_ALT/Danny/fs/WM_filled.mgz...
# filling took 0.2 minutes
# [1] 60984

# %%
# copy the white matter volume so we can edit it later
cp $src_WM.mgz $out_path/${SUBJ}_WM_fix.mgz
# Out:
# using voxel position (127, 114, 129) as corpus callosum seed point
# using voxel position (124, 148, 129) as pons seed point
# reading input volume...done.
# searching for cutting planes...INFO: volume does not have linear_transform set nor lta is given by option.-xform.
# INFO: use identity matrix as the talairach transform.
# INFO: use src volume parameters for the talairach volume.
# voxel to talairach voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Calculated talairach cc position (2.51, 5.66, 145.03)
# Using the seed to calculate the cutting plane
# Looking for area (min, max) = (350, 1400)
# area[0] = 579 (min = 350, max = 1400), aspect = 0.39 (min = 0.10, max = 0.75)
# no need to search
# using seed (127, 114, 129), TAL = (2.5, 5.7, 145.0)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# talairach cc position changed to (2.51, 5.66, 145.03)
# Using voxel pons seed point, calculated talairach pons position (5.51, 5.66, 111.03)
# find_cutting_plane:seed point not in structure! Searching neighborhood...
# Looking for area (min, max) = (350, 790)
# area[0] = 604 (min = 350, max = 790), aspect = 0.79 (min = 0.60, max = 1.20)
# no need to search
# using seed (124, 148, 129), TAL = (5.5, 5.7, 111.0)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# done.
# seed_search_size = 9, min_neighbors = 5
# search rh wm seed point around talairach space:(20.51, 5.66, 145.03) SRC: (109.00, 114.00, 129.00)
# search lh wm seed point around talairach space (-15.49, 5.66, 145.03), SRC: (145.00, 114.00, 129.00)
# filling left hemisphere...
# filling volume: pass 3 of 3...total of 138390 voxels filled...done.
# filling right hemisphere...
# filling volume: pass 3 of 3...total of 138675 voxels filled...done.
# filling degenerate left hemisphere surface locations...
# 80 voxels filled
# 0 voxels filled
# filling degenerate right hemisphere surface locations...
# 102 voxels filled
# 0 voxels filled
# refilling left hemisphere...
# filling volume: pass 3 of 3...total of 138470 voxels filled...done.
# refilling right hemisphere...
# filling volume: pass 3 of 3...total of 138777 voxels filled...done.
# combining hemispheres...
# writing output to /Users/chris/Desktop/FS_ALT/Danny/fs/WM_filled.mgz...
# filling took 0.2 minutes

# %% [markdown]
# ### Tesselate volumes (first run)

# %%
# left
mri_pretess $out_path/WM_filled.mgz 255 $src_brain.mgz $out_path/WM_filled-pretess255.mgz
mri_tessellate $out_path/WM_filled-pretess255.mgz 255 $out_path/lh.orig.nofix
# right
mri_pretess $out_path/WM_filled.mgz 127 $src_brain.mgz $out_path/WM_filled-pretess127.mgz
mri_tessellate $out_path/WM_filled-pretess127.mgz 127 $out_path/rh.orig.nofix

for xh in ${HEMI[@]}; do
    # -- Tesselate hemispheres --
    # NB! you may need to redo from here after fixing WM
    mris_extract_main_component $out_path/${xh}.orig.nofix $out_path/${xh}.orig.nofix
    mris_smooth -nw $out_path/${xh}.orig.nofix $out_path/${xh}.smoothwm.nofix
    mris_inflate $out_path/${xh}.smoothwm.nofix $out_path/${xh}.inflated.nofix
    mris_sphere -q $out_path/${xh}.inflated.nofix $out_path/${xh}.qsphere.nofix
done
# Out:
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   3 found -   3 modified     |    TOTAL:   3
# pass   2 (yz-):   0 found -   3 modified     |    TOTAL:   3
# pass   1 (xz+):   1 found -   1 modified     |    TOTAL:   4
# pass   2 (xz+):   0 found -   1 modified     |    TOTAL:   4
# pass   1 (xz-):   1 found -   1 modified     |    TOTAL:   5
# pass   2 (xz-):   0 found -   1 modified     |    TOTAL:   5
# Iteration Number : 1
# pass   1 (+++):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (+++):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 1
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 6 (out of 138477: 0.004333)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1580 vertices, 1675 faces
# slice 70: 5629 vertices, 5791 faces
# slice 80: 10856 vertices, 11000 faces
# slice 90: 15965 vertices, 16174 faces
# slice 100: 22160 vertices, 22351 faces
# slice 110: 29552 vertices, 29834 faces
# slice 120: 37856 vertices, 38147 faces
# slice 130: 45883 vertices, 46171 faces
# slice 140: 53183 vertices, 53445 faces
# slice 150: 59857 vertices, 60119 faces
# slice 160: 65594 vertices, 65774 faces
# slice 170: 70217 vertices, 70382 faces
# slice 180: 73353 vertices, 73464 faces
# slice 190: 75322 vertices, 75395 faces
# slice 200: 76336 vertices, 76374 faces
# slice 210: 76532 vertices, 76548 faces
# slice 220: 76532 vertices, 76548 faces
# slice 230: 76532 vertices, 76548 faces
# slice 240: 76532 vertices, 76548 faces
# slice 250: 76532 vertices, 76548 faces
# using the conformed surface RAS to save vertex points...
# writing /Users/chris/Desktop/FS_ALT/Danny/fs/lh.orig.nofix
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
#
# counting number of connected components...
#    76532 voxel in cpt #1: X=-16 [v=76532,e=229644,f=153096] located at (-22.840891, -8.097528, 6.584710)
# For the whole surface: X=-16 [v=76532,e=229644,f=153096]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /Users/chris/Desktop/FS_ALT/Danny/fs/lh.smoothwm.nofix
# avg radius = 39.0 mm, total surface area = 44778 mm^2
# step 060: RMS=0.040 (target=0.015)
# inflation complete.
# writing inflated surface to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.inflated.nofix
# writing sulcal depths to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.sulc
# mris_inflate utimesec    10.576079
# mris_inflate stimesec    0.066327
# mris_inflate ru_maxrss   103149568
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   25289
# mris_inflate ru_majflt   71
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    3
# mris_inflate ru_nivcsw   4058
# inflation took 0.2 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.355...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.889, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.632, avgs=0
# 010/300: dt: 0.9000, rms radial error=178.081, avgs=0
# 015/300: dt: 0.9000, rms radial error=177.356, avgs=0
# 020/300: dt: 0.9000, rms radial error=176.530, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.646, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.730, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.796, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.854, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.908, avgs=0
# 050/300: dt: 0.9000, rms radial error=170.962, avgs=0
# 055/300: dt: 0.9000, rms radial error=170.017, avgs=0
# 060/300: dt: 0.9000, rms radial error=169.076, avgs=0
# 065/300: dt: 0.9000, rms radial error=168.138, avgs=0
# 070/300: dt: 0.9000, rms radial error=167.204, avgs=0
# 075/300: dt: 0.9000, rms radial error=166.274, avgs=0
# 080/300: dt: 0.9000, rms radial error=165.348, avgs=0
# 085/300: dt: 0.9000, rms radial error=164.427, avgs=0
# 090/300: dt: 0.9000, rms radial error=163.510, avgs=0
# 095/300: dt: 0.9000, rms radial error=162.597, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.689, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.786, avgs=0
# 110/300: dt: 0.9000, rms radial error=159.887, avgs=0
# 115/300: dt: 0.9000, rms radial error=158.993, avgs=0
# 120/300: dt: 0.9000, rms radial error=158.104, avgs=0
# 125/300: dt: 0.9000, rms radial error=157.219, avgs=0
# 130/300: dt: 0.9000, rms radial error=156.339, avgs=0
# 135/300: dt: 0.9000, rms radial error=155.463, avgs=0
# 140/300: dt: 0.9000, rms radial error=154.592, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.725, avgs=0
# 150/300: dt: 0.9000, rms radial error=152.864, avgs=0
# 155/300: dt: 0.9000, rms radial error=152.007, avgs=0
# 160/300: dt: 0.9000, rms radial error=151.154, avgs=0
# 165/300: dt: 0.9000, rms radial error=150.306, avgs=0
# 170/300: dt: 0.9000, rms radial error=149.462, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.623, avgs=0
# 180/300: dt: 0.9000, rms radial error=147.788, avgs=0
# 185/300: dt: 0.9000, rms radial error=146.958, avgs=0
# 190/300: dt: 0.9000, rms radial error=146.132, avgs=0
# 195/300: dt: 0.9000, rms radial error=145.311, avgs=0
# 200/300: dt: 0.9000, rms radial error=144.495, avgs=0
# 205/300: dt: 0.9000, rms radial error=143.682, avgs=0
# 210/300: dt: 0.9000, rms radial error=142.875, avgs=0
# 215/300: dt: 0.9000, rms radial error=142.072, avgs=0
# 220/300: dt: 0.9000, rms radial error=141.273, avgs=0
# 225/300: dt: 0.9000, rms radial error=140.479, avgs=0
# 230/300: dt: 0.9000, rms radial error=139.689, avgs=0
# 235/300: dt: 0.9000, rms radial error=138.903, avgs=0
# 240/300: dt: 0.9000, rms radial error=138.122, avgs=0
# 245/300: dt: 0.9000, rms radial error=137.345, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.573, avgs=0
# 255/300: dt: 0.9000, rms radial error=135.805, avgs=0
# 260/300: dt: 0.9000, rms radial error=135.041, avgs=0
# 265/300: dt: 0.9000, rms radial error=134.281, avgs=0
# 270/300: dt: 0.9000, rms radial error=133.526, avgs=0
# 275/300: dt: 0.9000, rms radial error=132.775, avgs=0
# 280/300: dt: 0.9000, rms radial error=132.028, avgs=0
# 285/300: dt: 0.9000, rms radial error=131.285, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.547, avgs=0
# 295/300: dt: 0.9000, rms radial error=129.812, avgs=0
# 300/300: dt: 0.9000, rms radial error=129.082, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.36 +- 0.77 (0.00-->8.57) (max @ vno 26100 --> 26127)
# face area 0.04 +- 0.04 (-0.26-->0.74)
# epoch 1 (K=10.0), pass 1, starting sse = 8288.05
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00021
# epoch 2 (K=40.0), pass 1, starting sse = 1191.54
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00016
# epoch 3 (K=160.0), pass 1, starting sse = 109.52
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.06/10 = 0.00572
# epoch 4 (K=640.0), pass 1, starting sse = 8.49
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.12/14 = 0.00848
# final distance error %27.76
# writing spherical brain to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.qsphere.nofix
# mris_sphere utimesec    74.243509
# mris_sphere stimesec    0.226098
# mris_sphere ru_maxrss   108384256
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   26576
# mris_sphere ru_majflt   67
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1
# mris_sphere ru_nivcsw   35644
# spherical transformation took 0.02 hours
# FSRUNTIME@ mris_sphere  0.0207 hours 1 threads

# %%
# Inspect the results
freeview -v $src_brain.mgz \
    -f $out_path/lh.smoothwm.nofix $out_path/lh.inflated.nofix \
    $out_path/rh.smoothwm.nofix $out_path/rh.inflated.nofix &
# Out:
# objc[50485]: Class FIFinderSyncExtensionHost is implemented in both /System/Library/PrivateFrameworks/FinderKit.framework/Versions/A/FinderKit (0x7fff8e993210) and /System/Library/PrivateFrameworks/FileProvider.framework/OverrideBundles/FinderSyncCollaborationFileProviderOverride.bundle/Contents/MacOS/FinderSyncCollaborationFileProviderOverride (0x11ee99dc8). One of the two will be used. Which one is undefined.
# Correlation data does not match with surface
# 2019-02-05 19:07:17.859 Freeview[50485:5005620] modalSession has been exited prematurely - check for a reentrant call to endModalSession:

# %%
# Fix topology
for xh in ${HEMI[@]}; do
    cp $out_path/${xh}.orig.nofix $out_path/${xh}.orig
    cp $out_path/${xh}.inflated.nofix $out_path/${xh}.inflated
    mris_euler_number $out_path/${xh}.orig
    mris_remove_intersection $out_path/${xh}.orig $out_path/${xh}.orig
    mris_smooth -nw $out_path/${xh}.orig $out_path/${xh}.smoothwm
    mris_inflate $out_path/${xh}.smoothwm $out_path/${xh}.inflated
done

# %% [markdown]
# ### Manual adjustments and re-tesselations

# %%
# Check results again and edit the WM volume to fix errors
# keep doing this until you're happy with the result
freeview -v $src_brain.mgz -v $out_path/${SUBJ}_WM_fix.mgz \
    -f $out_path/lh.smoothwm $out_path/lh.inflated \
    $out_path/rh.smoothwm $out_path/rh.inflated &
# Out:
# MRISreadVertexPosition(white): could not open file /Users/chris/Desktop/FS_ALT/Danny/fs/lh.white
# No such file or directory
# could not load surface from white
# MRISreadVertexPosition(white): could not open file /Users/chris/Desktop/FS_ALT/Danny/fs/lh.white
# MRISreadVertexPosition(white): could not open file /Users/chris/Desktop/FS_ALT/Danny/fs/rh.white
# No such file or directory
# could not load surface from white
# MRISreadVertexPosition(white): could not open file /Users/chris/Desktop/FS_ALT/Danny/fs/rh.white
# /Users/chris/Desktop/FS_ALT/Danny/fs/Danny_WM_fix.mgz saved successfully.

# %%
# redo the tesselation with the fixed WM volume
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    $out_path/${SUBJ}_WM_fix.mgz $out_path/WM_filled.mgz
    
mri_pretess $out_path/WM_filled.mgz 255 $src_brain.mgz $out_path/WM_filled-pretess255.mgz
mri_tessellate $out_path/WM_filled-pretess255.mgz 255 $out_path/lh.orig.nofix
mri_pretess $out_path/WM_filled.mgz 127 $src_brain.mgz $out_path/WM_filled-pretess127.mgz
mri_tessellate $out_path/WM_filled-pretess127.mgz 127 $out_path/rh.orig.nofix

HEMI=(lh rh)
for xh in ${HEMI[@]}; do
    mris_extract_main_component $out_path/${xh}.orig.nofix $out_path/${xh}.orig.nofix
    mris_smooth -nw $out_path/${xh}.orig.nofix $out_path/${xh}.smoothwm.nofix
    mris_inflate $out_path/${xh}.smoothwm.nofix $out_path/${xh}.inflated.nofix
    mris_sphere -q $out_path/${xh}.inflated.nofix $out_path/${xh}.qsphere.nofix
    
    cp $out_path/${xh}.orig.nofix $out_path/${xh}.orig
    cp $out_path/${xh}.inflated.nofix $out_path/${xh}.inflated
    
    mris_euler_number $out_path/${xh}.orig
    mris_remove_intersection $out_path/${xh}.orig $out_path/${xh}.orig
    mris_smooth -nw $out_path/${xh}.orig $out_path/${xh}.smoothwm
    mris_inflate $out_path/${xh}.smoothwm $out_path/${xh}.inflated
    mris_curvature -thresh .999 -n -a 5 -w -distances 10 10 $out_path/${xh}.inflated
done
echo 'TESSELATION DONE!'
# Out:
# MRISreadVertexPosition(white): could not open file /Users/chris/Desktop/FS_ALT/Danny/fs/lh.white
# No such file or directory
# could not load surface from white
# MRISreadVertexPosition(white): could not open file /Users/chris/Desktop/FS_ALT/Danny/fs/lh.white
# MRISreadVertexPosition(white): could not open file /Users/chris/Desktop/FS_ALT/Danny/fs/rh.white
# No such file or directory
# could not load surface from white
# MRISreadVertexPosition(white): could not open file /Users/chris/Desktop/FS_ALT/Danny/fs/rh.white
# /Users/chris/Desktop/FS_ALT/Danny/fs/Danny_WM_fix.mgz saved successfully.
# [1]+  Done                    freeview -v $src_brain.mgz -v $out_path/${SUBJ}_WM_fix.mgz -f $out_path/lh.smoothwm $out_path/lh.inflated $out_path/rh.smoothwm $out_path/rh.inflated
# using voxel position (127, 114, 129) as corpus callosum seed point
# using voxel position (124, 148, 129) as pons seed point
# reading input volume...done.
# searching for cutting planes...INFO: volume does not have linear_transform set nor lta is given by option.-xform.
# INFO: use identity matrix as the talairach transform.
# INFO: use src volume parameters for the talairach volume.
# voxel to talairach voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Calculated talairach cc position (2.51, 5.66, 145.03)
# Using the seed to calculate the cutting plane
# Looking for area (min, max) = (350, 1400)
# area[0] = 446 (min = 350, max = 1400), aspect = 0.26 (min = 0.10, max = 0.75)
# no need to search
# using seed (127, 114, 129), TAL = (2.5, 5.7, 145.0)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# talairach cc position changed to (2.51, 5.66, 145.03)
# Using voxel pons seed point, calculated talairach pons position (5.51, 5.66, 111.03)
# find_cutting_plane:seed point not in structure! Searching neighborhood...
# Looking for area (min, max) = (350, 790)
# area[0] = 604 (min = 350, max = 790), aspect = 0.79 (min = 0.60, max = 1.20)
# no need to search
# using seed (124, 148, 129), TAL = (5.5, 5.7, 111.0)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# done.
# seed_search_size = 9, min_neighbors = 5
# search rh wm seed point around talairach space:(20.51, 5.66, 145.03) SRC: (109.00, 114.00, 129.00)
# search lh wm seed point around talairach space (-15.49, 5.66, 145.03), SRC: (145.00, 114.00, 129.00)
# filling left hemisphere...
# filling volume: pass 3 of 3...total of 138499 voxels filled...done.
# filling right hemisphere...
# filling volume: pass 3 of 3...total of 138474 voxels filled...done.
# filling degenerate left hemisphere surface locations...
# 72 voxels filled
# 0 voxels filled
# filling degenerate right hemisphere surface locations...
# 97 voxels filled
# 0 voxels filled
# refilling left hemisphere...
# filling volume: pass 3 of 3...total of 138571 voxels filled...done.
# refilling right hemisphere...
# filling volume: pass 3 of 3...total of 138571 voxels filled...done.
# combining hemispheres...
# writing output to /Users/chris/Desktop/FS_ALT/Danny/fs/WM_filled.mgz...
# filling took 0.2 minutes
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (yz-):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 1 (out of 138573: 0.000722)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1664 vertices, 1764 faces
# slice 70: 5782 vertices, 5946 faces
# slice 80: 11010 vertices, 11156 faces
# slice 90: 16126 vertices, 16336 faces
# slice 100: 22312 vertices, 22505 faces
# slice 110: 29534 vertices, 29811 faces
# slice 120: 37774 vertices, 38058 faces
# slice 130: 45734 vertices, 46007 faces
# slice 140: 52782 vertices, 53025 faces
# slice 150: 59099 vertices, 59327 faces
# slice 160: 64648 vertices, 64812 faces
# slice 170: 69271 vertices, 69420 faces
# slice 180: 72407 vertices, 72502 faces
# slice 190: 74376 vertices, 74433 faces
# slice 200: 75390 vertices, 75412 faces
# slice 210: 75586 vertices, 75586 faces
# slice 220: 75586 vertices, 75586 faces
# slice 230: 75586 vertices, 75586 faces
# slice 240: 75586 vertices, 75586 faces
# slice 250: 75586 vertices, 75586 faces
# using the conformed surface RAS to save vertex points...
# writing /Users/chris/Desktop/FS_ALT/Danny/fs/lh.orig.nofix
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (xz-):   0 found -   1 modified     |    TOTAL:   1
# Iteration Number : 1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (yz+):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 2 (out of 138574: 0.001443)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1107 vertices, 1174 faces
# slice 70: 4878 vertices, 5030 faces
# slice 80: 10053 vertices, 10217 faces
# slice 90: 15044 vertices, 15263 faces
# slice 100: 21358 vertices, 21567 faces
# slice 110: 28455 vertices, 28740 faces
# slice 120: 36811 vertices, 37118 faces
# slice 130: 44940 vertices, 45213 faces
# slice 140: 52322 vertices, 52571 faces
# slice 150: 58821 vertices, 59053 faces
# slice 160: 64807 vertices, 64964 faces
# slice 170: 69533 vertices, 69693 faces
# slice 180: 73000 vertices, 73100 faces
# slice 190: 75128 vertices, 75200 faces
# slice 200: 76461 vertices, 76491 faces
# slice 210: 76798 vertices, 76798 faces
# slice 220: 76798 vertices, 76798 faces
# slice 230: 76798 vertices, 76798 faces
# slice 240: 76798 vertices, 76798 faces
# slice 250: 76798 vertices, 76798 faces
# using the conformed surface RAS to save vertex points...
# writing /Users/chris/Desktop/FS_ALT/Danny/fs/rh.orig.nofix
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
#
# counting number of connected components...
#    75586 voxel in cpt #1: X=0 [v=75586,e=226758,f=151172] located at (-22.935795, -8.424312, 6.791482)
# For the whole surface: X=0 [v=75586,e=226758,f=151172]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /Users/chris/Desktop/FS_ALT/Danny/fs/lh.smoothwm.nofix
# avg radius = 39.2 mm, total surface area = 44269 mm^2
# step 060: RMS=0.028 (target=0.015)
# inflation complete.
# writing inflated surface to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.inflated.nofix
# writing sulcal depths to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.sulc
# mris_inflate utimesec    10.897507
# mris_inflate stimesec    0.082320
# mris_inflate ru_maxrss   106242048
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   25711
# mris_inflate ru_majflt   411
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    5
# mris_inflate ru_nivcsw   5270
# inflation took 0.2 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.359...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.556, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.300, avgs=0
# 010/300: dt: 0.9000, rms radial error=177.750, avgs=0
# 015/300: dt: 0.9000, rms radial error=177.028, avgs=0
# 020/300: dt: 0.9000, rms radial error=176.204, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.323, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.409, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.479, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.540, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.598, avgs=0
# 050/300: dt: 0.9000, rms radial error=170.653, avgs=0
# 055/300: dt: 0.9000, rms radial error=169.710, avgs=0
# 060/300: dt: 0.9000, rms radial error=168.770, avgs=0
# 065/300: dt: 0.9000, rms radial error=167.833, avgs=0
# 070/300: dt: 0.9000, rms radial error=166.900, avgs=0
# 075/300: dt: 0.9000, rms radial error=165.971, avgs=0
# 080/300: dt: 0.9000, rms radial error=165.046, avgs=0
# 085/300: dt: 0.9000, rms radial error=164.126, avgs=0
# 090/300: dt: 0.9000, rms radial error=163.210, avgs=0
# 095/300: dt: 0.9000, rms radial error=162.299, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.392, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.490, avgs=0
# 110/300: dt: 0.9000, rms radial error=159.592, avgs=0
# 115/300: dt: 0.9000, rms radial error=158.699, avgs=0
# 120/300: dt: 0.9000, rms radial error=157.811, avgs=0
# 125/300: dt: 0.9000, rms radial error=156.927, avgs=0
# 130/300: dt: 0.9000, rms radial error=156.047, avgs=0
# 135/300: dt: 0.9000, rms radial error=155.173, avgs=0
# 140/300: dt: 0.9000, rms radial error=154.302, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.437, avgs=0
# 150/300: dt: 0.9000, rms radial error=152.576, avgs=0
# 155/300: dt: 0.9000, rms radial error=151.719, avgs=0
# 160/300: dt: 0.9000, rms radial error=150.867, avgs=0
# 165/300: dt: 0.9000, rms radial error=150.020, avgs=0
# 170/300: dt: 0.9000, rms radial error=149.177, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.339, avgs=0
# 180/300: dt: 0.9000, rms radial error=147.505, avgs=0
# 185/300: dt: 0.9000, rms radial error=146.676, avgs=0
# 190/300: dt: 0.9000, rms radial error=145.851, avgs=0
# 195/300: dt: 0.9000, rms radial error=145.031, avgs=0
# 200/300: dt: 0.9000, rms radial error=144.216, avgs=0
# 205/300: dt: 0.9000, rms radial error=143.404, avgs=0
# 210/300: dt: 0.9000, rms radial error=142.598, avgs=0
# 215/300: dt: 0.9000, rms radial error=141.795, avgs=0
# 220/300: dt: 0.9000, rms radial error=140.998, avgs=0
# 225/300: dt: 0.9000, rms radial error=140.204, avgs=0
# 230/300: dt: 0.9000, rms radial error=139.415, avgs=0
# 235/300: dt: 0.9000, rms radial error=138.630, avgs=0
# 240/300: dt: 0.9000, rms radial error=137.850, avgs=0
# 245/300: dt: 0.9000, rms radial error=137.074, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.302, avgs=0
# 255/300: dt: 0.9000, rms radial error=135.535, avgs=0
# 260/300: dt: 0.9000, rms radial error=134.771, avgs=0
# 265/300: dt: 0.9000, rms radial error=134.012, avgs=0
# 270/300: dt: 0.9000, rms radial error=133.258, avgs=0
# 275/300: dt: 0.9000, rms radial error=132.507, avgs=0
# 280/300: dt: 0.9000, rms radial error=131.761, avgs=0
# 285/300: dt: 0.9000, rms radial error=131.018, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.280, avgs=0
# 295/300: dt: 0.9000, rms radial error=129.546, avgs=0
# 300/300: dt: 0.9000, rms radial error=128.816, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.35 +- 0.72 (0.00-->8.02) (max @ vno 23348 --> 24051)
# face area 0.04 +- 0.04 (-0.01-->0.78)
# epoch 1 (K=10.0), pass 1, starting sse = 8124.63
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00022
# epoch 2 (K=40.0), pass 1, starting sse = 1124.16
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00040
# epoch 3 (K=160.0), pass 1, starting sse = 93.74
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.20/14 = 0.01424
# epoch 4 (K=640.0), pass 1, starting sse = 4.11
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.38/20 = 0.01894
# final distance error %24.47
# writing spherical brain to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.qsphere.nofix
# mris_sphere utimesec    83.382307
# mris_sphere stimesec    0.275697
# mris_sphere ru_maxrss   106688512
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   25824
# mris_sphere ru_majflt   400
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    3
# mris_sphere ru_nivcsw   44218
# spherical transformation took 0.02 hours
# FSRUNTIME@ mris_sphere  0.0233 hours 1 threads
# euler # = v-e+f = 2g-2: 75586 - 226758 + 151172 = 0 --> 1 holes
#       F =2V-4:          151172 != 151172-4 (-4)
#       2E=3F:            453516 = 453516 (0)
#
# total defect index = 2
# removing intersecting faces
# writing corrected surface to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /Users/chris/Desktop/FS_ALT/Danny/fs/lh.smoothwm
# avg radius = 39.2 mm, total surface area = 44269 mm^2
# step 060: RMS=0.028 (target=0.015)
# inflation complete.
# writing inflated surface to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.inflated
# writing sulcal depths to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.sulc
# mris_inflate utimesec    10.633625
# mris_inflate stimesec    0.072971
# mris_inflate ru_maxrss   104132608
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   25857
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    0
# mris_inflate ru_nivcsw   4984
# inflation took 0.2 minutes
# thresholding curvature at 99.90% level
# normalizing curvature values.
# averaging curvature patterns 5 times.
# sampling 10 neighbors out to a distance of 10 mm
# 63 vertices thresholded to be in k1 ~ [-2.01 1.32], k2 ~ [-0.38 0.38]
# total integrated curvature = 0.525*4pi (6.603) --> 0 handles
# ICI = 1.5, FI = 9.2, variation=157.166
# 78 vertices thresholded to be in [-0.49 0.06]
# writing Gaussian curvature to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.inflated.K...curvature mean = 0.000, std = 0.009
# 48 vertices thresholded to be in [-0.73 0.41]
# curvature mean = -0.022, std = 0.034
# done.
# writing mean curvature to /Users/chris/Desktop/FS_ALT/Danny/fs/lh.inflated.H...done.
#
# counting number of connected components...
#    76798 voxel in cpt #1: X=0 [v=76798,e=230394,f=153596] located at (26.301296, -6.361455, 7.694393)
# For the whole surface: X=0 [v=76798,e=230394,f=153596]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /Users/chris/Desktop/FS_ALT/Danny/fs/rh.smoothwm.nofix
# avg radius = 39.1 mm, total surface area = 45063 mm^2
# step 060: RMS=0.031 (target=0.015)
# inflation complete.
# writing inflated surface to /Users/chris/Desktop/FS_ALT/Danny/fs/rh.inflated.nofix
# writing sulcal depths to /Users/chris/Desktop/FS_ALT/Danny/fs/rh.sulc
# mris_inflate utimesec    10.233589
# mris_inflate stimesec    0.052122
# mris_inflate ru_maxrss   110723072
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   27212
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    2
# mris_inflate ru_nivcsw   619
# inflation took 0.2 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.357...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.591, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.334, avgs=0
# 010/300: dt: 0.9000, rms radial error=177.784, avgs=0
# 015/300: dt: 0.9000, rms radial error=177.061, avgs=0
# 020/300: dt: 0.9000, rms radial error=176.238, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.357, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.443, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.511, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.570, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.625, avgs=0
# 050/300: dt: 0.9000, rms radial error=170.680, avgs=0
# 055/300: dt: 0.9000, rms radial error=169.738, avgs=0
# 060/300: dt: 0.9000, rms radial error=168.798, avgs=0
# 065/300: dt: 0.9000, rms radial error=167.861, avgs=0
# 070/300: dt: 0.9000, rms radial error=166.929, avgs=0
# 075/300: dt: 0.9000, rms radial error=166.001, avgs=0
# 080/300: dt: 0.9000, rms radial error=165.077, avgs=0
# 085/300: dt: 0.9000, rms radial error=164.157, avgs=0
# 090/300: dt: 0.9000, rms radial error=163.242, avgs=0
# 095/300: dt: 0.9000, rms radial error=162.331, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.425, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.524, avgs=0
# 110/300: dt: 0.9000, rms radial error=159.627, avgs=0
# 115/300: dt: 0.9000, rms radial error=158.734, avgs=0
# 120/300: dt: 0.9000, rms radial error=157.846, avgs=0
# 125/300: dt: 0.9000, rms radial error=156.963, avgs=0
# 130/300: dt: 0.9000, rms radial error=156.085, avgs=0
# 135/300: dt: 0.9000, rms radial error=155.210, avgs=0
# 140/300: dt: 0.9000, rms radial error=154.341, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.476, avgs=0
# 150/300: dt: 0.9000, rms radial error=152.616, avgs=0
# 155/300: dt: 0.9000, rms radial error=151.760, avgs=0
# 160/300: dt: 0.9000, rms radial error=150.908, avgs=0
# 165/300: dt: 0.9000, rms radial error=150.062, avgs=0
# 170/300: dt: 0.9000, rms radial error=149.219, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.381, avgs=0
# 180/300: dt: 0.9000, rms radial error=147.548, avgs=0
# 185/300: dt: 0.9000, rms radial error=146.719, avgs=0
# 190/300: dt: 0.9000, rms radial error=145.895, avgs=0
# 195/300: dt: 0.9000, rms radial error=145.075, avgs=0
# 200/300: dt: 0.9000, rms radial error=144.260, avgs=0
# 205/300: dt: 0.9000, rms radial error=143.449, avgs=0
# 210/300: dt: 0.9000, rms radial error=142.642, avgs=0
# 215/300: dt: 0.9000, rms radial error=141.840, avgs=0
# 220/300: dt: 0.9000, rms radial error=141.042, avgs=0
# 225/300: dt: 0.9000, rms radial error=140.249, avgs=0
# 230/300: dt: 0.9000, rms radial error=139.460, avgs=0
# 235/300: dt: 0.9000, rms radial error=138.675, avgs=0
# 240/300: dt: 0.9000, rms radial error=137.895, avgs=0
# 245/300: dt: 0.9000, rms radial error=137.119, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.348, avgs=0
# 255/300: dt: 0.9000, rms radial error=135.580, avgs=0
# 260/300: dt: 0.9000, rms radial error=134.817, avgs=0
# 265/300: dt: 0.9000, rms radial error=134.058, avgs=0
# 270/300: dt: 0.9000, rms radial error=133.304, avgs=0
# 275/300: dt: 0.9000, rms radial error=132.553, avgs=0
# 280/300: dt: 0.9000, rms radial error=131.807, avgs=0
# 285/300: dt: 0.9000, rms radial error=131.065, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.327, avgs=0
# 295/300: dt: 0.9000, rms radial error=129.593, avgs=0
# 300/300: dt: 0.9000, rms radial error=128.863, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.34 +- 0.72 (0.00-->6.26) (max @ vno 40509 --> 41345)
# face area 0.04 +- 0.04 (-0.00-->0.55)
# epoch 1 (K=10.0), pass 1, starting sse = 8267.31
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00032
# epoch 2 (K=40.0), pass 1, starting sse = 1143.01
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00038
# epoch 3 (K=160.0), pass 1, starting sse = 95.01
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.19/14 = 0.01351
# epoch 4 (K=640.0), pass 1, starting sse = 3.87
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.46/20 = 0.02293
# final distance error %24.43
# writing spherical brain to /Users/chris/Desktop/FS_ALT/Danny/fs/rh.qsphere.nofix
# mris_sphere utimesec    82.509118
# mris_sphere stimesec    0.214944
# mris_sphere ru_maxrss   108294144
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   26620
# mris_sphere ru_majflt   0
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1
# mris_sphere ru_nivcsw   30971
# spherical transformation took 0.02 hours
# FSRUNTIME@ mris_sphere  0.0230 hours 1 threads
# euler # = v-e+f = 2g-2: 76798 - 230394 + 153596 = 0 --> 1 holes
#       F =2V-4:          153596 != 153596-4 (-4)
#       2E=3F:            460788 = 460788 (0)
#
# total defect index = 2
# removing intersecting faces
# writing corrected surface to /Users/chris/Desktop/FS_ALT/Danny/fs/rh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /Users/chris/Desktop/FS_ALT/Danny/fs/rh.smoothwm
# avg radius = 39.1 mm, total surface area = 45063 mm^2
# step 060: RMS=0.031 (target=0.015)
# inflation complete.
# writing inflated surface to /Users/chris/Desktop/FS_ALT/Danny/fs/rh.inflated
# writing sulcal depths to /Users/chris/Desktop/FS_ALT/Danny/fs/rh.sulc
# mris_inflate utimesec    11.055562
# mris_inflate stimesec    0.077402
# mris_inflate ru_maxrss   108261376
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   26545
# mris_inflate ru_majflt   71
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    0
# mris_inflate ru_nivcsw   5968
# inflation took 0.2 minutes
# thresholding curvature at 99.90% level
# normalizing curvature values.
# averaging curvature patterns 5 times.
# sampling 10 neighbors out to a distance of 10 mm
# 60 vertices thresholded to be in k1 ~ [-1.65 2.16], k2 ~ [-0.39 0.27]
# total integrated curvature = 0.535*4pi (6.729) --> 0 handles
# ICI = 1.5, FI = 9.5, variation=162.902
# 53 vertices thresholded to be in [-0.21 0.12]
# writing Gaussian curvature to /Users/chris/Desktop/FS_ALT/Danny/fs/rh.inflated.K...curvature mean = 0.000, std = 0.006
# 41 vertices thresholded to be in [-0.54 0.61]
# curvature mean = -0.022, std = 0.034
# done.
# writing mean curvature to /Users/chris/Desktop/FS_ALT/Danny/fs/rh.inflated.H...done.
# TESSELATION DONE!

# %% [markdown]
# ### Next steps
