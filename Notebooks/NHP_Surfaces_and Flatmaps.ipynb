# %% [markdown]
# # **Create Single Monkey Surfaces**

# %% [markdown]
# This notebook will guide you through the procedure to create single monkey surface representations in four steps (some are optional):
#
# 1. **(OPTIONAL)** Average multiple T1 scans from the same animal. (takes seconds)
# 2. Segment the (averaged) T1 of an individual animal using the NMT template as a prior. (takes many hours)
# 3. Create surfaces and flatmaps using Freesurfer. (takes up to to several hours depending on segmentation quality at the start)
# 4. **(OPTIONAL)** Create additional surfaces with Connectome Workbench. (takes minutes)

# %% [markdown]
# ## Initiate
# Setting a few environment variables here so we can actually run code from this notebook

# %%
SUBJ=Eddy  # Name of the animal you are going to process
NMT_path=/NHP_MRI/Template/NMT # path to the template folder
startpath=pwd # current directory
# Out:
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.white
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.white

# %% [markdown]
# ----
# ----
# ## **Step 1 (OPTIONAL): Average multiple T1 scans**
#
# ----
# ----
#
# ### Requirements:
# - Freesurfer installation (https://surfer.nmr.mgh.harvard.edu/)
# - NIH Macaque Template (https://github.com/jms290/NMT)
# - One or more high resolution anatomical scans
#
# - The `average_multiple_t1.sh ` script
#
# ### Procedure
# - Create a folder for your subject in the NIH Macaque Template folder as
#
# `<>/NHP_MRI/Template/NMT/single_subject_scans/<SUBJECT>`
#
# - Inside this folder, create a subfolder with all individual T1 scan for this subject, e.g.
#
# `<>/NHP_MRI/Template/NMT/single_subject_scans/<SUBJECT>/<T1_FLD>/*.nii.gz`
#
# - Copy the script `average_multiple_t1.sh` to the `<SUBJECT>` folder as well.
#
# - Run this script with the name of the `<T1_FLD>` as input:
#
# `$ ./average_multiple_t1.sh <T1_FLD>`
#
#
# - The script will:
#
#     - Correct for having the monkey in the sphinx position
#     - Resample each T1 to 0.5 mm isotropic voxels
#     - Reorient the colume for correct display in FSL (e.g., with FSLEyes)
#     - Normalize the contrast gradient
#     - Average the multiple T1's together using motion correction to account for small differences
#
#
# - When the script is done, there should be a `<SUBJECT>.nii.gz` file in the root `<SUBJECT>` folder.

# %%
# Get path and make folders
NMT_ss_path=${NMT_path}/single_subject_scans/${SUBJ}
mkdir -p ${NMT_ss_path}
mkdir -p ${NMT_path}/single_subject_scans/${SUBJ}/T1s
echo Copy the T1 files to ${NMT_path}/single_subject_scans/${SUBJ}/T1s
# Out:
# Copy the T1 files to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s

# %%
# Copy averaging script
cp ${NMT_path}/single_subject_scans/average_multiple_t1.sh \
    ${NMT_path}/single_subject_scans/${SUBJ}/
cd ${NMT_path}/single_subject_scans/${SUBJ}/
# Run script
./average_multiple_t1.sh T1s
# Out:
# mri_convert.bin -i sub-eddy_ses-20170516_acq-nosense_scan-20_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170516_acq-nosense_scan-20_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170516_acq-nosense_scan-20_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170607_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170607_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170607_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170516_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170516_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170614_acq-sense_run-10_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170614_acq-sense_run-10_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170517_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170517_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170614_acq-sense_run-10_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170517_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170516_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20171220_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20171220_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20171220_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170516_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170516_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20171116_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20171116_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170518_acq-nosense_scan-16_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170518_acq-nosense_scan-16_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170720_acq-nosense_run-9_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170720_acq-nosense_run-9_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170516_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20171116_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20171116_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20171116_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170518_acq-nosense_scan-16_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20171116_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170720_acq-nosense_run-9_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20180125_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180125_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20180131_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180131_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180131_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170607_acq-nosense_run-13_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170607_acq-nosense_run-13_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170517_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170517_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20180117_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180117_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170517_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170607_acq-nosense_run-13_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180117_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170516_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170516_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170516_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20180201_acq-nosense_run-18_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180201_acq-nosense_run-18_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-24_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-24_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20180201_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180201_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-24_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20180228_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180228_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180228_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180125_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# mri_convert.bin -i sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-25_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-25_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# reading from sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-10_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-10_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20171129_acq-nosense_scan-09_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20171129_acq-nosense_scan-09_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-25_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180201_acq-nosense_run-18_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180201_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-10_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20171129_acq-nosense_scan-09_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170614_acq-sense_run-15_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170614_acq-sense_run-15_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-23_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-23_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-23_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170614_acq-sense_run-15_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20170512_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170512_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# mri_convert.bin -i sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170512_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz...
# mri_convert.bin -i sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz -o rs_sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz --sphinx -vs 0.5 0.5 0.5
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz...
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=8.02, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -4.20545e-05, 0)
# j_ras = (4.20545e-05, 1, 0)
# k_ras = (0, 0, 1)
# Reslicing using trilinear interpolation
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180117_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20171220_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170720_acq-nosense_run-9_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170517_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170607_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20171116_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180131_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170516_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180228_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180125_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180201_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170614_acq-sense_run-10_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170516_acq-nosense_scan-20_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-23_T1w_res-06x06x06_preproc.nii.gz...
# writing to rs_sub-eddy_ses-20180201_acq-nosense_run-18_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170517_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz...
# writing to rs_sub-eddy_ses-20170516_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz...
# writing to rs_sub-eddy_ses-20170607_acq-nosense_run-13_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-25_T1w_res-06x06x06_preproc.nii.gz...
# writing to rs_sub-eddy_ses-20170516_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20171116_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-24_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170512_acq-nosense_scan-10_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20171129_acq-nosense_scan-09_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170614_acq-sense_run-15_T1w_res-06x06x06_preproc.nii.gz...
# Changing orientation information to Sphinx
# writing to rs_sub-eddy_ses-20170518_acq-nosense_scan-16_T1w_res-06x06x06_preproc.nii.gz...
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# --i rs_sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# Thu Mar  7 19:40:02 CET 2019
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# /usr/bin/bc
# tmpdir is ./output/tmp.mri_nu_correct.mni.8723
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# mri_convert rs_sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8723/nu0.mnc -odt float
# mri_convert.bin rs_sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8723/nu0.mnc -odt float
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from rs_sub-eddy_ses-20170516_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz...
# TR=12.90, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# writing to ./output/tmp.mri_nu_correct.mni.8723/nu0.mnc...
#
# --------------------------------------------------------
# Iteration 1 Thu Mar  7 19:40:06 CET 2019
# nu_correct -clobber ./output/tmp.mri_nu_correct.mni.8723/nu0.mnc ./output/tmp.mri_nu_correct.mni.8723/nu1.mnc -tmpdir ./output/tmp.mri_nu_correct.mni.8723/0/ -distance 24
# [chris@chrisklink-linux:/media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s/] [2019-03-07 19:40:07] running:
#   /media/DATA1/NHP_MRI/freesurfer/mni/bin/nu_estimate_np_and_em -parzen -log -sharpen 0.15 0.01 -iterations 50 -stop 0.001 -shrink 4 -auto_mask -nonotify -b_spline 1.0e-7 -distance 24 -quiet -execute -clobber -nokeeptmp -tmpdir ./output/tmp.mri_nu_correct.mni.8723/0/ ./output/tmp.mri_nu_correct.mni.8723/nu0.mnc ./output/tmp.mri_nu_correct.mni.8723/nu1.imp
#
# mv: cannot move './output/mri_nu_correct.mni.log' to './output/mri_nu_correct.mni.log.bak': No such file or directory
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# --i rs_sub-eddy_ses-20170512_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz --distance 24
# --i rs_sub-eddy_ses-20170512_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# nIters 1
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# Thu Mar  7 19:40:07 CET 2019
# Thu Mar  7 19:40:08 CET 2019
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# /usr/bin/bc
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# tmpdir is ./output/tmp.mri_nu_correct.mni.8777
# --i rs_sub-eddy_ses-20171220_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20171220_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# mri_convert rs_sub-eddy_ses-20170512_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8777/nu0.mnc -odt float
# nIters 1
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# /usr/bin/bc
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# tmpdir is ./output/tmp.mri_nu_correct.mni.8783
# mri_convert.bin rs_sub-eddy_ses-20170512_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8777/nu0.mnc -odt float
# Thu Mar  7 19:40:08 CET 2019
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# mri_convert rs_sub-eddy_ses-20170512_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8783/nu0.mnc -odt float
# mri_convert.bin rs_sub-eddy_ses-20170512_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8783/nu0.mnc -odt float
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# /usr/bin/bc
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# tmpdir is ./output/tmp.mri_nu_correct.mni.8827
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# --i rs_sub-eddy_ses-20170516_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170516_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# nIters 1
# mri_convert rs_sub-eddy_ses-20171220_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8827/nu0.mnc -odt float
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# Processing:..........Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# ..........mri_convert.bin rs_sub-eddy_ses-20171220_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8827/nu0.mnc -odt float
# ..Thu Mar  7 19:40:09 CET 2019
# ........................Done
# mv: cannot stat './output/mri_nu_correct.mni.log': No such file or directory
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# --i rs_sub-eddy_ses-20170607_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170607_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# --i rs_sub-eddy_ses-20170517_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170517_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# --i rs_sub-eddy_ses-20180131_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20180131_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz --distance 24
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# nIters 1
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# Thu Mar  7 19:40:10 CET 2019
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# --i rs_sub-eddy_ses-20180117_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20180117_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz --distance 24
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# Thu Mar  7 19:40:10 CET 2019
# nIters 1
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# Thu Mar  7 19:40:10 CET 2019
# /usr/bin/bc
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# tmpdir is ./output/tmp.mri_nu_correct.mni.8893
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Thu Mar  7 19:40:10 CET 2019
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# mri_convert rs_sub-eddy_ses-20170516_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8893/nu0.mnc -odt float
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /usr/bin/bc
# --i rs_sub-eddy_ses-20170720_acq-nosense_run-9_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170720_acq-nosense_run-9_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# --i rs_sub-eddy_ses-20170607_acq-nosense_run-13_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170607_acq-nosense_run-13_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# --i rs_sub-eddy_ses-20171129_acq-nosense_scan-09_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20171129_acq-nosense_scan-09_T1w_res-06x06x06_preproc.nii.gz --distance 24
# --i rs_sub-eddy_ses-20171116_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20171116_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# mv: cannot stat './output/mri_nu_correct.mni.log': No such file or directory
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# nIters 1
# mri_convert.bin rs_sub-eddy_ses-20170516_acq-nosense_scan-12_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8893/nu0.mnc -odt float
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# tmpdir is ./output/tmp.mri_nu_correct.mni.8921
# nIters 1
# /usr/bin/bc
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /usr/bin/bc
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# --i rs_sub-eddy_ses-20180201_acq-nosense_run-18_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20180201_acq-nosense_run-18_T1w_res-06x06x06_preproc.nii.gz --distance 24
# Program nu_correct, built from:
# Package MNI N3, version 1.12.0, compiled by nicks@terrier (x86_64-unknown-linux-gnu) on 2015-06-19 at 01:25:34
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /usr/bin/bc
# --i rs_sub-eddy_ses-20170512_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# --i rs_sub-eddy_ses-20170516_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170516_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz --distance 24
# Thu Mar  7 19:40:11 CET 2019
# mri_convert rs_sub-eddy_ses-20170607_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8921/nu0.mnc -odt float
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# nIters 1
# Thu Mar  7 19:40:11 CET 2019
# mv: cannot stat './output/mri_nu_correct.mni.log': No such file or directory
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# tmpdir is ./output/tmp.mri_nu_correct.mni.8922
# --i rs_sub-eddy_ses-20180125_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20180125_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# nIters 1
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# --i rs_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --distance 24
# --i rs_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --distance 24
# tmpdir is ./output/tmp.mri_nu_correct.mni.8920
# --i rs_sub-eddy_ses-20170512_acq-nosense_scan-25_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-25_T1w_res-06x06x06_preproc.nii.gz --distance 24
# --i rs_sub-eddy_ses-20180201_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20180201_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz --distance 24
# tmpdir is ./output/tmp.mri_nu_correct.mni.8946
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# nIters 1
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Thu Mar  7 19:40:11 CET 2019
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Thu Mar  7 19:40:11 CET 2019
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# nIters 1
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# mv: './output/mri_nu_correct.mni.log' and './output/mri_nu_correct.mni.log.bak' are the same file
# --i rs_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# nIters 1
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# nIters 1
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# nIters 1
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# mri_convert.bin rs_sub-eddy_ses-20170607_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8921/nu0.mnc -odt float
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# --i rs_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Thu Mar  7 19:40:11 CET 2019
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# mri_convert rs_sub-eddy_ses-20170517_acq-nosense_scan-13_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8922/nu0.mnc -odt float
# --i rs_sub-eddy_ses-20170614_acq-sense_run-10_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170614_acq-sense_run-10_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# --i rs_sub-eddy_ses-20170512_acq-nosense_scan-23_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-23_T1w_res-06x06x06_preproc.nii.gz --distance 24
# mri_convert rs_sub-eddy_ses-20180131_acq-nosense_run-10_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8920/nu0.mnc -odt float
# --i rs_sub-eddy_ses-20170512_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-22_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# mri_convert rs_sub-eddy_ses-20180117_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz ./output/tmp.mri_nu_correct.mni.8946/nu0.mnc -odt float
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# nIters 1
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# --i rs_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# --i rs_sub-eddy_ses-20170512_acq-nosense_scan-10_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-10_T1w_res-06x06x06_preproc.nii.gz --distance 24
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# nIters 1
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/freesurfer/bin/mri_nu_correct.mni
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# Linux chrisklink-linux 4.15.0-46-generic #49-Ubuntu SMP Wed Feb 6 09:33:07 UTC 2019 x86_64 x86_64 x86_64 GNU/Linux
# nIters 1
# /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/T1s
# $Id: mri_nu_correct.mni,v 1.27 2016/02/26 16:19:49 mreuter Exp $
# --i rs_sub-eddy_ses-20170517_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170517_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --distance 24
# --i rs_sub-eddy_ses-20170516_acq-nosense_scan-20_T1w_res-06x06x06_preproc.nii.gz --o ./output/ro_sub-eddy_ses-20170516_acq-nosense_scan-20_T1w_res-06x06x06_preproc.nii.gz --distance 24
# nIters 1
# nIters 1
# Thu Mar  7 19:40:11 CET 2019
# ...
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170614_acq-sense_run-15_T1w_res-06x06x06_preproc.nii.gz...
#
# Thu Mar  7 19:45:35 CET 2019
# mri_nu_correct.mni done
#
#
# Thu Mar  7 19:45:35 CET 2019
# mri_nu_correct.mni done
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9164/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170512_acq-nosense_scan-24_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-24_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9478/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20180228_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20180228_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz...
#
#
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9005/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20171116_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20171116_acq-nosense_scan-04_T1w_res-06x06x06_preproc.nii.gz...
#                        [ ok ]
# Thu Mar  7 19:45:35 CET 2019
# mri_nu_correct.mni done
#
# mri_convert ./output/tmp.mri_nu_correct.mni.9178/nu1.mnc ./output/ro_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --conform
#
#
# Thu Mar  7 19:45:35 CET 2019
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9299/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170518_acq-nosense_scan-16_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170518_acq-nosense_scan-16_T1w_res-06x06x06_preproc.nii.gz...
#
# mri_nu_correct.mni done
# Thu Mar  7 19:45:35 CET 2019
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9178/nu1.mnc ./output/ro_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_nu_correct.mni done
#
#
# Thu Mar  7 19:45:35 CET 2019
# mri_nu_correct.mni done
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9072/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170512_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170512_acq-nosense_scan-21_T1w_res-06x06x06_preproc.nii.gz...
#
#
# Thu Mar  7 19:45:36 CET 2019
# mri_nu_correct.mni done
#                        [ ok ]
# mri_convert ./output/tmp.mri_nu_correct.mni.9188/nu1.mnc ./output/ro_sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz --conform
#                        [ ok ]
#                        [ ok ]
# mri_convert ./output/tmp.mri_nu_correct.mni.9118/nu1.mnc ./output/ro_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert ./output/tmp.mri_nu_correct.mni.9225/nu1.mnc ./output/ro_sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9188/nu1.mnc ./output/ro_sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz --conform
#                        [ ok ]
# mri_convert ./output/tmp.mri_nu_correct.mni.9179/nu1.mnc ./output/ro_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9118/nu1.mnc ./output/ro_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz --conform
#                        [ ok ]
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9225/nu1.mnc ./output/ro_sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz --conform
#                        [ ok ]
# mri_convert ./output/tmp.mri_nu_correct.mni.9204/nu1.mnc ./output/ro_sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert ./output/tmp.mri_nu_correct.mni.9099/nu1.mnc ./output/ro_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9179/nu1.mnc ./output/ro_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz --conform
#                        [ ok ]
#                        [ ok ]
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9204/nu1.mnc ./output/ro_sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert ./output/tmp.mri_nu_correct.mni.9202/nu1.mnc ./output/ro_sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert ./output/tmp.mri_nu_correct.mni.9213/nu1.mnc ./output/ro_sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --conform
#                        [ ok ]
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9099/nu1.mnc ./output/ro_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz --conform
#                        [ ok ]
# mri_convert ./output/tmp.mri_nu_correct.mni.9411/nu1.mnc ./output/ro_sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert ./output/tmp.mri_nu_correct.mni.9095/nu1.mnc ./output/ro_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9202/nu1.mnc ./output/ro_sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9213/nu1.mnc ./output/ro_sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9095/nu1.mnc ./output/ro_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz --conform
# mri_convert.bin ./output/tmp.mri_nu_correct.mni.9411/nu1.mnc ./output/ro_sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz --like rs_sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz --conform
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9178/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170621_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz...
#
#
# Thu Mar  7 19:45:38 CET 2019
# mri_nu_correct.mni done
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9202/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170607_acq-nosense_run-07_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9188/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170516_acq-nosense_scan-15_T1w_res-06x06x06_preproc.nii.gz...
#
#
#
# Thu Mar  7 19:45:38 CET 2019
#
# mri_nu_correct.mni done
# Thu Mar  7 19:45:38 CET 2019
# mri_nu_correct.mni done
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9225/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170525_acq-sense_run-09_T1w_res-06x06x06_preproc.nii.gz...
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9118/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20180222_acq-nosense_run-09_T1w_res-06x06x06_preproc.nii.gz...
#
#
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9179/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170621_acq-sense_run-17_T1w_res-06x06x06_preproc.nii.gz...
#
#
# Thu Mar  7 19:45:39 CET 2019
# Thu Mar  7 19:45:39 CET 2019
#
# mri_nu_correct.mni done
# mri_nu_correct.mni done
#
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9099/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20171220_acq-nosense_run-03_T1w_res-06x06x06_preproc.nii.gz...
# Thu Mar  7 19:45:39 CET 2019
# mri_nu_correct.mni done
#
#
# Thu Mar  7 19:45:39 CET 2019
# mri_nu_correct.mni done
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9204/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20180222_acq-nosense_run-17_T1w_res-06x06x06_preproc.nii.gz...
#
#
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9411/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20180125_acq-nosense_run-11_T1w_res-06x06x06_preproc.nii.gz...
# Thu Mar  7 19:45:39 CET 2019
# mri_nu_correct.mni done
#
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9095/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20180228_acq-nosense_scan-11_T1w_res-06x06x06_preproc.nii.gz...
#
# Thu Mar  7 19:45:39 CET 2019
# mri_nu_correct.mni done
#
#
# Thu Mar  7 19:45:39 CET 2019
# mri_nu_correct.mni done
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from ./output/tmp.mri_nu_correct.mni.9213/nu1.mnc...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, 0, 4.20545e-05)
# j_ras = (0, 1, 0)
# k_ras = (-4.20545e-05, 0, 1)
# INFO: transform src into the like-volume: rs_sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# writing to ./output/ro_sub-eddy_ses-20170525_acq-sense_run-12_T1w_res-06x06x06_preproc.nii.gz...
#
#
# Thu Mar  7 19:45:39 CET 2019
# mri_nu_correct.mni done
# ./average_multiple_t1.sh: line 27: -o: command not found
# [1]+  Done                    freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated  (wd: ~/Documents/MRI_ANALYSIS/NHP-Freesurfer/Notebooks)
# (wd now: /NHP_MRI/Template/NMT/single_subject_scans/Eddy)
# : 127

# %% [markdown]
# ----
# ----
# ## **Step 2: Segment the single subject anatomy using the NMT template as a prior**
#
# ----
# ----
#
# ### Requirements
#   - NIH Macaque Template (https://github.com/jms290/NMT)
#   - ANTS (http://stnava.github.io/ANTs/)
#   - AFNI (https://afni.nimh.nih.gov/)
#
# ### Procedure
# This will segment and process the single-subject anatomical and warp the D99 atlas (https://afni.nimh.nih.gov/Macaque) to your individual anatomy.
#
# - Navigate to `<>/NHP_MRI/Template/NMT/single_subject_scans` in your terminal
#
# - There should be a folder `<SUBJECT>` containing a T1 named `<SUBJECT>.nii.gz` (Step 1 produces this)
#
# - Run the `align_and_process_singlesubject.sh` script with input `<SUBJECT>`:
#
# - The following 2 steps can be executed together by running: `$ ./create_ss_atlas.sh <SUBJECT>`
#
#     - Extracting single ROI masks from the warped atlas: `./extract_ROI.sh <SUBJECT>`
#
#     - Creating a label-file that makes the warped atlas usable in FSLEyes: `./create_xml.sh <SUBJECT>`

# %%
# Go to the single subject folder in NMT
cd ${NMT_path}/single_subject_scans
# Run script to align and segment. This will take a long time (~8-10 hours)
./align_and_process_singlesubject.sh ${SUBJ}
# Out:
# Aligning and processing single subject scans using the NIMH Macaque Template:
# 1) Changing your current directory
# 2) Aligning Single Subject Scan to the NIMH Macaque Template and align the D99 atlas to your single subject scan
# ++ 3dAFNItoNIFTI: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ../../atlases/D99_atlas/D99_atlas_1.2a_al2NMT.nii.gz
# ++ 3dcopy: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset ./Eddy_shft.nii.gz
#  + deoblique
#  + loading and re-writing dataset ./Eddy_shft.nii.gz (./Eddy_shft.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# ../../NMT.nii.gz
# #++ align_epi_anat version: 1.58
# #++ turning off tshift, volume registration, resampling
# #++ turning off tshift, volume registration, resampling
# #Script is running (command trimmed):
#   3dAttribute DELTA ./Eddy_shft.nii.gz
# #Script is running (command trimmed):
#   3dAttribute DELTA ./Eddy_shft.nii.gz
# #Script is running:
#   3dAttribute DELTA /media/DATA1/NHP_MRI/Template/NMT/NMT.nii.gz
# #++ Multi-cost is lpa
# #++ Removing all the temporary files
# #Script is running:
#   \rm -f ./__tt_Eddy_shft*
# #Script is running:
#   \rm -f ./__tt_NMT*
# #Script is running (command trimmed):
#   3dcopy /media/DATA1/NHP_MRI/Template/NMT/NMT.nii.gz ./__tt_NMT+orig
# ++ 3dcopy: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# #Script is running (command trimmed):
#   3dinfo ./__tt_NMT+orig | \grep 'Data Axes Tilt:'|\grep 'Oblique'
# #++ Dataset /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/__tt_NMT+orig is not oblique
# #Script is running (command trimmed):
#   3dinfo ./Eddy_shft.nii.gz | \grep 'Data Axes Tilt:'|\grep 'Oblique'
# #++ Dataset /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/Eddy_shft.nii.gz is not oblique
# #++ Copying NIFTI EPI input to AFNI format
# #Script is running (command trimmed):
#   3dcopy ./Eddy_shft.nii.gz ./__tt_Eddy_shft+orig
# ++ 3dcopy: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# #++ using 0th sub-brick because only one found
# #Script is running (command trimmed):
#   3dbucket -prefix ./__tt_Eddy_shft_ts ./__tt_Eddy_shft+orig'[0]'
# ++ 3dbucket: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# #++ removing skull or area outside brain
# #++ Computing weight mask
# #Script is running (command trimmed):
#   3dBrickStat -automask -percentile 90.000000 1 90.000000 ./__tt_Eddy_shft_ts+orig
# #++ Applying threshold of 142.470123 on /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/__tt_Eddy_shft_ts+orig
# #Script is running (command trimmed):
#   3dcalc -datum float -prefix ./__tt_Eddy_shft_ts_wt -a ./__tt_Eddy_shft_ts+orig -expr 'min(1,(a/142.470123))'
# ++ 3dcalc: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: A cast of thousands
# #++ Aligning dset1 data to dset2 data
# #Script is running (command trimmed):
#   3dAllineate -lpa -wtprefix ./__tt_NMT_al2std_wtal -weight ./__tt_Eddy_shft_ts_wt+orig -source ./__tt_NMT+orig -prefix ./__tt_NMT_al2std -base ./__tt_Eddy_shft_ts+orig -cmass -1Dmatrix_save ./NMT_al2std_mat.aff12.1D -master BASE -mast_dxyz 0.250000 -weight_frac 1.0 -maxrot 6 -maxshf 10 -VERB -warp aff -source_automask+4 -twobest 11 -twopass -VERB -maxrot 45 -maxshf 40 -fineblur 1 -source_automask+2
# ++ 3dAllineate: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: Zhark the Registrator
# *+ WARNING: Small value 0.25 after -mast_dxyz :-(
# ++ Source dataset: ./__tt_NMT+orig.HEAD
# ++ Base dataset:   ./__tt_Eddy_shft_ts+orig.HEAD
# ++ Loading datasets
# ++ 14438047 voxels in -source_automask+2
# ++ Zero-pad: xbot=0 xtop=3
# ++ Zero-pad: ybot=4 ytop=4
# ++ Zero-pad: zbot=4 ztop=2
# ++ 3806835 voxels [86.7%] in weight mask
# ++ Number of points for matching = 3806835
# ++ Local correlation: blok type = 'RHDD(6.54321)'
# ++ base center of mass = 89.429 55.099 84.812 (index)
#  + source center of mass = 125.794 171.701 111.432 (index)
#  + source-target CM = 0.016 -4.126 1.702 (xyz)
#  + center of mass shifts = 0.016 -4.126 1.702
# ++ shift param auto-range: -29.2..29.2 -24.7..16.4 -28.0..31.4
#  + Range param#4 [z-angle] = -6.000000 .. 6.000000
#  + Range param#5 [x-angle] = -6.000000 .. 6.000000
#  + Range param#6 [y-angle] = -6.000000 .. 6.000000
#  + Range param#1 [x-shift] = -9.983963 .. 10.016037
#  + Range param#2 [y-shift] = -14.126085 .. 5.873915
#  + Range param#3 [z-shift] = -8.297941 .. 11.702059
#  + Range param#4 [z-angle] = -45.000000 .. 45.000000
#  + Range param#5 [x-angle] = -45.000000 .. 45.000000
#  + Range param#6 [y-angle] = -45.000000 .. 45.000000
#  + Range param#1 [x-shift] = -39.983963 .. 40.016037
#  + Range param#2 [y-shift] = -44.126083 .. 35.873917
#  + Range param#3 [z-shift] = -38.297943 .. 41.702057
#  + 12 free parameters
# ++ Normalized convergence radius = 0.000625
# ++ changing output grid spacing to 0.2500 mm
# ++ OpenMP thread count = 8
# ++ ======= Allineation of 1 sub-bricks using Local Pearson Correlation Abs =======
#  + source mask has 14438047 [out of 21508795] voxels
#  + base mask has 2702324 [out of 4390902] voxels
# ++ ========== sub-brick #0 ========== [total CPU to here=0.0 s]
# ++ *** Coarse pass begins ***
#  + * Enter alignment setup routine
#  + - copying base image
#  + - copying source image
#  + - Smoothing base; radius=2.22
#  + - Smoothing source; radius=2.22
#  + !source mask fill: ubot=0.281118 usiz=1.01531
#  + - copying weight image
#  + - using 253789 points from base image [use_all=0]
#  + * Exit alignment setup routine
#  + - Search for coarse starting parameters
#  + 217556 total points stored in 645 'RHDD(6.9102)' bloks
#  + - number of free params = 6
#  + - Testing (64+61)*64 params:#o*[#2=0.98319] **[#3=0.981291] *o-..*[#11=0.968646] *o*[#15=0.965619] *o..*[#20=0.964045] **[#24=0.956927] *oo*[#36=0.946221] *o..o-.++.--*[#1914=0.946072] **[#2592=0.944617] *-*[#3535=0.940577] *o$*[#4175=0.92751] *o.-o+
#  + - best 45 costs found:
#     0 v= 0.927510:  29.03 -31.27 -31.91  -7.44  27.42  25.63  [rand]
#     1 v= 0.928462:   9.84 -28.88  -9.68  -3.10 -34.36  -2.55  [rand]
#     2 v= 0.934080: -32.19  24.92 -34.44 -40.41 -19.09  40.75  [rand]
#     3 v= 0.940344: -15.97 -23.62   7.43  20.53   3.14 -10.08  [rand]
#     4 v= 0.940577:  26.68 -30.79 -24.96 -15.00  30.00  30.00  [grid]
#     5 v= 0.940775:   9.84 -28.88  -9.68   3.10 -34.36   2.55  [rand]
#     6 v= 0.941010:  24.98 -33.18 -33.75  17.69  14.58  34.92  [rand]
#     7 v= 0.941489:  22.87  19.45  12.12   5.91 -29.74  29.45  [rand]
#     8 v= 0.942387: -26.65   9.21  28.37 -30.00 -30.00 -30.00  [grid]
#     9 v= 0.942678:  19.80 -20.88 -15.97  -2.96  -2.59 -18.65  [rand]
#    10 v= 0.943087: -15.97 -23.62   7.43  20.53  -3.14 -10.08  [rand]
#    11 v= 0.943598:   9.84 -28.88  -9.68   3.10 -34.36  -2.55  [rand]
#    12 v= 0.943673:  19.80 -20.88 -15.97  -2.96   2.59 -18.65  [rand]
#    13 v= 0.943717:  22.87  19.45  12.12  -5.91 -29.74  29.45  [rand]
#    14 v= 0.944106:  19.80 -20.88 -15.97   2.96  -2.59 -18.65  [rand]
#    15 v= 0.944193: -32.19  24.92 -34.44  40.41  19.09 -40.75  [rand]
#    16 v= 0.944617: -13.32 -17.46 -11.63 -30.00 -15.00  30.00  [grid]
#    17 v= 0.944653:   9.84 -28.88  -9.68  -3.10 -34.36   2.55  [rand]
#    18 v= 0.946072: -26.65   9.21  28.37 -30.00 -30.00 -15.00  [grid]
#    19 v= 0.946109:  19.80 -20.88 -15.97   2.96   2.59 -18.65  [rand]
#    20 v= 0.946221: -13.32 -17.46  15.04  15.00  15.00 -15.00  [grid]
#    21 v= 0.946379: -34.62 -26.37 -12.60 -17.65  21.98   4.20  [rand]
#    22 v= 0.946413:  13.35 -17.46 -11.63  30.00 -15.00 -30.00  [grid]
#    23 v= 0.946646:  13.35 -17.46  15.04 -15.00 -15.00 -15.00  [grid]
#    24 v= 0.946995:  14.95 -28.22 -28.22  19.13  33.53  22.48  [rand]
#    25 v= 0.947522:  35.63  -8.54 -35.17 -37.76 -24.22  -3.86  [rand]
#    26 v= 0.947838: -13.32 -17.46  15.04  15.00 -30.00  15.00  [grid]
#    27 v= 0.947892: -15.97 -23.62   7.43  20.53  -3.14  10.08  [rand]
#    28 v= 0.948293:  13.35 -17.46  15.04 -30.00 -30.00 -15.00  [grid]
#    29 v= 0.948572:  11.61   0.43  -2.19  24.53 -29.49 -26.10  [rand]
#    30 v= 0.948814: -13.32 -17.46  15.04  15.00  30.00 -15.00  [grid]
#    31 v= 0.949371:  13.35 -17.46  15.04 -15.00 -15.00 -30.00  [grid]
#    32 v= 0.949631:  32.22 -33.17 -34.44  40.41  19.09  40.75  [rand]
#    33 v= 0.949894: -13.32  22.54 -11.63 -30.00 -15.00  30.00  [grid]
#    34 v= 0.950044:  35.21 -38.82  23.27  18.41  40.28   7.49  [rand]
#    35 v= 0.950796:  19.51 -20.80   4.30  30.54 -19.59 -20.03  [rand]
#    36 v= 0.950841:  13.18  33.76 -35.49  14.03   8.39 -25.20  [rand]
#    37 v= 0.950882: -15.97 -23.62   7.43  20.53   3.14  10.08  [rand]
#    38 v= 0.950962: -13.32 -17.46 -11.63 -15.00  30.00  15.00  [grid]
#    39 v= 0.951686: -32.19 -33.17 -34.44  40.41  19.09 -40.75  [rand]
#    40 v= 0.951706:  13.35   9.21  28.37 -15.00 -30.00  30.00  [grid]
#    41 v= 0.951841:   6.00  -0.72  26.23  29.81  -4.26 -23.54  [rand]
#    42 v= 0.951902:  13.35 -17.46  15.04  15.00  30.00 -15.00  [grid]
#    43 v= 0.952032:  13.35 -17.46  15.04 -15.00 -30.00 -15.00  [grid]
#    44 v= 0.952477:  26.68 -17.46  28.37 -30.00  15.00  30.00  [grid]
# *[#8010=0.909654] *[#8014=0.907322] *[#8018=0.907314] *[#8019=0.906293] *[#8022=0.906134] *[#8025=0.904591] *[#8027=0.904182] *[#8028=0.903067]  + - costs of the above after a little optimization:
#   * 0 v= 0.903067:  28.04 -31.06 -32.25 -11.16  25.11  22.74  [rand]
#     1 v= 0.913828:   9.59 -28.29  -6.34  -3.68 -36.18  -2.04  [rand]
#     2 v= 0.912988: -33.05  26.15 -33.13 -37.74 -13.11  41.14  [rand]
#     3 v= 0.930958: -16.47 -20.37   7.74  20.78   2.46 -10.24  [rand]
#     4 v= 0.925087:  26.85 -30.89 -24.76 -15.05  34.67  29.40  [grid]
#     5 v= 0.910327:   9.41 -28.35  -7.61  -1.79 -35.76   0.12  [rand]
#     6 v= 0.920470:  25.72 -37.06 -33.10  17.34  14.68  34.87  [rand]
#     7 v= 0.939330:  22.87  19.45  12.12   5.91 -25.24  29.45  [rand]
#     8 v= 0.931995: -26.61  10.12  29.24 -27.88 -29.23 -25.08  [grid]
#     9 v= 0.922221:  18.49 -20.69 -16.06   1.64  -3.17 -19.07  [rand]
#    10 v= 0.921722: -16.33 -20.46   7.99  19.22  -4.45  -9.85  [rand]
#    11 v= 0.913428:   9.61 -28.28  -6.20  -2.33 -34.50  -1.49  [rand]
#    12 v= 0.928351:  19.00 -20.75 -14.79   1.36   1.03 -18.54  [rand]
#    13 v= 0.931261:  23.31  18.17  13.44   4.35 -27.18  31.35  [rand]
#    14 v= 0.924473:  18.70 -21.12 -14.40   3.92  -1.23 -13.15  [rand]
#    15 v= 0.931182: -31.02  24.23 -34.77  38.74  22.77 -40.89  [rand]
#    16 v= 0.940005: -13.25 -17.62 -11.48 -25.60 -15.06  29.90  [grid]
#    17 v= 0.914711:   9.98 -28.12  -6.19  -0.93 -34.70   1.76  [rand]
#    18 v= 0.938675: -26.98  10.09  28.36 -29.77 -29.12 -15.16  [grid]
#    19 v= 0.936408:  18.80 -20.40 -14.45   5.63   3.73  -8.46  [rand]
#    20 v= 0.940246: -13.35 -17.23  14.98  14.80  19.52 -14.69  [grid]
#    21 v= 0.940029: -35.12 -26.77 -13.04 -19.33  20.82   3.85  [rand]
#    22 v= 0.916794:  17.25 -18.11 -13.10  30.99 -14.14 -30.18  [grid]
#    23 v= 0.940411:  13.25 -20.88  14.87 -15.51 -15.00 -15.84  [grid]
#    24 v= 0.932839:  16.52 -25.30 -29.87  15.30  29.20  22.37  [rand]
#    25 v= 0.934565:  35.03  -8.89 -37.99 -39.63 -25.51  -6.20  [rand]
#    26 v= 0.946590: -13.52 -17.10  14.96  15.40 -29.86  15.01  [grid]
#    27 v= 0.915175: -17.15 -19.67   5.70  14.50  -6.96   5.75  [rand]
#    28 v= 0.939052:  12.94 -20.54  15.15 -29.97 -30.08 -15.83  [grid]
#    29 v= 0.936907:  11.18   0.19  -3.83  24.49 -31.53 -30.09  [rand]
#    30 v= 0.937670: -12.86 -19.15  14.17  15.73  29.93 -10.21  [grid]
#    31 v= 0.934644:  13.49 -18.29  12.93 -15.96 -16.73 -22.94  [grid]
#    32 v= 0.937167:  32.84 -33.59 -33.31  39.09  18.74  41.38  [rand]
#    33 v= 0.947860: -12.91  23.11 -11.52 -30.40 -14.96  30.07  [grid]
#    34 v= 0.930508:  35.24 -38.50  24.37  19.06  41.93  16.19  [rand]
#    35 v= 0.938417:  19.82 -19.99   3.28  30.41 -19.31 -24.45  [rand]
#    36 v= 0.941561:  18.20  32.72 -35.60  15.02   9.45 -25.46  [rand]
#    37 v= 0.922081: -17.13 -19.48   6.12  16.51  -1.88   9.37  [rand]
#    38 v= 0.935445: -13.54 -19.77 -10.75 -13.73  36.06  19.24  [grid]
#    39 v= 0.931472: -32.21 -33.31 -33.90  40.40  23.55 -40.86  [rand]
#    40 v= 0.924088:  14.68  14.63  27.99 -15.18 -28.70  27.37  [grid]
#    41 v= 0.939678:   7.28  -0.19  23.87  28.84  -6.80 -24.02  [rand]
#    42 v= 0.942727:  11.55 -17.95   6.39  17.48  27.93 -14.93  [grid]
#    43 v= 0.945027:  12.58 -18.60  14.82 -12.74 -29.10 -16.38  [grid]
#    44 v= 0.949940:  26.77 -17.33  28.87 -29.88  19.20  29.82  [grid]
#  + - save # 0 for twobest
#  + - save # 5 for twobest
#  + - save # 2 for twobest
#  + - skip #11 for twobest: too close to set # 5
#  + - skip # 1 for twobest: too close to set # 5
#  + - skip #17 for twobest: too close to set # 5
#  + - save #27 for twobest
#  + - save #22 for twobest
#  + - save # 6 for twobest
#  + - save #10 for twobest
#  + - save #37 for twobest
#  + - save # 9 for twobest
#  + - save #40 for twobest
#  + - save #14 for twobest
#  + - save # 4 for twobest
#  + - skip #12 for twobest: too close to set # 9
#  + - save #34 for twobest
#  + - save # 3 for twobest
#  + - save #15 for twobest
#  + - save #13 for twobest
#  + - save #39 for twobest
#  + - save # 8 for twobest
#  + - save #24 for twobest
#  + - save #25 for twobest
#  + - save #31 for twobest
#  + - save #38 for twobest
#  + - Coarse startup search net CPU time = 0.0 s
# ++ Start refinement #1 on 12 coarse parameter sets
#  + * Enter alignment setup routine
#  + - Smoothing base; radius=1.73
#  + - Smoothing source; radius=1.73
#  + !source mask fill: ubot=0.281118 usiz=1.01531
#  + - retaining old weight image
#  + - using 380683 points from base image [use_all=0]
#  + * Exit alignment setup routine
#  + 340336 total points stored in 704 'RHDD(6.76755)' bloks
#  + - param set #1 has cost=0.923301
#  + -- Parameters = 27.8280 -28.8277 -31.6408 -13.1327 25.8821 25.6683 1.0020 0.9809 1.0034 0.0021 0.0013 0.0021
#  + - param set #2 has cost=0.936945
#  + -- Parameters = 9.6081 -28.3397 -7.6632 -2.9076 -37.8292 -2.9242 0.9860 0.9912 1.0034 -0.0017 -0.0065 0.0052
#  + - param set #3 has cost=0.933513
#  + -- Parameters = -33.0647 26.4277 -32.8820 -37.7890 -13.2157 41.0248 1.0009 0.9997 0.9996 -0.0004 0.0096 -0.0003
#  + - param set #4 has cost=0.925989
#  + -- Parameters = -16.2106 -20.3904 5.6947 14.8754 -9.9147 2.6974 1.0435 0.9974 0.9715 -0.0022 -0.0035 -0.0159
#  + - param set #5 has cost=0.928580
#  + -- Parameters = 16.0466 -18.6805 -13.8125 36.4602 -8.1733 -35.1860 1.0106 0.9963 1.0130 -0.0098 0.0095 0.0012
#  + - param set #6 has cost=0.949544
#  + -- Parameters = 25.5256 -37.3200 -33.1766 17.2391 14.5352 34.4547 1.0171 1.0000 0.9999 -0.0001 -0.0007 -0.0004
#  + - param set #7 has cost=0.933115
#  + -- Parameters = -15.8425 -21.3060 8.5611 18.4024 -3.5600 -9.7035 1.0231 1.0013 1.0000 0.0007 -0.0002 0.0003
#  + - param set #8 has cost=0.919573
#  + -- Parameters = -16.9462 -19.5430 5.2532 14.9564 -10.0107 4.5125 1.1066 1.0082 0.9661 -0.0004 -0.0446 0.0231
#  + - param set #9 has cost=0.944360
#  + -- Parameters = 18.4620 -20.7840 -16.0354 1.7062 -2.9546 -19.2680 0.9998 1.0005 1.0172 -0.0006 0.0002 0.0000
#  + - param set #10 has cost=0.951771
#  + -- Parameters = 14.0126 14.6448 28.2699 -15.8575 -28.4962 27.2650 1.0031 1.0033 1.0031 0.0018 0.0019 0.0109
#  + - param set #11 has cost=0.940403
#  + -- Parameters = 18.8058 -21.7584 -13.5614 3.2728 -0.4204 -12.6530 1.0012 1.0015 1.0212 0.0013 0.0009 0.0010
#  + - param set #12 has cost=0.953172
#  + -- Parameters = -7.2777 -9.6403 7.2535 -0.3239 -1.8373 -4.0782 0.9901 0.9870 0.9859 -0.0018 0.0019 0.0143
#  + - sorting parameter sets by cost
#  + -- scanning for distances from #1
#  + --- dist(#2,#1) = 0.56
#  + --- dist(#3,#1) = 0.185
#  + --- dist(#4,#1) = 0.441
#  + --- dist(#5,#1) = 0.228
#  + --- dist(#6,#1) = 0.586
#  + --- dist(#7,#1) = 0.332
#  + --- dist(#8,#1) = 0.447
#  + --- dist(#9,#1) = 0.443
#  + --- dist(#10,#1) = 0.531
#  + --- dist(#11,#1) = 0.427
#  + --- dist(#12,#1) = 0.318
# ++ Start refinement #2 on 12 coarse parameter sets
#  + * Enter alignment setup routine
#  + - Smoothing base; radius=1.34
#  + - Smoothing source; radius=1.34
#  + !source mask fill: ubot=0.281118 usiz=1.01531
#  + - retaining old weight image
#  + - using 571024 points from base image [use_all=0]
#  + * Exit alignment setup routine
#  + 519113 total points stored in 753 'RHDD(6.6798)' bloks
#  + - param set #1 has cost=0.933919
#  + -- Parameters = -16.3464 -19.6030 5.2684 15.3480 -8.9917 4.1152 1.1108 0.9834 0.9416 0.0024 -0.0380 0.0178
#  + - param set #2 has cost=0.935344
#  + -- Parameters = 28.1880 -28.7625 -31.6548 -13.9849 25.2864 25.8226 0.9981 0.9573 0.9908 0.0086 0.0058 -0.0096
#  + - param set #3 has cost=0.934474
#  + -- Parameters = -15.9124 -19.4319 5.5612 14.8482 -10.2163 3.1054 1.0974 0.9942 0.9587 0.0026 -0.0043 -0.0175
#  + - param set #4 has cost=0.948722
#  + -- Parameters = 16.4887 -18.6726 -13.5583 38.5226 -9.7698 -35.1783 1.0102 0.9995 1.0238 -0.0016 0.0142 -0.0002
#  + - param set #5 has cost=0.935364
#  + -- Parameters = -15.6383 -20.7546 8.3081 15.9316 -2.6276 -6.3744 1.0635 0.9892 0.9473 -0.0210 -0.0145 0.0037
#  + - param set #6 has cost=0.932988
#  + -- Parameters = -33.3610 26.5118 -33.2772 -34.5060 -13.2820 41.3667 0.9997 1.0038 1.0010 0.0002 0.0095 0.0000
#  + - param set #7 has cost=0.934862
#  + -- Parameters = 9.6801 -27.6685 -8.2749 -4.0693 -38.1194 -1.2884 0.9597 0.9865 1.0014 0.0042 -0.0116 0.0015
#  + - param set #8 has cost=0.959418
#  + -- Parameters = 18.7960 -21.7195 -13.6760 3.3871 -1.1838 -12.4580 0.9981 1.0000 1.0330 0.0002 0.0008 0.0008
#  + - param set #9 has cost=0.959472
#  + -- Parameters = 18.4562 -20.7967 -16.0820 1.8196 -2.8255 -22.0034 0.9997 1.0003 1.0175 -0.0010 0.0001 0.0004
#  + - param set #10 has cost=0.949411
#  + -- Parameters = 25.6865 -38.2215 -33.1182 17.7336 14.5338 34.1930 1.0048 0.9978 1.0239 0.0093 -0.0113 -0.0101
#  + - param set #11 has cost=0.962061
#  + -- Parameters = 16.3076 14.4435 28.5705 -15.4990 -28.3841 26.8489 1.0047 1.0042 1.0016 0.0026 0.0018 0.0118
#  + - param set #12 has cost=0.950968
#  + -- Parameters = -6.3651 -9.8315 7.6418 -3.9399 -2.0102 -3.6890 0.9827 0.9843 0.9549 -0.0049 0.0025 0.0124
#  + - sorting parameter sets by cost
#  + -- scanning for distances from #1
#  + --- dist(#2,#1) = 0.576
#  + --- dist(#3,#1) = 0.574
#  + --- dist(#4,#1) = 0.677
#  + --- dist(#5,#1) = 0.769
#  + --- dist(#6,#1) = 0.591
#  + --- dist(#7,#1) = 0.85
#  + --- dist(#8,#1) = 0.809
#  + --- dist(#9,#1) = 0.511
#  + --- dist(#10,#1) = 0.652
#  + --- dist(#11,#1) = 0.704
#  + --- dist(#12,#1) = 0.773
# ++ Start refinement #3 on 12 coarse parameter sets
#  + * Enter alignment setup routine
#  + - Smoothing base; radius=1.05
#  + - Smoothing source; radius=1.05
#  + !source mask fill: ubot=0.281118 usiz=1.01531
#  + - retaining old weight image
#  + - using 856536 points from base image [use_all=0]
#  + * Exit alignment setup routine
#  + 771710 total points stored in 756 'RHDD(6.62616)' bloks
#  + - param set #1 has cost=0.939188
#  + -- Parameters = -33.8677 26.5179 -33.4388 -34.5467 -13.8088 41.5000 1.0000 1.0040 1.0026 0.0008 0.0098 0.0007
#  + - param set #2 has cost=0.934367
#  + -- Parameters = -15.2734 -20.3432 5.8727 11.2996 -6.9420 4.3064 1.1226 1.0091 0.9074 0.0062 -0.0382 -0.0071
#  + - param set #3 has cost=0.937117
#  + -- Parameters = -15.6153 -19.6014 5.7044 13.2220 -9.3540 3.0685 1.1374 0.9945 0.9454 0.0104 -0.0069 -0.0159
#  + - param set #4 has cost=0.940109
#  + -- Parameters = 9.6406 -27.6413 -8.4876 -4.0526 -38.0427 -1.2609 0.9595 0.9793 1.0013 0.0042 -0.0116 0.0014
#  + - param set #5 has cost=0.942057
#  + -- Parameters = 28.5599 -28.7936 -31.5065 -15.9368 25.3367 25.9072 0.9977 0.9574 0.9903 0.0081 0.0054 -0.0106
#  + - param set #6 has cost=0.942039
#  + -- Parameters = -15.6386 -20.4570 8.2478 14.1413 -2.6088 -6.1857 1.0641 0.9888 0.9471 -0.0208 -0.0142 0.0038
#  + - param set #7 has cost=0.951200
#  + -- Parameters = 16.4875 -18.6708 -13.5602 38.5293 -9.7746 -35.0934 1.0101 0.9921 1.0238 -0.0016 0.0140 -0.0001
#  + - param set #8 has cost=0.954081
#  + -- Parameters = 25.6817 -38.2520 -33.0279 17.7835 14.5062 34.1821 1.0124 0.9975 1.0237 0.0093 -0.0114 -0.0102
#  + - param set #9 has cost=0.951272
#  + -- Parameters = -6.2254 -10.2113 7.5302 -5.9063 0.2448 -3.7342 0.9823 0.9995 0.9297 -0.0279 -0.0038 0.0303
#  + - param set #10 has cost=0.965252
#  + -- Parameters = 18.6420 -21.7339 -13.6592 3.3134 -1.2966 -12.5236 0.9904 1.0002 1.0329 0.0003 0.0006 0.0006
#  + - param set #11 has cost=0.962672
#  + -- Parameters = 18.3599 -21.3852 -16.9870 2.0392 -3.6760 -20.5420 0.9638 0.9972 1.0233 -0.0030 0.0017 -0.0023
#  + - param set #12 has cost=0.962752
#  + -- Parameters = 17.4373 14.4782 28.1507 -15.3836 -28.6092 24.4325 0.9960 1.0005 0.9879 0.0039 0.0011 0.0073
#  + - sorting parameter sets by cost
#  + -- scanning for distances from #1
#  + --- dist(#2,#1) = 0.141
#  + --- dist(#3,#1) = 0.586
#  + --- dist(#4,#1) = 0.444
#  + --- dist(#5,#1) = 0.159
#  + --- dist(#6,#1) = 0.548
#  + --- dist(#7,#1) = 0.438
#  + --- dist(#8,#1) = 0.382
#  + --- dist(#9,#1) = 0.512
#  + --- dist(#10,#1) = 0.433
#  + --- dist(#11,#1) = 0.435
#  + --- dist(#12,#1) = 0.424
#  + - Total coarse refinement net CPU time = 0.0 s; 2442 funcs
# ++ *** Fine pass begins ***
#  + * Enter alignment setup routine
#  + - Smoothing base; radius=1.00
#  + - Smoothing source; radius=1.00
#  + !source mask fill: ubot=0.281118 usiz=1.01531
#  + - retaining old weight image
#  + - using 3806835 points from base image [use_all=0]
#  + * Exit alignment setup routine
# ++ Picking best parameter set out of 13 cases
#  + 3419171 total points stored in 756 'RHDD(6.61918)' bloks
#  + - cost(#1)=0.938881 *
#  + -- Parameters = -15.2734 -20.3432 5.8727 11.2996 -6.9420 4.3064 1.1226 1.0091 0.9074 0.0062 -0.0382 -0.0071
#  + - cost(#2)=0.941516
#  + -- Parameters = -15.6153 -19.6014 5.7044 13.2220 -9.3540 3.0685 1.1374 0.9945 0.9454 0.0104 -0.0069 -0.0159
#  + - cost(#3)=0.942821
#  + -- Parameters = -33.8677 26.5179 -33.4388 -34.5467 -13.8088 41.5000 1.0000 1.0040 1.0026 0.0008 0.0098 0.0007
#  + - cost(#4)=0.943238
#  + -- Parameters = 9.6406 -27.6413 -8.4876 -4.0526 -38.0427 -1.2609 0.9595 0.9793 1.0013 0.0042 -0.0116 0.0014
#  + - cost(#5)=0.944989
#  + -- Parameters = -15.6386 -20.4570 8.2478 14.1413 -2.6088 -6.1857 1.0641 0.9888 0.9471 -0.0208 -0.0142 0.0038
#  + - cost(#6)=0.947939
#  + -- Parameters = 28.5599 -28.7936 -31.5065 -15.9368 25.3367 25.9072 0.9977 0.9574 0.9903 0.0081 0.0054 -0.0106
#  + - cost(#7)=0.957891
#  + -- Parameters = 16.4875 -18.6708 -13.5602 38.5293 -9.7746 -35.0934 1.0101 0.9921 1.0238 -0.0016 0.0140 -0.0001
#  + - cost(#8)=0.952285
#  + -- Parameters = -6.2254 -10.2113 7.5302 -5.9063 0.2448 -3.7342 0.9823 0.9995 0.9297 -0.0279 -0.0038 0.0303
#  + - cost(#9)=0.957628
#  + -- Parameters = 25.6817 -38.2520 -33.0279 17.7835 14.5062 34.1821 1.0124 0.9975 1.0237 0.0093 -0.0114 -0.0102
#  + - cost(#10)=0.965604
#  + -- Parameters = 18.3599 -21.3852 -16.9870 2.0392 -3.6760 -20.5420 0.9638 0.9972 1.0233 -0.0030 0.0017 -0.0023
#  + - cost(#11)=0.965122
#  + -- Parameters = 17.4373 14.4782 28.1507 -15.3836 -28.6092 24.4325 0.9960 1.0005 0.9879 0.0039 0.0011 0.0073
#  + - cost(#12)=0.967572
#  + -- Parameters = 18.6420 -21.7339 -13.6592 3.3134 -1.2966 -12.5236 0.9904 1.0002 1.0329 0.0003 0.0006 0.0006
#  + - cost(#13)=0.992590
#  + -- Parameters = 0.0160 -4.1261 1.7021 0.0000 0.0000 0.0000 1.0000 1.0000 1.0000 0.0000 0.0000 0.0000
#  + -num_rtb 99 ==> refine all 13 cases
#  + - cost(#1)=0.938144 *
#  + -- Parameters = -15.2424 -20.5547 5.9694 11.3146 -6.8928 4.4243 1.1230 1.0096 0.9143 0.0059 -0.0388 -0.0082
#  + - cost(#2)=0.940535
#  + -- Parameters = -15.4971 -19.2025 5.7275 13.2818 -9.2772 2.6802 1.1372 0.9948 0.9394 0.0098 -0.0070 -0.0163
#  + - cost(#3)=0.938632
#  + -- Parameters = -34.2453 27.1842 -33.4241 -33.4772 -15.2199 40.7601 1.0054 1.0027 1.0057 -0.0047 0.0208 0.0023
#  + - cost(#4)=0.943056
#  + -- Parameters = 9.6264 -27.6252 -8.5231 -4.0035 -38.0449 -1.2680 0.9597 0.9794 0.9951 0.0042 -0.0115 0.0012
#  + - cost(#5)=0.942847
#  + -- Parameters = -15.3874 -20.0190 7.4250 14.1719 -2.7383 -6.2626 1.0685 0.9887 0.9445 -0.0207 -0.0117 0.0020
#  + - cost(#6)=0.946234
#  + -- Parameters = 28.4253 -28.7077 -31.2555 -15.8266 25.3574 26.6189 1.0019 0.9596 0.9884 0.0114 0.0024 -0.0074
#  + - cost(#7)=0.954509
#  + -- Parameters = 16.9015 -17.8832 -13.7672 41.9941 -11.8523 -33.5627 1.0067 0.9980 1.0261 0.0018 0.0186 0.0054
#  + - cost(#8)=0.951194
#  + -- Parameters = -5.8950 -10.2893 7.5235 -6.5867 0.4572 -3.6282 0.9764 0.9994 0.9320 -0.0410 -0.0073 0.0315
#  + - cost(#9)=0.957163
#  + -- Parameters = 25.7832 -38.2874 -33.0326 17.7841 14.5120 34.2608 1.0127 0.9980 1.0239 0.0092 -0.0117 -0.0140
#  + - cost(#10)=0.963620
#  + -- Parameters = 18.2487 -21.0221 -17.3343 1.7848 -4.2188 -22.1547 0.9648 0.9958 1.0246 -0.0031 0.0021 -0.0012
#  + - cost(#11)=0.964592
#  + -- Parameters = 17.6831 14.4690 28.0954 -15.4007 -28.3953 24.4421 0.9955 1.0016 0.9936 0.0046 0.0010 0.0072
#  + - cost(#12)=0.964388
#  + -- Parameters = 18.4878 -21.7064 -13.9779 4.0389 -0.6094 -11.2489 0.9582 0.9942 1.0514 0.0001 -0.0048 0.0068
#  + - cost(#13)=0.977102
#  + -- Parameters = 0.5782 -6.4539 -2.0511 0.0929 0.6301 -0.7232 1.0036 0.9992 1.0006 0.0007 0.0040 -0.0017
#  + - case #1 is now the best
#  + - Initial  cost = 0.938144
#  + - Initial fine Parameters = -15.2424 -20.5547 5.9694 11.3146 -6.8928 4.4243 1.1230 1.0096 0.9143 0.0059 -0.0388 -0.0082
#  + - Finalish cost = 0.937923 ; 84 funcs
#  + - Final    cost = 0.937876 ; 118 funcs
#  + Final fine fit Parameters:
#        x-shift=-15.2565   y-shift=-20.5728   z-shift= 5.9660
#        z-angle=11.3386   x-angle=-6.9577   y-angle= 4.4486
#        x-scale= 1.1229   y-scale= 1.0094   z-scale= 0.9147
#      y/x-shear= 0.0059 z/x-shear=-0.0382 z/y-shear=-0.0144
#  + - Fine net CPU time = 0.0 s
# ++ Computing output image
# ++ image warp: parameters = -15.2565 -20.5728 5.9660 11.3386 -6.9577 4.4486 1.1229 1.0094 0.9147 0.0059 -0.0382 -0.0144
# ++ Wrote -1Dmatrix_save ./NMT_al2std_mat.aff12.1D
# ++ 3dAllineate: total CPU time = 0.0 sec  Elapsed = 198.1
# ++ ###########################################################
# ++ #   Please check results visually for alignment quality   #
# ++ ###########################################################
# ++ #   '-autoweight' is recommended when using -lpc or -lpa  #
# ++ #   If your results are not good, please try again.       #
# ++ ###########################################################
# #++  Applying alignment for dset2 to dset1
# #++ Inverting dset1 to dset2 matrix
# #Script is running (command trimmed):
#   cat_matvec -ONELINE ./NMT_al2std_mat.aff12.1D -I > ./Eddy_shft_al2std_mat.aff12.1D
# #++ Applying transformation of dset2 to dset1
# #Script is running (command trimmed):
#   3dAllineate -base /media/DATA1/NHP_MRI/Template/NMT/NMT.nii.gz -1Dmatrix_apply ./Eddy_shft_al2std_mat.aff12.1D -prefix ././Eddy_shft_al2std -input ./__tt_Eddy_shft+orig -master BASE -mast_dxyz 0.500000 -weight_frac 1.0 -maxrot 6 -maxshf 10 -VERB -warp aff -source_automask+4 -twobest 11 -twopass -VERB -maxrot 45 -maxshf 40 -fineblur 1 -source_automask+2
# ++ 3dAllineate: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: Zhark the Registrator
# *+ WARNING: Small value 0.5 after -mast_dxyz :-(
# ++ Source dataset: ./__tt_Eddy_shft+orig.HEAD
# ++ Base dataset:   /media/DATA1/NHP_MRI/Template/NMT/NMT.nii.gz
# ++ Loading datasets
#  + Range param#4 [z-angle] = -6.000000 .. 6.000000
#  + Range param#5 [x-angle] = -6.000000 .. 6.000000
#  + Range param#6 [y-angle] = -6.000000 .. 6.000000
#  + Range param#1 [x-shift] = -10.000000 .. 10.000000
#  + Range param#2 [y-shift] = -10.000000 .. 10.000000
#  + Range param#3 [z-shift] = -10.000000 .. 10.000000
#  + Range param#4 [z-angle] = -45.000000 .. 45.000000
#  + Range param#5 [x-angle] = -45.000000 .. 45.000000
#  + Range param#6 [y-angle] = -45.000000 .. 45.000000
#  + Range param#1 [x-shift] = -40.000000 .. 40.000000
#  + Range param#2 [y-shift] = -40.000000 .. 40.000000
#  + Range param#3 [z-shift] = -40.000000 .. 40.000000
# ++ changing output grid spacing to 0.5000 mm
# ++ OpenMP thread count = 8
# ++ ========== Applying transformation to 1 sub-bricks ==========
# ++ ========== sub-brick #0 ========== [total CPU to here=0.0 s]
#  + * Enter alignment setup routine
#  + - copying base image
#  + - copying source image
#  + - no weight image
#  + - using 11 points from base image [use_all=0]
#  + * Exit alignment setup routine
# ++ using -1Dmatrix_apply
# ++ Computing output image
# ++ image warp: parameters = 0.8755 -0.1925 -0.0572 39.1391 0.1662 0.9663 -0.1461 -68.3518 0.0267 0.1045 1.0820 -5.5848
# ++ 3dAllineate: total CPU time = 0.0 sec  Elapsed = 1.8
# ++ ###########################################################
# #++ Creating final output: dset2 data aligned to dset1
# # copy is not necessary - both paths are same
# #++ Saving history
# #Script is running (command trimmed):
#   3dNotes -h "align_epi_anat.py -dset2 Eddy_shft.nii.gz -dset1 ../../NMT.nii.gz \
#  -overwrite -dset2to1 -giant_move -suffix _al2std -dset1_strip None \
#  -dset2_strip None" \
#  ./Eddy_shft_al2std+orig
#
# #++ Removing all the temporary files
# #Script is running:
#   \rm -f ./__tt_Eddy_shft*
# #Script is running:
#   \rm -f ./__tt_NMT*
#
# # Finished alignment successfully
#
# ++ 3dAFNItoNIFTI: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ 3dAllineate: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: Zhark the Registrator
# ++ Source dataset: ./Eddy_shft.nii.gz
# ++ Base dataset:   ../../NMT.nii.gz
# ++ Loading datasets
# ++ OpenMP thread count = 8
# ++ ========== Applying transformation to 1 sub-bricks ==========
# ++ Output dataset ./Eddy_shft_aff.nii.gz
# ++ 3dAllineate: total CPU time = 0.0 sec  Elapsed = 4.8
# ++ ###########################################################
# #++ auto_warp.py version: 0.04
# -- clearing AFNI_COMPRESSOR ...
# # Output directory /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/awpy_Eddy_shft/
# #Script is running (command trimmed):
#   mkdir ./awpy_Eddy_shft/
# cd /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/awpy_Eddy_shft/
# #Script is running (command trimmed):
#   3dcopy /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/Eddy_shft_aff.nii.gz ./anat.nii
# ++ 3dcopy: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# #Script is running (command trimmed):
#   3dUnifize -GM -input ./anat.nii -prefix ./anat.un.nii
# ++ 3dUnifize: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
#  + Pre-processing: ADV.......................UWG
# ++ Output dataset ./anat.un.nii
# ++ ===== Elapsed = 49.6 sec
# #Script is running (command trimmed):
#   3dcopy /media/DATA1/NHP_MRI/Template/NMT/NMT.nii.gz ./base.nii
# ++ 3dcopy: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# #Script is running (command trimmed):
#   3dAttribute DELTA ./anat.un.nii
# #Script is running (command trimmed):
#   3dAttribute DELTA ./base.nii
# 0.250000 0.250000
# #Script is running (command trimmed):
#   3dinfo -same_grid ./anat.un.nii ./base.nii
# #++ Aligning /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/awpy_Eddy_shft/base.nii data to /media/DATA1/NHP_MRI/Template/NMT/single_subject_scans/Eddy/awpy_Eddy_shft/anat.un.nii data
# #Script is running (command trimmed):
#   3dQwarp -prefix ./anat.un.qw.nii -blur -3 -3 -workhard:0:2 -iwarp -base ./base.nii -source ./anat.un.nii
# ++ OpenMP thread count = 8
# ++ 3dQwarp: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: Zhark the (Hermite) Cubically Warped
# ++ Dataset zero-pad: xbot=28 xtop=28  ybot=38 ytop=39  zbot=27 ztop=27 voxels
# ++ Weightizing the base image
# ++ +++++++++++ Begin warp optimization:  base=./base.nii  source=./anat.un.nii
# ++ AFNI warpomatic: 309 x 424 x 299 volume ; autobbox = 21..287 37..391 22..269 [clock= 38s 610ms]
# lev=0 0..308 0..423 0..298: [first cost=-0.07097] ..
# Fatal Signal 2 (SIGINT) received
# Last STATUS: start loop
#       Hwarp_apply
#      IW3D_improve_warp
#     IW3D_warpomatic
#    IW3D_warp_s2bim
#   3dQwarp
#  Bottom of Debug Stack
# ** Command line was:
# 3dQwarp -prefix ./anat.un.qw.nii -blur -3 -3 -workhard:0:2 -iwarp -base ./base.nii -source ./anat.un.nii
# ** AFNI version = AFNI_18.2.04  Compile date = Jul  6 2018
# ** [[Precompiled binary linux_ubuntu_16_64: Jul  6 2018]]
# ** Program Death **
# Traceback (most recent call last):
#   File "/home/chris/abin/auto_warp.py", line 835, in <module>
#     a, ps.warp_input_xform = ps.qwarping(a=a, b=b)
#   File "/home/chris/abin/auto_warp.py", line 722, in qwarping
#     com.run()
#   File "/home/chris/abin/afni_base.py", line 548, in run
#     self.status, self.so, self.se = shell_exec2(self.trimcom, self.capture)
#   File "/home/chris/abin/afni_base.py", line 990, in shell_exec2
#     status = pipe.wait() #Wait till it is over and store returncode
#   File "/home/chris/anaconda3/lib/python3.5/subprocess.py", line 1399, in wait
#     (pid, sts) = self._try_wait(0)
#   File "/home/chris/anaconda3/lib/python3.5/subprocess.py", line 1349, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt

# %% [markdown]
# You may already want to perform some manual adjustments here (e.g., white matter tends to be overestimated in the occipital lobe). There are many ways to do this but one easy way is with `ITK-SNAP` (http://www.itksnap.org/pmwiki/pmwiki.php). Whenever you decide to make adjustments, dot it on a copy of the original results and leave the original results intact.
#
# In `ITK-SNAP` you can open the brain volume as the `Main Image` and load the segmentation volume as segmentation.
#
# ![ITKSNAP](pics/itksnap_loaded.png)
#
# Voxels in the segmentation are labeled red (value 1) for CSF, green (value 2) for grey matter, and blue (value 3) for white matter. You can use the paintbrush tool to change labels and save the adjusted segmentation file.
#
# To generate separate CSF/GM/WM masks you can run
# ```
# fslmaths <SUBJECT>_segmentation.nii.gz -thr 0.9 -uthr 1.1 -bin <SUBJECT>_CSF.nii.gz
# fslmaths <SUBJECT>_segmentation.nii.gz -thr 1.9 -uthr 2.1 -bin <SUBJECT>_GM.nii.gz
# fslmaths <SUBJECT>_segmentation.nii.gz -thr 2.9 -uthr 3.1 -bin <SUBJECT>_WM.nii.gz
# fslmaths <SUBJECT>_segmentation.nii.gz -thr 0.5 -uthr 3.1 -bin <SUBJECT>_brainmask.nii.gz
# ```
#
# In addtion you can create atlas files so you use the warped D99 atlas for this individual in `FSLEyes`

# %%
# Create usability files for the warped D99 atlas in individual space
./create_ss_atlas ${SUBJ}

# %% [markdown]
# ----
# ----
# ## **Step 3: Create surfaces and flatmaps using Freesurfer**
#
# ----
# ----

# %% [markdown]
# ### Requirements
# - Freesurfer installation (https://surfer.nmr.mgh.harvard.edu/)
# - Segmented individual subject T1
#
# ### Procedure
# #### Create folders & copy files

# %%
# Path to the single_subjects folder in NMT where this subject's segmentation is located
#NMT_src=${NMT_path}/single_subject_scans/${SUBJ}/NMT_${SUBJ}_process 
# adjust this path if you have manually adjusted and saved to a different folder, e.g.
NMT_src=${NMT_path}/single_subject_scans/${SUBJ}/NMT_${SUBJ}_process/manual_adjust # for Danny & Eddy

# create a folder for the freesurfer surfaces we will eventually end up with
fsSurf=${NMT_path}/single_subject_scans/${SUBJ}/fsSurf
mkdir -p ${fsSurf}

# make subfolders for structure
fsSurf_src=${fsSurf}/src
fsSurf_mgz=${fsSurf}/mgz
fsSurf_temp=${fsSurf}/temp
mkdir -p ${fsSurf_src}
mkdir -p ${fsSurf_mgz}
mkdir -p ${fsSurf_temp}

# initialize an array to be able to loop over hemispheres
HEMI=(lh rh)

# %%
# copy the source files from the NMT segmentation to the freesurfer folders you just created
cp ${NMT_src}/${SUBJ}_N4.nii.gz ${fsSurf_src}/T1.nii.gz
cp ${NMT_src}/${SUBJ}_brain.nii.gz ${fsSurf_src}/brain.nii.gz
cp ${NMT_src}/${SUBJ}_brain.nii.gz ${fsSurf_src}/brainmask.nii.gz # freesurfer brainmask aren't actually masks
cp ${NMT_src}/${SUBJ}_WM.nii.gz ${fsSurf_src}/wm.nii.gz

# copy source files again but keep these in original state 
# (for others the header will be changed to 'fake' 1 mm voxels, which is necessary for freesurfer)
mkdir -p ${fsSurf_src}/org
cp ${fsSurf_src}/*.nii.gz ${fsSurf_src}/org/

# %% [markdown]
# #### Change headers to mimic 1mm isotropic voxels & make mgz files

# %%
# change headers
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/T1.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brain.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brainmask.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/wm.nii.gz
# convert to mgz files for freesurfer
mri_convert -c ${fsSurf_src}/T1.nii.gz ${fsSurf_mgz}/T1.mgz
mri_convert -c ${fsSurf_src}/brain.nii.gz ${fsSurf_mgz}/brain.mgz
mri_convert -c ${fsSurf_src}/brain.nii.gz ${fsSurf_mgz}/brainmask.mgz
mri_convert -c ${fsSurf_src}/brainmask.nii.gz ${fsSurf_mgz}/brainmask_binary.mgz
mri_convert -c ${fsSurf_src}/wm.nii.gz ${fsSurf_mgz}/wm.mgz
# create brain.finalsurfs.mgz
mri_mask -T 5 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/brainmask.mgz ${fsSurf_mgz}/brain.finalsurfs.mgz
# Out:
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/T1.nii.gz
#  + applying -keepcen
#  + deoblique
#  + loading and re-writing dataset /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/T1.nii.gz (/NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/T1.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brain.nii.gz
#  + applying -keepcen
#  + deoblique
#  + loading and re-writing dataset /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brain.nii.gz (/NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brain.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brainmask.nii.gz
#  + applying -keepcen
#  + deoblique
#  + loading and re-writing dataset /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brainmask.nii.gz (/NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brainmask.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# ++ 3drefit: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# ++ Authored by: RW Cox
# ++ Processing AFNI dataset /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/wm.nii.gz
#  + applying -keepcen
#  + deoblique
#  + loading and re-writing dataset /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/wm.nii.gz (/NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/wm.nii.gz in NIFTI storage)
# ++ 3drefit processed 1 datasets
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/T1.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/T1.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/T1.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/T1.mgz...
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brain.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/brain.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brain.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/brain.mgz...
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brain.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/brainmask.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brain.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/brainmask.mgz...
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brainmask.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/brainmask_binary.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/brainmask.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/brainmask_binary.mgz...
# mri_convert.bin -c /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/wm.nii.gz /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/wm.mgz
# $Id: mri_convert.c,v 1.226 2016/02/26 16:15:24 mreuter Exp $
# reading from /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/src/wm.nii.gz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (1, -0, 0)
# j_ras = (-0, 1, 0)
# k_ras = (-0, -0, 1)
# changing data type from float to uchar (noscale = 0)...
# MRIchangeType: Building histogram
# Reslicing using trilinear interpolation
# writing to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/wm.mgz...
# threshold mask volume at 5
# DoAbs = 0
# Found 901650 voxels in mask (pct=  5.37)
# Writing masked volume to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/brain.finalsurfs.mgz...done.

# %% [markdown]
# #### Get corpus callosum and pons voxel coordinates
# These will later define the cutting planes for the surface generation so make sure that 1) the corpus callosum is in the middle, and 2) the pons coordinates are low enough to not cut through cortex.
#
# Corpus callosum:
# ![CC](pics/CC_coordinates.png)
#
# Pons:
# ![PONS](pics/PONS_coordinates.png)

# %%
# Inspect volume to get voxel coordinates
freeview -v ${fsSurf_mgz}/brain.mgz &
# Out:
# [1] 23038

# %%
#DANNY
#CC=(127 114 129) # corpus callosum
#PONS=(124 148 119) # pons

#EDDY
CC=(131 113 122) # corpus callosum
PONS=(131 149 117) # pons

# %% [markdown]
# #### Fill the white matter volume & copy for backup before fixing

# %%
# Fill WM
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/filled.mgz
# copy the original white matter before applying fixes    
cp ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/wm_nofix.mgz
# Out:
# using voxel position (131, 113, 122) as corpus callosum seed point
# using voxel position (131, 149, 117) as pons seed point
# reading input volume...done.
# searching for cutting planes...INFO: volume does not have linear_transform set nor lta is given by option.-xform.
# INFO: use identity matrix as the talairach transform.
# INFO: use src volume parameters for the talairach volume.
# voxel to talairach voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Calculated talairach cc position (8.94, -13.37, 115.57)
# Using the seed to calculate the cutting plane
# Looking for area (min, max) = (350, 1400)
# area[0] = 577 (min = 350, max = 1400), aspect = 0.42 (min = 0.10, max = 0.75)
# no need to search
# using seed (131, 113, 122), TAL = (8.9, -13.4, 115.6)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# talairach cc position changed to (8.94, -13.37, 115.57)
# Using voxel pons seed point, calculated talairach pons position (8.94, -18.37, 79.57)
# Looking for area (min, max) = (350, 790)
# area[0] = 1981 (min = 350, max = 790), aspect = 0.92 (min = 0.60, max = 1.20)
# need search nearby
# using seed (131, 149, 117), TAL = (8.9, -18.4, 79.6)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# done.
# seed_search_size = 9, min_neighbors = 5
# search rh wm seed point around talairach space:(26.94, -13.37, 115.57) SRC: (113.00, 113.00, 122.00)
# search lh wm seed point around talairach space (-9.06, -13.37, 115.57), SRC: (149.00, 113.00, 122.00)
# filling left hemisphere...
# filling volume: pass 3 of 3...total of 293172 voxels filled...done.
# filling right hemisphere...
# filling volume: pass 3 of 3...total of 293172 voxels filled...done.
# filling degenerate left hemisphere surface locations...
# 206 voxels filled
# 3 voxels filled
# 0 voxels filled
# filling degenerate right hemisphere surface locations...
# 206 voxels filled
# 3 voxels filled
# 0 voxels filled
# refilling left hemisphere...
# filling volume: pass 3 of 3...total of 293381 voxels filled...done.
# refilling right hemisphere...
# filling volume: pass 3 of 3...total of 293381 voxels filled...done.
# combining hemispheres...
# using variable coefficient diffusion to correct hemispheric overlap...
# 26:  292775 ambiguous voxels remaining
# 9:  16326 ambiguous voxels remaining
# 8:  14773 ambiguous voxels remaining
# 7:  14292 ambiguous voxels remaining
# 6:  14090 ambiguous voxels remaining
# 5:  13983 ambiguous voxels remaining
# 4:  13943 ambiguous voxels remaining
# 3:  13909 ambiguous voxels remaining
# 2:  2 ambiguous voxels remaining
# 1:  0 ambiguous voxels remaining
# writing output to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/filled.mgz...
# filling took 0.3 minutes

# %% [markdown]
# #### Tesselate volumes & fix topology (First run)

# %%
# Tesselate
# left hemisphere
mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig.nofix
# right hemisphere
mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig.nofix

# for both hemispheres
for xh in ${HEMI[@]}; do
    # create a version we can edit
    cp ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.orig

    # post-process tesselation
    mris_extract_main_component ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.orig.nofix
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.smoothwm.nofix
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm.nofix ${fsSurf_temp}/${xh}.inflated.nofix
    mris_sphere -q ${fsSurf_temp}/${xh}.inflated.nofix ${fsSurf_temp}/${xh}.qsphere.nofix
    cp ${fsSurf_temp}/${xh}.inflated.nofix ${fsSurf_temp}/${xh}.inflated

    # fix topology
    mris_euler_number ${fsSurf_temp}/${xh}.orig
    mris_remove_intersection ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
done
# Out:
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (yz+):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (yz-):   6 found -   6 modified     |    TOTAL:   7
# pass   2 (yz-):   0 found -   6 modified     |    TOTAL:   7
# pass   1 (xz+):   2 found -   2 modified     |    TOTAL:   9
# pass   2 (xz+):   0 found -   2 modified     |    TOTAL:   9
# pass   1 (xz-):   2 found -   2 modified     |    TOTAL:  11
# pass   2 (xz-):   0 found -   2 modified     |    TOTAL:  11
# Iteration Number : 1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (++):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (++):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (-+):   1 found -   1 modified     |    TOTAL:   2
# pass   2 (-+):   0 found -   1 modified     |    TOTAL:   2
# Iteration Number : 2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 13 (out of 152650: 0.008516)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1294 vertices, 1366 faces
# slice 70: 6267 vertices, 6476 faces
# slice 80: 12869 vertices, 13121 faces
# slice 90: 20859 vertices, 21140 faces
# slice 100: 29027 vertices, 29349 faces
# slice 110: 37334 vertices, 37645 faces
# slice 120: 45492 vertices, 45814 faces
# slice 130: 53196 vertices, 53500 faces
# slice 140: 60185 vertices, 60466 faces
# slice 150: 67150 vertices, 67433 faces
# slice 160: 72065 vertices, 72256 faces
# slice 170: 75887 vertices, 76043 faces
# slice 180: 78211 vertices, 78335 faces
# slice 190: 79515 vertices, 79596 faces
# slice 200: 79992 vertices, 80040 faces
# slice 210: 79992 vertices, 80040 faces
# slice 220: 79992 vertices, 80040 faces
# slice 230: 79992 vertices, 80040 faces
# slice 240: 79992 vertices, 80040 faces
# slice 250: 79992 vertices, 80040 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.orig.nofix
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   4 found -   4 modified     |    TOTAL:   4
# pass   2 (yz-):   0 found -   4 modified     |    TOTAL:   4
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   4
# pass   1 (xz-):   1 found -   1 modified     |    TOTAL:   5
# pass   2 (xz-):   0 found -   1 modified     |    TOTAL:   5
# Iteration Number : 1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (xy-):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 6 (out of 140751: 0.004263)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1544 vertices, 1637 faces
# slice 70: 5991 vertices, 6164 faces
# slice 80: 10814 vertices, 10978 faces
# slice 90: 16341 vertices, 16539 faces
# slice 100: 22117 vertices, 22327 faces
# slice 110: 29704 vertices, 29981 faces
# slice 120: 37482 vertices, 37766 faces
# slice 130: 44943 vertices, 45224 faces
# slice 140: 51580 vertices, 51825 faces
# slice 150: 58379 vertices, 58623 faces
# slice 160: 63285 vertices, 63461 faces
# slice 170: 67164 vertices, 67287 faces
# slice 180: 69426 vertices, 69530 faces
# slice 190: 70978 vertices, 71039 faces
# slice 200: 71532 vertices, 71554 faces
# slice 210: 71532 vertices, 71554 faces
# slice 220: 71532 vertices, 71554 faces
# slice 230: 71532 vertices, 71554 faces
# slice 240: 71532 vertices, 71554 faces
# slice 250: 71532 vertices, 71554 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.orig.nofix
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
#
# counting number of connected components...
#    79992 voxel in cpt #1: X=-48 [v=79992,e=240120,f=160080] located at (-24.915955, -13.905628, 6.847160)
# For the whole surface: X=-48 [v=79992,e=240120,f=160080]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.smoothwm.nofix
# avg radius = 39.9 mm, total surface area = 47401 mm^2
# step 060: RMS=0.053 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.inflated.nofix
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.sulc
# mris_inflate utimesec    14.570462
# mris_inflate stimesec    0.044043
# mris_inflate ru_maxrss   108972
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   25528
# mris_inflate ru_majflt   35
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  8040
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    2005
# mris_inflate ru_nivcsw   21
# inflation took 0.2 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.387...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=177.381, avgs=0
# 005/300: dt: 0.9000, rms radial error=177.131, avgs=0
# 010/300: dt: 0.9000, rms radial error=176.593, avgs=0
# 015/300: dt: 0.9000, rms radial error=175.885, avgs=0
# 020/300: dt: 0.9000, rms radial error=175.077, avgs=0
# 025/300: dt: 0.9000, rms radial error=174.211, avgs=0
# 030/300: dt: 0.9000, rms radial error=173.311, avgs=0
# 035/300: dt: 0.9000, rms radial error=172.394, avgs=0
# 040/300: dt: 0.9000, rms radial error=171.467, avgs=0
# 045/300: dt: 0.9000, rms radial error=170.536, avgs=0
# 050/300: dt: 0.9000, rms radial error=169.605, avgs=0
# 055/300: dt: 0.9000, rms radial error=168.674, avgs=0
# 060/300: dt: 0.9000, rms radial error=167.749, avgs=0
# 065/300: dt: 0.9000, rms radial error=166.827, avgs=0
# 070/300: dt: 0.9000, rms radial error=165.907, avgs=0
# 075/300: dt: 0.9000, rms radial error=164.990, avgs=0
# 080/300: dt: 0.9000, rms radial error=164.076, avgs=0
# 085/300: dt: 0.9000, rms radial error=163.165, avgs=0
# 090/300: dt: 0.9000, rms radial error=162.258, avgs=0
# 095/300: dt: 0.9000, rms radial error=161.355, avgs=0
# 100/300: dt: 0.9000, rms radial error=160.455, avgs=0
# 105/300: dt: 0.9000, rms radial error=159.559, avgs=0
# 110/300: dt: 0.9000, rms radial error=158.666, avgs=0
# 115/300: dt: 0.9000, rms radial error=157.778, avgs=0
# 120/300: dt: 0.9000, rms radial error=156.894, avgs=0
# 125/300: dt: 0.9000, rms radial error=156.014, avgs=0
# 130/300: dt: 0.9000, rms radial error=155.137, avgs=0
# 135/300: dt: 0.9000, rms radial error=154.265, avgs=0
# 140/300: dt: 0.9000, rms radial error=153.398, avgs=0
# 145/300: dt: 0.9000, rms radial error=152.539, avgs=0
# 150/300: dt: 0.9000, rms radial error=151.685, avgs=0
# 155/300: dt: 0.9000, rms radial error=150.835, avgs=0
# 160/300: dt: 0.9000, rms radial error=149.989, avgs=0
# 165/300: dt: 0.9000, rms radial error=149.149, avgs=0
# 170/300: dt: 0.9000, rms radial error=148.313, avgs=0
# 175/300: dt: 0.9000, rms radial error=147.482, avgs=0
# 180/300: dt: 0.9000, rms radial error=146.655, avgs=0
# 185/300: dt: 0.9000, rms radial error=145.833, avgs=0
# 190/300: dt: 0.9000, rms radial error=145.015, avgs=0
# 195/300: dt: 0.9000, rms radial error=144.202, avgs=0
# 200/300: dt: 0.9000, rms radial error=143.394, avgs=0
# 205/300: dt: 0.9000, rms radial error=142.590, avgs=0
# 210/300: dt: 0.9000, rms radial error=141.791, avgs=0
# 215/300: dt: 0.9000, rms radial error=140.996, avgs=0
# 220/300: dt: 0.9000, rms radial error=140.205, avgs=0
# 225/300: dt: 0.9000, rms radial error=139.419, avgs=0
# 230/300: dt: 0.9000, rms radial error=138.638, avgs=0
# 235/300: dt: 0.9000, rms radial error=137.860, avgs=0
# 240/300: dt: 0.9000, rms radial error=137.088, avgs=0
# 245/300: dt: 0.9000, rms radial error=136.319, avgs=0
# 250/300: dt: 0.9000, rms radial error=135.555, avgs=0
# 255/300: dt: 0.9000, rms radial error=134.795, avgs=0
# 260/300: dt: 0.9000, rms radial error=134.039, avgs=0
# 265/300: dt: 0.9000, rms radial error=133.288, avgs=0
# 270/300: dt: 0.9000, rms radial error=132.541, avgs=0
# 275/300: dt: 0.9000, rms radial error=131.798, avgs=0
# 280/300: dt: 0.9000, rms radial error=131.060, avgs=0
# 285/300: dt: 0.9000, rms radial error=130.325, avgs=0
# 290/300: dt: 0.9000, rms radial error=129.595, avgs=0
# 295/300: dt: 0.9000, rms radial error=128.869, avgs=0
# 300/300: dt: 0.9000, rms radial error=128.144, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.37 +- 0.87 (0.00-->10.28) (max @ vno 32165 --> 32978)
# face area 0.04 +- 0.06 (-0.43-->1.50)
# epoch 1 (K=10.0), pass 1, starting sse = 8434.24
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.01/10 = 0.00052
# epoch 2 (K=40.0), pass 1, starting sse = 1260.53
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.01/10 = 0.00077
# epoch 3 (K=160.0), pass 1, starting sse = 182.36
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.03/10 = 0.00272
# epoch 4 (K=640.0), pass 1, starting sse = 64.96
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.06/10 = 0.00626
# final distance error %30.94
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.qsphere.nofix
# mris_sphere utimesec    91.939016
# mris_sphere stimesec    0.055996
# mris_sphere ru_maxrss   109232
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   25532
# mris_sphere ru_majflt   37
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  8408
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1591
# mris_sphere ru_nivcsw   297
# spherical transformation took 0.03 hours
# FSRUNTIME@ mris_sphere  0.0256 hours 1 threads
# euler # = v-e+f = 2g-2: 79992 - 240120 + 160080 = -48 --> 25 holes
#       F =2V-4:          160080 != 159984-4 (-100)
#       2E=3F:            480240 = 480240 (0)
#
# total defect index = 50
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.smoothwm
# avg radius = 39.9 mm, total surface area = 48432 mm^2
# step 060: RMS=0.057 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.sulc
# mris_inflate utimesec    14.271062
# mris_inflate stimesec    0.036017
# mris_inflate ru_maxrss   109208
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   25549
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1487
# mris_inflate ru_nivcsw   9
# inflation took 0.2 minutes
#
# counting number of connected components...
#    71532 voxel in cpt #1: X=-22 [v=71532,e=214662,f=143108] located at (21.793043, -10.847495, 8.217805)
# For the whole surface: X=-22 [v=71532,e=214662,f=143108]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.smoothwm.nofix
# avg radius = 38.3 mm, total surface area = 42274 mm^2
# step 060: RMS=0.043 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.inflated.nofix
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.sulc
# mris_inflate utimesec    13.076639
# mris_inflate stimesec    0.036001
# mris_inflate ru_maxrss   98492
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   22921
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  112
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1802
# mris_inflate ru_nivcsw   6
# inflation took 0.2 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.383...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.257, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.000, avgs=0
# 010/300: dt: 0.9000, rms radial error=177.448, avgs=0
# 015/300: dt: 0.9000, rms radial error=176.723, avgs=0
# 020/300: dt: 0.9000, rms radial error=175.897, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.013, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.096, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.161, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.219, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.273, avgs=0
# 050/300: dt: 0.9000, rms radial error=170.327, avgs=0
# 055/300: dt: 0.9000, rms radial error=169.384, avgs=0
# 060/300: dt: 0.9000, rms radial error=168.443, avgs=0
# 065/300: dt: 0.9000, rms radial error=167.506, avgs=0
# 070/300: dt: 0.9000, rms radial error=166.573, avgs=0
# 075/300: dt: 0.9000, rms radial error=165.644, avgs=0
# 080/300: dt: 0.9000, rms radial error=164.720, avgs=0
# 085/300: dt: 0.9000, rms radial error=163.801, avgs=0
# 090/300: dt: 0.9000, rms radial error=162.885, avgs=0
# 095/300: dt: 0.9000, rms radial error=161.975, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.069, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.168, avgs=0
# 110/300: dt: 0.9000, rms radial error=159.271, avgs=0
# 115/300: dt: 0.9000, rms radial error=158.379, avgs=0
# 120/300: dt: 0.9000, rms radial error=157.492, avgs=0
# 125/300: dt: 0.9000, rms radial error=156.609, avgs=0
# 130/300: dt: 0.9000, rms radial error=155.732, avgs=0
# 135/300: dt: 0.9000, rms radial error=154.859, avgs=0
# 140/300: dt: 0.9000, rms radial error=153.990, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.126, avgs=0
# 150/300: dt: 0.9000, rms radial error=152.267, avgs=0
# 155/300: dt: 0.9000, rms radial error=151.413, avgs=0
# 160/300: dt: 0.9000, rms radial error=150.562, avgs=0
# 165/300: dt: 0.9000, rms radial error=149.717, avgs=0
# 170/300: dt: 0.9000, rms radial error=148.876, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.040, avgs=0
# 180/300: dt: 0.9000, rms radial error=147.208, avgs=0
# 185/300: dt: 0.9000, rms radial error=146.381, avgs=0
# 190/300: dt: 0.9000, rms radial error=145.558, avgs=0
# 195/300: dt: 0.9000, rms radial error=144.740, avgs=0
# 200/300: dt: 0.9000, rms radial error=143.926, avgs=0
# 205/300: dt: 0.9000, rms radial error=143.117, avgs=0
# 210/300: dt: 0.9000, rms radial error=142.312, avgs=0
# 215/300: dt: 0.9000, rms radial error=141.511, avgs=0
# 220/300: dt: 0.9000, rms radial error=140.715, avgs=0
# 225/300: dt: 0.9000, rms radial error=139.924, avgs=0
# 230/300: dt: 0.9000, rms radial error=139.137, avgs=0
# 235/300: dt: 0.9000, rms radial error=138.354, avgs=0
# 240/300: dt: 0.9000, rms radial error=137.575, avgs=0
# 245/300: dt: 0.9000, rms radial error=136.801, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.032, avgs=0
# 255/300: dt: 0.9000, rms radial error=135.266, avgs=0
# 260/300: dt: 0.9000, rms radial error=134.505, avgs=0
# 265/300: dt: 0.9000, rms radial error=133.749, avgs=0
# 270/300: dt: 0.9000, rms radial error=132.996, avgs=0
# 275/300: dt: 0.9000, rms radial error=132.248, avgs=0
# 280/300: dt: 0.9000, rms radial error=131.504, avgs=0
# 285/300: dt: 0.9000, rms radial error=130.764, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.028, avgs=0
# 295/300: dt: 0.9000, rms radial error=129.296, avgs=0
# 300/300: dt: 0.9000, rms radial error=128.568, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.43 +- 0.84 (0.00-->13.79) (max @ vno 46903 --> 46904)
# face area 0.04 +- 0.05 (-0.54-->1.18)
# epoch 1 (K=10.0), pass 1, starting sse = 7490.66
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00021
# epoch 2 (K=40.0), pass 1, starting sse = 1046.23
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00044
# epoch 3 (K=160.0), pass 1, starting sse = 103.26
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.03/10 = 0.00324
# epoch 4 (K=640.0), pass 1, starting sse = 16.23
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.16/14 = 0.01117
# final distance error %28.75
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.qsphere.nofix
# mris_sphere utimesec    89.016048
# mris_sphere stimesec    0.104009
# mris_sphere ru_maxrss   98680
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   22923
# mris_sphere ru_majflt   0
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1405
# mris_sphere ru_nivcsw   699
# spherical transformation took 0.02 hours
# FSRUNTIME@ mris_sphere  0.0248 hours 1 threads
# euler # = v-e+f = 2g-2: 71532 - 214662 + 143108 = -22 --> 12 holes
#       F =2V-4:          143108 != 143064-4 (-48)
#       2E=3F:            429324 = 429324 (0)
#
# total defect index = 24
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.smoothwm
# avg radius = 38.3 mm, total surface area = 43146 mm^2
# step 060: RMS=0.045 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.sulc
# mris_inflate utimesec    13.227760
# mris_inflate stimesec    0.032009
# mris_inflate ru_maxrss   98604
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   22923
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1369
# mris_inflate ru_nivcsw   18
# inflation took 0.2 minutes

# %% [markdown]
# #### Iterate manual adjustments and doing tesselation & topology fix again
# Should look something like this. Keep going (adjust `wm.mgz` using the recon-edit function of Freeview) until you are happy with the result.
#
# ![LH_wm_inflated_lateral](pics/LH_wm_inflated_lateral.png) ![LH_wm_inflated_medial](pics/LH_wm_inflated_medial.png)

# %%
# look at the result and apply fixes in WM definition
# you will want to get rid of weird 'stalks' and 'bridges'
freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz \
    -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated \
    ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated &
# Out:
# [1] 29019

# %%
# redo the tesselation with the freshly fixed WM volume
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/filled.mgz
    
mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig
mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig

for xh in ${HEMI[@]}; do
    mris_extract_main_component ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
    mris_sphere -q ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.qsphere
    
    mris_euler_number ${fsSurf_temp}/${xh}.orig
    mris_remove_intersection ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
    mris_curvature -thresh .999 -n -a 5 -w -distances 10 10 ${fsSurf_temp}/${xh}.inflated
done
# Out:
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.white
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.white
# /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/wm.mgz saved successfully.
# using voxel position (131, 113, 122) as corpus callosum seed point
# using voxel position (131, 149, 117) as pons seed point
# reading input volume...done.
# searching for cutting planes...INFO: volume does not have linear_transform set nor lta is given by option.-xform.
# INFO: use identity matrix as the talairach transform.
# INFO: use src volume parameters for the talairach volume.
# voxel to talairach voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Calculated talairach cc position (8.94, -13.37, 115.57)
# Using the seed to calculate the cutting plane
# Looking for area (min, max) = (350, 1400)
# area[0] = 431 (min = 350, max = 1400), aspect = 0.38 (min = 0.10, max = 0.75)
# no need to search
# using seed (131, 113, 122), TAL = (8.9, -13.4, 115.6)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# talairach cc position changed to (8.94, -13.37, 115.57)
# Using voxel pons seed point, calculated talairach pons position (8.94, -18.37, 79.57)
# Looking for area (min, max) = (350, 790)
# area[0] = 447 (min = 350, max = 790), aspect = 0.85 (min = 0.60, max = 1.20)
# no need to search
# using seed (131, 149, 117), TAL = (8.9, -18.4, 79.6)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# done.
# seed_search_size = 9, min_neighbors = 5
# search rh wm seed point around talairach space:(26.94, -13.37, 115.57) SRC: (113.00, 113.00, 122.00)
# search lh wm seed point around talairach space (-9.06, -13.37, 115.57), SRC: (149.00, 113.00, 122.00)
# filling left hemisphere...
# filling volume: pass 2 of 3...Application asked to unregister timer 0x36000028 which is not registered in this thread. Fix application.
# filling volume: pass 3 of 3...total of 109640 voxels filled...done.
# filling right hemisphere...
# filling volume: pass 3 of 3...total of 109177 voxels filled...done.
# filling degenerate left hemisphere surface locations...
# 440 voxels filled
# 0 voxels filled
# filling degenerate right hemisphere surface locations...
# 525 voxels filled
# 2 voxels filled
# 0 voxels filled
# refilling left hemisphere...
# filling volume: pass 3 of 3...total of 110080 voxels filled...done.
# refilling right hemisphere...
# filling volume: pass 3 of 3...total of 109704 voxels filled...done.
# combining hemispheres...
# writing output to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/mgz/filled.mgz...
# filling took 0.1 minutes
# [1]+  Done                    freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (xz+):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 1 (out of 110082: 0.000908)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1176 vertices, 1243 faces
# slice 70: 6313 vertices, 6527 faces
# slice 80: 11489 vertices, 11660 faces
# slice 90: 17416 vertices, 17639 faces
# slice 100: 23502 vertices, 23714 faces
# slice 110: 31266 vertices, 31567 faces
# slice 120: 39906 vertices, 40208 faces
# slice 130: 47701 vertices, 47988 faces
# slice 140: 54819 vertices, 55067 faces
# slice 150: 61932 vertices, 62184 faces
# slice 160: 67122 vertices, 67305 faces
# slice 170: 71064 vertices, 71183 faces
# slice 180: 73312 vertices, 73396 faces
# slice 190: 74598 vertices, 74640 faces
# slice 200: 75038 vertices, 75048 faces
# slice 210: 75038 vertices, 75048 faces
# slice 220: 75038 vertices, 75048 faces
# slice 230: 75038 vertices, 75048 faces
# slice 240: 75038 vertices, 75048 faces
# slice 250: 75038 vertices, 75048 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.orig
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (+++):   2 found -   2 modified     |    TOTAL:   2
# pass   2 (+++):   0 found -   2 modified     |    TOTAL:   2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   2
# pass   1 (+++):   1 found -   1 modified     |    TOTAL:   3
# pass   2 (+++):   0 found -   1 modified     |    TOTAL:   3
# Iteration Number : 1
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (+-):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (yz-):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 5 (out of 109710: 0.004557)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1371 vertices, 1455 faces
# slice 70: 6333 vertices, 6553 faces
# slice 80: 11355 vertices, 11531 faces
# slice 90: 17309 vertices, 17527 faces
# slice 100: 23457 vertices, 23685 faces
# slice 110: 31332 vertices, 31619 faces
# slice 120: 39450 vertices, 39748 faces
# slice 130: 47106 vertices, 47391 faces
# slice 140: 53834 vertices, 54083 faces
# slice 150: 60852 vertices, 61099 faces
# slice 160: 66056 vertices, 66233 faces
# slice 170: 70027 vertices, 70145 faces
# slice 180: 72240 vertices, 72333 faces
# slice 190: 73840 vertices, 73897 faces
# slice 200: 74350 vertices, 74364 faces
# slice 210: 74350 vertices, 74364 faces
# slice 220: 74350 vertices, 74364 faces
# slice 230: 74350 vertices, 74364 faces
# slice 240: 74350 vertices, 74364 faces
# slice 250: 74350 vertices, 74364 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.orig
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
#
# counting number of connected components...
#    75038 voxel in cpt #1: X=-10 [v=75038,e=225144,f=150096] located at (-27.500280, -11.497082, 8.574336)
# For the whole surface: X=-10 [v=75038,e=225144,f=150096]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.smoothwm
# avg radius = 37.8 mm, total surface area = 42649 mm^2
# step 060: RMS=0.038 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.sulc
# mris_inflate utimesec    13.715600
# mris_inflate stimesec    0.024027
# mris_inflate ru_maxrss   103032
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   24034
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1868
# mris_inflate ru_nivcsw   10
# inflation took 0.2 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.375...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.366, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.112, avgs=0
# 010/300: dt: 0.9000, rms radial error=177.567, avgs=0
# 015/300: dt: 0.9000, rms radial error=176.851, avgs=0
# 020/300: dt: 0.9000, rms radial error=176.036, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.162, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.257, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.334, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.403, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.468, avgs=0
# 050/300: dt: 0.9000, rms radial error=170.533, avgs=0
# 055/300: dt: 0.9000, rms radial error=169.600, avgs=0
# 060/300: dt: 0.9000, rms radial error=168.668, avgs=0
# 065/300: dt: 0.9000, rms radial error=167.740, avgs=0
# 070/300: dt: 0.9000, rms radial error=166.816, avgs=0
# 075/300: dt: 0.9000, rms radial error=165.896, avgs=0
# 080/300: dt: 0.9000, rms radial error=164.979, avgs=0
# 085/300: dt: 0.9000, rms radial error=164.067, avgs=0
# 090/300: dt: 0.9000, rms radial error=163.159, avgs=0
# 095/300: dt: 0.9000, rms radial error=162.256, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.356, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.461, avgs=0
# 110/300: dt: 0.9000, rms radial error=159.571, avgs=0
# 115/300: dt: 0.9000, rms radial error=158.684, avgs=0
# 120/300: dt: 0.9000, rms radial error=157.803, avgs=0
# 125/300: dt: 0.9000, rms radial error=156.925, avgs=0
# 130/300: dt: 0.9000, rms radial error=156.053, avgs=0
# 135/300: dt: 0.9000, rms radial error=155.184, avgs=0
# 140/300: dt: 0.9000, rms radial error=154.320, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.461, avgs=0
# 150/300: dt: 0.9000, rms radial error=152.606, avgs=0
# 155/300: dt: 0.9000, rms radial error=151.756, avgs=0
# 160/300: dt: 0.9000, rms radial error=150.910, avgs=0
# 165/300: dt: 0.9000, rms radial error=150.068, avgs=0
# 170/300: dt: 0.9000, rms radial error=149.231, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.398, avgs=0
# 180/300: dt: 0.9000, rms radial error=147.570, avgs=0
# 185/300: dt: 0.9000, rms radial error=146.746, avgs=0
# 190/300: dt: 0.9000, rms radial error=145.927, avgs=0
# 195/300: dt: 0.9000, rms radial error=145.112, avgs=0
# 200/300: dt: 0.9000, rms radial error=144.302, avgs=0
# 205/300: dt: 0.9000, rms radial error=143.496, avgs=0
# 210/300: dt: 0.9000, rms radial error=142.694, avgs=0
# 215/300: dt: 0.9000, rms radial error=141.897, avgs=0
# 220/300: dt: 0.9000, rms radial error=141.104, avgs=0
# 225/300: dt: 0.9000, rms radial error=140.315, avgs=0
# 230/300: dt: 0.9000, rms radial error=139.531, avgs=0
# 235/300: dt: 0.9000, rms radial error=138.751, avgs=0
# 240/300: dt: 0.9000, rms radial error=137.975, avgs=0
# 245/300: dt: 0.9000, rms radial error=137.204, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.437, avgs=0
# 255/300: dt: 0.9000, rms radial error=135.674, avgs=0
# 260/300: dt: 0.9000, rms radial error=134.915, avgs=0
# 265/300: dt: 0.9000, rms radial error=134.161, avgs=0
# 270/300: dt: 0.9000, rms radial error=133.410, avgs=0
# 275/300: dt: 0.9000, rms radial error=132.664, avgs=0
# 280/300: dt: 0.9000, rms radial error=131.922, avgs=0
# 285/300: dt: 0.9000, rms radial error=131.184, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.450, avgs=0
# 295/300: dt: 0.9000, rms radial error=129.720, avgs=0
# 300/300: dt: 0.9000, rms radial error=128.994, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.39 +- 0.83 (0.00-->9.79) (max @ vno 49861 --> 49879)
# face area 0.04 +- 0.04 (-0.28-->0.71)
# epoch 1 (K=10.0), pass 1, starting sse = 8000.98
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00033
# epoch 2 (K=40.0), pass 1, starting sse = 1137.97
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00032
# epoch 3 (K=160.0), pass 1, starting sse = 105.07
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.03/10 = 0.00256
# epoch 4 (K=640.0), pass 1, starting sse = 10.65
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.16/16 = 0.00970
# final distance error %28.93
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.qsphere
# mris_sphere utimesec    94.646253
# mris_sphere stimesec    0.028001
# mris_sphere ru_maxrss   103216
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   24036
# mris_sphere ru_majflt   0
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1466
# mris_sphere ru_nivcsw   47
# spherical transformation took 0.03 hours
# FSRUNTIME@ mris_sphere  0.0263 hours 1 threads
# euler # = v-e+f = 2g-2: 75038 - 225144 + 150096 = -10 --> 6 holes
#       F =2V-4:          150096 != 150076-4 (-24)
#       2E=3F:            450288 = 450288 (0)
#
# total defect index = 12
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.smoothwm
# avg radius = 37.8 mm, total surface area = 42649 mm^2
# step 060: RMS=0.038 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.sulc
# mris_inflate utimesec    13.700360
# mris_inflate stimesec    0.028017
# mris_inflate ru_maxrss   103032
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   24035
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1871
# mris_inflate ru_nivcsw   5
# inflation took 0.2 minutes
# thresholding curvature at 99.90% level
# normalizing curvature values.
# averaging curvature patterns 5 times.
# sampling 10 neighbors out to a distance of 10 mm
# 83 vertices thresholded to be in k1 ~ [-4.62 0.82], k2 ~ [-0.98 0.15]
# total integrated curvature = -0.435*4pi (-5.463) --> 1 handles
# ICI = 1.4, FI = 16.9, variation=267.394
# 68 vertices thresholded to be in [-0.08 1.33]
# writing Gaussian curvature to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.inflated.K...curvature mean = 0.001, std = 0.019
# 65 vertices thresholded to be in [-2.14 0.37]
# curvature mean = -0.029, std = 0.075
# done.
# writing mean curvature to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/lh.inflated.H...done.
#
# counting number of connected components...
#    74350 voxel in cpt #1: X=-14 [v=74350,e=223092,f=148728] located at (21.804237, -11.280350, 8.189563)
# For the whole surface: X=-14 [v=74350,e=223092,f=148728]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.smoothwm
# avg radius = 38.0 mm, total surface area = 42286 mm^2
# step 060: RMS=0.041 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.sulc
# mris_inflate utimesec    13.513062
# mris_inflate stimesec    0.040014
# mris_inflate ru_maxrss   101984
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   23823
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1856
# mris_inflate ru_nivcsw   20
# inflation took 0.2 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.373...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.349, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.096, avgs=0
# 010/300: dt: 0.9000, rms radial error=177.550, avgs=0
# 015/300: dt: 0.9000, rms radial error=176.833, avgs=0
# 020/300: dt: 0.9000, rms radial error=176.016, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.142, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.235, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.311, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.379, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.443, avgs=0
# 050/300: dt: 0.9000, rms radial error=170.506, avgs=0
# 055/300: dt: 0.9000, rms radial error=169.571, avgs=0
# 060/300: dt: 0.9000, rms radial error=168.638, avgs=0
# 065/300: dt: 0.9000, rms radial error=167.708, avgs=0
# 070/300: dt: 0.9000, rms radial error=166.782, avgs=0
# 075/300: dt: 0.9000, rms radial error=165.860, avgs=0
# 080/300: dt: 0.9000, rms radial error=164.942, avgs=0
# 085/300: dt: 0.9000, rms radial error=164.028, avgs=0
# 090/300: dt: 0.9000, rms radial error=163.119, avgs=0
# 095/300: dt: 0.9000, rms radial error=162.214, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.314, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.418, avgs=0
# 110/300: dt: 0.9000, rms radial error=159.527, avgs=0
# 115/300: dt: 0.9000, rms radial error=158.640, avgs=0
# 120/300: dt: 0.9000, rms radial error=157.757, avgs=0
# 125/300: dt: 0.9000, rms radial error=156.879, avgs=0
# 130/300: dt: 0.9000, rms radial error=156.005, avgs=0
# 135/300: dt: 0.9000, rms radial error=155.136, avgs=0
# 140/300: dt: 0.9000, rms radial error=154.271, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.411, avgs=0
# 150/300: dt: 0.9000, rms radial error=152.555, avgs=0
# 155/300: dt: 0.9000, rms radial error=151.703, avgs=0
# 160/300: dt: 0.9000, rms radial error=150.856, avgs=0
# 165/300: dt: 0.9000, rms radial error=150.013, avgs=0
# 170/300: dt: 0.9000, rms radial error=149.175, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.341, avgs=0
# 180/300: dt: 0.9000, rms radial error=147.512, avgs=0
# 185/300: dt: 0.9000, rms radial error=146.687, avgs=0
# 190/300: dt: 0.9000, rms radial error=145.866, avgs=0
# 195/300: dt: 0.9000, rms radial error=145.050, avgs=0
# 200/300: dt: 0.9000, rms radial error=144.239, avgs=0
# 205/300: dt: 0.9000, rms radial error=143.431, avgs=0
# 210/300: dt: 0.9000, rms radial error=142.628, avgs=0
# 215/300: dt: 0.9000, rms radial error=141.830, avgs=0
# 220/300: dt: 0.9000, rms radial error=141.035, avgs=0
# 225/300: dt: 0.9000, rms radial error=140.246, avgs=0
# 230/300: dt: 0.9000, rms radial error=139.460, avgs=0
# 235/300: dt: 0.9000, rms radial error=138.679, avgs=0
# 240/300: dt: 0.9000, rms radial error=137.902, avgs=0
# 245/300: dt: 0.9000, rms radial error=137.129, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.360, avgs=0
# 255/300: dt: 0.9000, rms radial error=135.596, avgs=0
# 260/300: dt: 0.9000, rms radial error=134.835, avgs=0
# 265/300: dt: 0.9000, rms radial error=134.079, avgs=0
# 270/300: dt: 0.9000, rms radial error=133.328, avgs=0
# 275/300: dt: 0.9000, rms radial error=132.580, avgs=0
# 280/300: dt: 0.9000, rms radial error=131.836, avgs=0
# 285/300: dt: 0.9000, rms radial error=131.097, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.362, avgs=0
# 295/300: dt: 0.9000, rms radial error=129.630, avgs=0
# 300/300: dt: 0.9000, rms radial error=128.903, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.39 +- 0.83 (0.01-->7.25) (max @ vno 29423 --> 29445)
# face area 0.04 +- 0.05 (-0.32-->0.83)
# epoch 1 (K=10.0), pass 1, starting sse = 7968.05
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00025
# epoch 2 (K=40.0), pass 1, starting sse = 1162.89
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00031
# epoch 3 (K=160.0), pass 1, starting sse = 118.34
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.04/10 = 0.00408
# epoch 4 (K=640.0), pass 1, starting sse = 11.79
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.11/13 = 0.00880
# final distance error %28.53
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.qsphere
# mris_sphere utimesec    89.102702
# mris_sphere stimesec    0.060001
# mris_sphere ru_maxrss   102504
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   23828
# mris_sphere ru_majflt   0
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1453
# mris_sphere ru_nivcsw   192
# spherical transformation took 0.02 hours
# FSRUNTIME@ mris_sphere  0.0248 hours 1 threads
# euler # = v-e+f = 2g-2: 74350 - 223092 + 148728 = -14 --> 8 holes
#       F =2V-4:          148728 != 148700-4 (-32)
#       2E=3F:            446184 = 446184 (0)
#
# total defect index = 16
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.smoothwm
# avg radius = 38.0 mm, total surface area = 42286 mm^2
# step 060: RMS=0.041 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.sulc
# mris_inflate utimesec    13.693351
# mris_inflate stimesec    0.044017
# mris_inflate ru_maxrss   101964
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   23820
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1857
# mris_inflate ru_nivcsw   5
# inflation took 0.2 minutes
# thresholding curvature at 99.90% level
# normalizing curvature values.
# averaging curvature patterns 5 times.
# sampling 10 neighbors out to a distance of 10 mm
# 81 vertices thresholded to be in k1 ~ [-7.09 1.01], k2 ~ [-2.83 0.25]
# total integrated curvature = -0.732*4pi (-9.195) --> 2 handles
# ICI = 1.5, FI = 21.3, variation=333.084
# 63 vertices thresholded to be in [-0.15 5.39]
# writing Gaussian curvature to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.inflated.K...curvature mean = 0.001, std = 0.050
# 51 vertices thresholded to be in [-3.09 0.45]
# curvature mean = -0.030, std = 0.096
# done.
# writing mean curvature to /NHP_MRI/Template/NMT/single_subject_scans/Eddy/fsSurf/temp/rh.inflated.H...done.

# %%
# create the spheres (this takes longer so do it only when you're happy with the inflated)
for xh in ${HEMI[@]}; do
    mris_sphere ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.sphere
done

# %% [markdown]
# #### Create a subject directory in your freesurfer subject directory

# %%
# create a freesurfer SUBJECT with the correct folder structure
# NB! $SUBJECTS_DIR should be defined in your ~/.bashrc as the Freesurfer subjects directory
echo 'Creating a subject directory for '${SUBJ}'in:'
echo ${SUBJECTS_DIR}/${SUBJ}
mksubjdirs ${SUBJECTS_DIR}/${SUBJ}

# %% [markdown]
# #### Move files to the Freesurfer subjects directory

# %%
# copy the necessary files for cutting to the subject directory
for xh in ${HEMI[@]}; do
    cp ${fsSurf_temp}/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.smoothwm ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.orig ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.qsphere ${SUBJECTS_DIR}/${SUBJ}/surf/
done

cp ${fsSurf_mgz}/T1.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/T1.mgz
cp ${fsSurf_mgz}/filled.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/filled.mgz
cp ${fsSurf_mgz}/wm.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/wm.mgz
cp ${fsSurf_mgz}/brain.finalsurfs.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brain.finalsurfs.mgz
cp ${fsSurf_mgz}/brainmask.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brainmask.mgz

# %% [markdown]
# Before we can start making the final surfaces we need a little trick to compensate for the low grey/white matter contrast in monkeys. Now that we have a white matter volume we are happy with (if not go back and fix it) we can use it to enhance the GM/WM contrast artificially and bring the voxel values into the range that Freesurfer expects. The difference looks somewhat like this (Left: normal brain, Right: contrast enhanced brain).
#
# ![Brain](pics/brain.png) ![Brain_enh](pics/brain_enhanced.png)

# %% [markdown]
# #### Make a contrast-enhanced brain volume to aid in getting the pial surface

# %%
# Make a folder for this procedure and convert the necessary files to nifti so we can use `fslmaths`
mkdir -p $fsSurf/enh
mri_convert ${fsSurf_mgz}/brain.mgz $fsSurf/enh/brain.nii.gz
mri_convert ${fsSurf_mgz}/wm.mgz $fsSurf/enh/wm.nii.gz

# binarize the wm volume
fslmaths $fsSurf/enh/wm.nii.gz -bin $fsSurf/enh/wm_bin.nii.gz

# divide the voxel value in the original brain volume by **some** value and add **another** value to the white matter only 
# which values you need here is up to you but we want to end with white matter voxels having a value ~110 and grey matter ~60-80
# alternative ways are definitely possible as long as your end result is similar
fslmaths $fsSurf/enh/brain.nii.gz -div 2 $fsSurf/enh/brain2.nii.gz
fslmaths $fsSurf/enh/wm_bin.nii.gz -mul 20 $fsSurf/enh/wm_add.nii.gz
fslmaths $fsSurf/enh/brain2.nii.gz -add $fsSurf/enh/wm_add.nii.gz $fsSurf/enh/brain_enh.nii.gz

# convert the 'enhanced' brain back to mgz
mri_convert $fsSurf/enh/brain_enh.nii.gz ${SUBJECTS_DIR}/${SUBJ}/mri/brain_enh.mgz

# %% [markdown]
# #### Create the surfaces

# %%
# create surfaces
# this will take a while. don't wait for it. go get a coffee, call your mother, or read a paper.
for xh in ${HEMI[@]}; do
    mris_make_surfaces -noaseg -noaparc -T1 brain_enh -orig_wm orig ${SUBJ} ${xh}
    mris_sphere ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.sphere
done

# %% [markdown]
# You should now have nicely looking inflated white matter surfaces and a projection of it onto a sphere surface. They should look somewhat like the following images.
# `freeview -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/lh.sphere &`
#
# ![surfaces_leged](pics/final_surf_legend.png)

# %%
# freeview -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/lh.sphere &
freeview -f ${SUBJECTS_DIR}/${SUBJ}/surf/lh.smoothwm ${SUBJECTS_DIR}/${SUBJ}/surf/lh.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/lh.sphere &

# %%
# check and edit the pial surface
mkdir -p ${SUBJECTS_DIR}/${SUBJ}/pial_edits # create a folder for pial edits
cp -R ${SUBJECTS_DIR}/${SUBJ}/mri ${SUBJECTS_DIR}/${SUBJ}/pial_edits/ 
cp -R ${SUBJECTS_DIR}/${SUBJ}/surf ${SUBJECTS_DIR}/${SUBJ}/pial_edits/

# %%
freeview -v ${SUBJECTS_DIR}/${SUBJ}/pial_edits/mri/T1.mgz ${SUBJECTS_DIR}/${SUBJ}/pial_edits/mri/brain_enh.mgz \
    -f ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/lh.white:edgecolor=yellow ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/lh.pial:edgecolor=red \
    ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/rh.white:edgecolor=yellow ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/rh.pial:edgecolor=red &

# %%
# NB! If you adjustments to the brainmask (which probably isn't necessary if NMT segmentation worked well) 
# don't forget to copy back the adjusted brain_enh for re-generation of the pial surface 
cp ${SUBJECTS_DIR}/${SUBJ}/pial_edits/mri/brain_enh.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brain_enh.mgz

# %%
# regenerate the pial surface
for xh in ${HEMI[@]}; do
    mris_make_surfaces  -noaseg -noaparc -orig_white white -orig_pial white -nowhite -mgz -T1 brain_enh ${SUBJ} ${xh}
done

# %%
# create midcortical surface by growing the white matter halfway towards the pial surface
for xh in ${HEMI[@]}; do
    mris_expand -thickness ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white 0.5 ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid
done

# %%
# Fix topology, smooth & inflate the final surfaces
for xh in ${HEMI[@]}; do    
    mris_euler_number ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white
    mris_remove_intersection ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white
    mris_smooth -n 3 -nw ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.smoothwm
    
    mris_euler_number ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.pial
    mris_remove_intersection ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.pial ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.pial
    mris_smooth -n 3 -nw ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.pial ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.smoothpial
    
    mris_euler_number ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid
    mris_remove_intersection ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid
    mris_smooth -n 3 -nw ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.smoothgraymid
    
    mris_inflate ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.smoothwm ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated
    mris_curvature -thresh .999 -n -a 5 -w -distances 10 10 ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated
    mris_sphere ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.sphere
done

# %% [markdown]
# #### Cut surfaces and create flatmaps
#
# The cells below will load the inflated hemispheres in tksurfer where you can make the cuts to create the flatmaps.
#
# For the full hemisphere make cuts on the medial wall. One cut enclosing the midline and five additional relaxation cuts.
# Mark a point on the part of the surface you want to keep and save patch as `?h.full.patch.3d` (replace '?' with 'l' and 'r' respectively)
#
# ![Cut_full](pics/Cut_full.png)
#
# For an occipital patch make one cut on the medial wall along the calcarine sulcus. Use 3 points to select a coronal cutting plane, and a fourth point to select which part of the surface you want to keep and save as `?h.occip.patch.3d`
#
# ![Cut_occip1](pics/Cut_occip1.png) ![Cut_occip1](pics/Cut_occip2.png)

# %%
# left
#tksurfer ${SUBJ} lh inflated -curv
tksurfer ${SUBJ} lh inflated -gray

# %%
# right
#tksurfer ${SUBJ} rh inflated -curv
tksurfer ${SUBJ} rh inflated -gray

# %%
# Time for another coffee, you are not going to want to wait for this to finish while staring at its progress
cd ${SUBJECTS_DIR}/${SUBJ}/surf/
for xh in ${HEMI[@]}; do
    mris_flatten -w 0 -distances 20 7 ${xh}.full.patch.3d  ${xh}.full.patch.flat
    mris_flatten -w 0 -distances 20 7 ${xh}.occip.patch.3d  ${xh}.occip.patch.flat
done

# %% [markdown]
# If everything went well, you now have flatmaps of the white matter surface.
# They should look somewhat like this:
#
# **Full hemisphere (rh)**
# ![RH_flatmap](pics/RH_Flat_Sulci_gray_nolegend.png) ![RH_flatmap_legend](pics/RH_Flat_Sulci_gray_legend.png)
#
# **Occipital (rh)** (functional areas are guesstimates based on anatomy)
# ![RH_occip](pics/RH_Flat_occip_gray_nolegend.png) ![RH_occip_gray_legend](pics/RH_Flat_occip_gray_legend.png)
#
# It is of course also possible to make **any** other funtionally relevant cutting pattern to extract a flatmap of a piece of cortex. The method is the same.

# %%
# check your result
#tksurfer ${SUBJ} rh inflated -patch rh.full.patch.flat -curv # for a red/green curvature map
tksurfer ${SUBJ} lh inflated -patch lh.full.patch.flat -gray # for a gray curvature map

# %% [markdown]
# #### Convert Freesurfer surfaces to Gifti
# Other software may like this better.

# %%
mkdir -p gii
for xh in ${HEMI[@]}; do
    mris_convert ${xh}.white ./gii/${xh}.white.gii
    mris_convert ${xh}.graymid ./gii/${xh}.graymid.gii
    mris_convert ${xh}.pial ./gii/${xh}.pial.gii
    mris_convert ${xh}.inflated ./gii/${xh}.inflated.gii

    mris_convert ${xh}.smoothwm ./gii/${xh}.smoothwm.gii
    mris_convert ${xh}.smoothgraymid ./gii/${xh}.smoothgraymid.gii
    mris_convert ${xh}.smoothpial ./gii/${xh}.smoothpial.gii
    
    mris_convert -p -c ${xh}.curv ${xh}.full.patch.flat ./gii/${xh}.full.patch.flat.gii
    mris_convert -p -c ${xh}.curv ${xh}.occip.patch.flat ./gii/${xh}.occip.patch.flat.gii
done

# %% [markdown]
# #### Copy Freesurfer results back to NMT template folder

# %%
cp -r ${SUBJECTS_DIR}/${SUBJ}/surf ${fsSurf}/surf

# %%
# return to startpath
cd ${startpath}

# %% [markdown]
# ----
# ----
# ## **Step 4 (OPTIONAL): Create additional surfaces using Connectome Workbench.**
# This should not be necessary at all. Try the Freesurfer approach and a conversion to gifti with `mris_convert` first (as explained above)
#
# ----
# ----
#
# ### Requirements
#   - Connectome Workbench (https://www.humanconnectome.org/software/connectome-workbench)

# %%
# THIS SHOULDN'T BE NECESSARY SINCE WE'RE GETTINGS THESE OUTPUTS ALSO FROM THE FREESURFER PIPELINE !! #

# set path to where you want the results
wbSurf_path=${NMT_path}/single_subject_scans/${SUBJ}/wbSurf

echo 'Extracting surfaces from segmentation'
cd ${wbSurf_path}

# create surfaces
IsoSurface -input ${NMT_ss_path}/NMT_${SUBJ}_process/${SUBJ}_segmentation.nii.gz \
    -isorois -o_gii surf

# rename to something recognizable
mv surf.k2.gii gm.surf.gii # gm surface
mv surf.k3.gii wm.surf.gii # wm surface

# Smooth the surfaces a bit
echo 'Smoothing the surfaces a bit' 
wb_command -surface-smoothing wm.surf.gii 0.5 1 wm_sm.surf.gii
wb_command -surface-smoothing gm.surf.gii 0.5 1 gm_sm.surf.gii

# inflate the surfaces
echo 'Inflating the surfaces'
wb_command -surface-generate-inflated \
    wm_sm.surf.gii infl_wm_sm.surf.gii vinfl_wm_sm.surf.gii
wb_command -surface-generate-inflated \
    gm_sm.surf.gii infl_gm_sm.surf.gii vinfl_gm_sm.surf.gii

# view the result in your favorite viewer
echo 'Inspect the surfaces in a viewer'
freeview -f wm_sm.surf.gii infl_wm_sm.surf.gii vinfl_wm_sm.surf.gii \
    gm_sm.surf.gii infl_gm_sm.surf.gii vinfl_gm_sm.surf.gii
