# %% [markdown]
# # **Create Single Monkey Surfaces**

# %% [markdown]
# This notebook will guide you through the procedure to create single monkey surface representations in four steps (some are optional):
#
# 1. **(OPTIONAL)** Average multiple T1 scans from the same animal. (takes seconds)
# 2. Segment the (averaged) T1 of an individual animal using the NMT template as a prior. (takes many hours)
# 3. Create surfaces and flatmaps using Freesurfer. (takes minutes to hours depending on segmentation quality at the start)
# 4. **(OPTIONAL)** Create additional surfaces with Connectome Workbench. (takes minutes)

# %% [markdown]
# ## Initiate
# Setting a few environment variables here so we can actually run code from this notebook

# %%
SUBJ=Danny  # Name of the animal you are going to process
NMT_path=/NHP_MRI/Template/NMT # path to the template folder
startpath=pwd

# %% [markdown]
# ## **Step 1: Average multiple T1 scans**
# ### Requirements:
# - Freesurfer installation (https://surfer.nmr.mgh.harvard.edu/)
# - NIH Macaque Template (https://github.com/jms290/NMT)
# - One or more high resolution anatomical scans
#
# - The `average_multiple_t1.sh ` script

# %% [markdown]
# ### Procedure
# - Create a folder for your subject in the NIH Macaque Template folder as
#
# `<>/NHP_MRI/Template/NMT/single_subject_scans/<SUBJECT>`
#
# - Inside this folder, create a subfolder with all individual T1 scan for this subject, e.g.
#
# `<>/NHP_MRI/Template/NMT/single_subject_scans/<SUBJECT>/<T1_FLD>/*.nii.gz`
#
# - Copy the script `average_multiple_t1.sh` to the `<SUBJECT>` folder as well.
#
# - Run this script with the name of the `<T1_FLD>` as input:
#
# `$ ./average_multiple_t1.sh <T1_FLD>`
#
#
# - The script will:
#
#     - Correct for having the monkey in the sphinx position
#     - Resample each T1 to 0.5 mm isotropic voxels
#     - Reorient the colume for correct display in FSL (e.g., with FSLEyes)
#     - Normalize the contrast gradient
#     - Average the multiple T1's together using motion correction to account for small differences
#
#
# - When the script is done, there should be a `<SUBJECT>.nii.gz` file in the root `<SUBJECT>` folder.

# %%
NMT_ss_path=${NMT_path}/single_subject_scans/${SUBJ}
mkdir -p ${NMT_ss_path}
mkdir -p ${NMT_path}/single_subject_scans/${SUBJ}/T1s
echo Copy the T1 files to ${NMT_path}/single_subject_scans/${SUBJ}/T1s

# %%
cp ${NMT_path}/single_subject_scans/average_multiple_t1.sh \
    ${NMT_path}/single_subject_scans/${SUBJ}/
cd ${NMT_path}/single_subject_scans/${SUBJ}/
./average_multiple_t1.sh T1s

# %% [markdown]
# ## **Step 2: Segment the single subject anatomy using the NMT template as a prior**
# ### Requirements
#   - NIH Macaque Template (https://github.com/jms290/NMT)
#   - ANTS (http://stnava.github.io/ANTs/)
#   - AFNI (https://afni.nimh.nih.gov/)
#
# ### Procedure
# This will segment and process the single-subject anatomical and warp the D99 atlas (https://afni.nimh.nih.gov/Macaque) to your individual anatomy.
#
# - Navigate to `<>/NHP_MRI/Template/NMT/single_subject_scans` in your terminal
#
# - There should be a folder `<SUBJECT>` containing a T1 named `<SUBJECT>.nii.gz` (Step 1 produces this)
#
# - Run the `align_and_process_singlesubject.sh` script with input `<SUBJECT>`:
#
# - The following 2 steps can be executed together by running: `$ ./create_ss_atlas.sh <SUBJECT>`
#
#     - Extracting single ROI masks from the warped atlas: `./extract_ROI.sh <SUBJECT>`
#
#     - Creating a label-file that makes the warped atlas usable in FSLEyes: `./create_xml.sh <SUBJECT>`

# %%
cd ${NMT_path}/single_subject_scans
./align_and_process_singlesubject.sh ${SUBJ}
./create_ss_atlas ${SUBJ}

# %% [markdown]
# ## **Step 3: Create surfaces and flatmaps using Freesurfer**

# %% [markdown]
# ### Requirements
# - Freesurfer installation (https://surfer.nmr.mgh.harvard.edu/)
# - Segmented individual subject T1

# %% [markdown]
# ### Procedure
# #### Create folders & copy files

# %%
#NMT_src=${NMT_path}/single_subject_scans/${SUBJ}/NMT_${SUBJ}_process 
NMT_src=${NMT_path}/single_subject_scans/${SUBJ}/NMT_${SUBJ}_process/manual_adjust # danny 
# adjust this if you have manually adjusted and saved to a different folder

fsSurf=${NMT_path}/single_subject_scans/${SUBJ}/fsSurf
mkdir -p ${fsSurf}

fsSurf_src=${fsSurf}/src
fsSurf_mgz=${fsSurf}/mgz
fsSurf_temp=${fsSurf}/temp
mkdir -p ${fsSurf_src}
mkdir -p ${fsSurf_mgz}
mkdir -p ${fsSurf_temp}

# source files
cp ${NMT_src}/${SUBJ}_N4.nii.gz ${fsSurf_src}/T1.nii.gz
cp ${NMT_src}/${SUBJ}_brain.nii.gz ${fsSurf_src}/brain.nii.gz
cp ${NMT_src}/${SUBJ}_brain.nii.gz ${fsSurf_src}/brainmask.nii.gz # freesurfer brainmask aren't actually masks
cp ${NMT_src}/${SUBJ}_segmentation_WM.nii.gz ${fsSurf_src}/wm.nii.gz

# copy source files again but keep these original (for others the header will be changed to 'fake' 1 mm voxels)
mkdir -p ${fsSurf_src}/org
cp ${fsSurf_src}/*.nii.gz ${fsSurf_src}/org/

# %% [markdown]
# #### Change headers to mimic 1mm isotropic voxels & make mgz files

# %%
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/T1.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brain.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brainmask.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/wm.nii.gz

mri_convert -c ${fsSurf_src}/T1.nii.gz ${fsSurf_mgz}/T1.mgz
mri_convert -c ${fsSurf_src}/brain.nii.gz ${fsSurf_mgz}/brain.mgz
mri_convert -c ${fsSurf_src}/brainmask.nii.gz ${fsSurf_mgz}/brainmask.mgz
mri_convert -c ${fsSurf_src}/wm.nii.gz ${fsSurf_mgz}/wm.mgz

mri_mask -T 5 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/brainmask.mgz ${fsSurf_mgz}/brain.finalsurfs.mgz

# %% [markdown]
# #### Get corpus callosum and pons voxel coordinates
# Corpus callosum:
# ![CC](pics/CC_coordinates.png)
#
# Pons:
# ![PONS](pics/PONS_coordinates.png)

# %%
# Inspect volume to get voxel coordinates
freeview -v ${fsSurf_mgz}/brain.mgz &

# %%
CC=(127 114 129)
PONS=(124 148 119)

# %% [markdown]
# #### Fill the white matter volume & copy for fixing

# %%
# Fill WM
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/filled.mgz
    
cp ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/wm_nofix.mgz

# %% [markdown]
# #### Tesselate volumes & fix topology (First run)

# %%
# left
mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig.nofix
# right
mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig.nofix

HEMI=(lh rh) # array to loop over hemispheres
for xh in ${HEMI[@]}; do
    cp ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.orig

    # post-process tesselation
    mris_extract_main_component ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.orig.nofix
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.smoothwm.nofix
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm.nofix ${fsSurf_temp}/${xh}.inflated.nofix
    mris_sphere -q ${fsSurf_temp}/${xh}.inflated.nofix ${fsSurf_temp}/${xh}.qsphere.nofix
    cp ${fsSurf_temp}/${xh}.inflated.nofix ${fsSurf_temp}/${xh}.inflated

    # fix topology
    mris_euler_number ${fsSurf_temp}/${xh}.orig
    mris_remove_intersection ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
done

# %% [markdown]
# #### Iterate manual adjustments and doing tesselation & topology fix again
# Should look something like this. Keep going (adjust wm.mgz using the recon-edit function of Freeview) until you are happy with the result.
#
# ![LH_wm_inflated](pics/LH_wm_inflated.png) ![RH_wm_inflated](pics/RH_in_wm_inflated.png)

# %%
# look at the result and apply fixes in WM definition
freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz \
    -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated \
    ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated &

# %%
# redo the tesselation with the fixed WM volume
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/filled.mgz
    
mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig
mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig

for xh in ${HEMI[@]}; do
    mris_extract_main_component ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
    mris_sphere -q ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.qsphere
    
    mris_euler_number ${fsSurf_temp}/${xh}.orig
    mris_remove_intersection ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
    mris_curvature -thresh .999 -n -a 5 -w -distances 10 10 ${fsSurf_temp}/${xh}.inflated
    mris_sphere ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.sphere
done
echo 'TESSELATION DONE!'

# %%
# create sphere surface
for xh in ${HEMI[@]}; do
    mris_sphere ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.sphere
done

# %% [markdown]
# #### Create a subject directory in your freesurfer subject directory

# %%
# create a freesurfer SUBJECT with the correct folder structure
# NB! $SUBJECTS_DIR should be defined in your ~/.bashrc as the Freesurfer subjects directory
echo 'Creating a subject directory for '${SUBJ}'in:'
echo ${SUBJECTS_DIR}/${SUBJ}
mksubjdirs ${SUBJECTS_DIR}/${SUBJ}

# %% [markdown]
# #### Cut surfaces and create flatmaps

# %%
# copy the necessary files for cutting to the subject directory
for xh in ${HEMI[@]}; do
    cp ${fsSurf_temp}/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.smoothwm ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.orig ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.qsphere ${SUBJECTS_DIR}/${SUBJ}/surf/
done

cp ${fsSurf_mgz}/T1.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/T1.mgz
cp ${fsSurf_mgz}/filled.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/filled.mgz
cp ${fsSurf_mgz}/wm.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/wm.mgz
cp ${fsSurf_mgz}/brain.finalsurfs.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brain.finalsurfs.mgz
cp ${fsSurf_mgz}/brainmask.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brainmask.mgz

# %%
mris_make_surfaces -noaseg -noaparc -T1 brain -orig_white orig -orig_pial orig ${SUBJ} lh
# Out:
# not using aseg volume to prevent surfaces crossing the midline
# not using aparc to prevent surfaces crossing the midline
# using brain as T1 volume...
# using orig starting white location...
# using orig starting pial locations...
# $Id: mris_make_surfaces.c,v 1.164.2.4 2016/12/13 22:26:32 zkaufman Exp $
# $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/filled.mgz...
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/brain.mgz...
# resampling filled volume to be in voxel register with T1
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/wm.mgz...
# resampling wm volume to be in voxel register with T1
# 315762 bright wm thresholded.
# 525282 bright non-wm voxels segmented.
# reading original surface position from /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.orig...
# computing class statistics...
# border white:    159857 voxels (0.95%)
# border gray      171366 voxels (1.02%)
# WM (109.0): 110.0 +- 0.1 [91.0 --> 110.0]
# GM (95.0) : 91.6 +- 15.8 [30.0 --> 110.0]
# using class modes intead of means, discounting robust sigmas....
# intensity peaks found at WM=110+-0.9,    GM=167+-19.1
# setting MIN_GRAY_AT_WHITE_BORDER to 151.2 (was 70)
# setting MAX_BORDER_WHITE to 110.1 (was 105)
# setting MIN_BORDER_WHITE to 167.0 (was 85)
# setting MAX_CSF to 135.4 (was 40)
# setting MAX_GRAY to 109.9 (was 95)
# setting MAX_GRAY_AT_CSF_BORDER to 151.2 (was 75)
# setting MIN_GRAY_AT_CSF_BORDER to 119.5 (was 40)
# mean inside = 120.5, mean outside = 167.4
# inverted contrast detected....
# smoothing surface for 5 iterations...
# reading initial white vertex positions from orig...
# repositioning cortical surface to gray/white boundary
# smoothing T1 volume with sigma = 2.000
# vertex spacing 1.14 +- 0.20 (1.00-->1.41) (max @ vno 0 --> 130)
# face area 0.50 +- 0.00 (0.50-->0.50)
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=2.0, host=unkno, nav=4, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# complete_dist_mat 0
# rms 0
# smooth_averages 0
# remove_neg 0
# ico_order 0
# which_surface 0
# target_radius 0.000000
# nfields 0
# scale 0.000000
# desired_rms_height 0.000000
# momentum 0.000000
# nbhd_size 0
# max_nbrs 0
# niterations 25
# nsurfaces 0
# SURFACES 3
# flags 0 (0)
# use curv 0
# no sulc 0
# no rigid align 0
# mris->nsize 2
# mris->hemisphere 0
# randomSeed 0
#
# 000: dt: 0.0000, sse=468101.1, rms=nan
# 001: dt: 0.5000, sse=544093.3, rms=nan (nan%)
# 002: dt: 0.5000, sse=581335.4, rms=nan (nan%)
# 003: dt: 0.5000, sse=582868.0, rms=nan (nan%)
# 004: dt: 0.5000, sse=581194.0, rms=nan (nan%)
# 005: dt: 0.5000, sse=580082.9, rms=nan (nan%)
# 006: dt: 0.5000, sse=579989.2, rms=nan (nan%)
# 007: dt: 0.5000, sse=578558.3, rms=nan (nan%)
# 008: dt: 0.5000, sse=578032.9, rms=nan (nan%)
# 009: dt: 0.5000, sse=578534.2, rms=nan (nan%)
# 010: dt: 0.5000, sse=583428.8, rms=nan (nan%)
# 011: dt: 0.5000, sse=581016.2, rms=nan (nan%)
# 012: dt: 0.5000, sse=579336.8, rms=nan (nan%)
# 013: dt: 0.5000, sse=580109.7, rms=nan (nan%)
# 014: dt: 0.5000, sse=585954.8, rms=nan (nan%)
# 015: dt: 0.5000, sse=580634.0, rms=nan (nan%)
# 016: dt: 0.5000, sse=581991.5, rms=nan (nan%)
# 017: dt: 0.5000, sse=580902.9, rms=nan (nan%)
# 018: dt: 0.5000, sse=584667.6, rms=nan (nan%)
# 019: dt: 0.5000, sse=581906.9, rms=nan (nan%)
# 020: dt: 0.5000, sse=582624.1, rms=nan (nan%)
# 021: dt: 0.5000, sse=583010.1, rms=nan (nan%)
# 022: dt: 0.5000, sse=583963.2, rms=nan (nan%)
# 023: dt: 0.5000, sse=584653.6, rms=nan (nan%)
# 024: dt: 0.5000, sse=585583.3, rms=nan (nan%)
# 025: dt: 0.5000, sse=586587.6, rms=nan (nan%)
# positioning took 1.3 minutes
# smoothing T1 volume with sigma = 1.000
# vertex spacing 0.83 +- 0.22 (0.09-->2.41) (max @ vno 24034 --> 24051)
# face area 0.50 +- 0.22 (0.00-->1.72)
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=1.0, host=unkno, nav=2, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=332552.3, rms=nan
# 026: dt: 0.5000, sse=334525.9, rms=nan (nan%)
# 027: dt: 0.5000, sse=332329.9, rms=nan (nan%)
# 028: dt: 0.5000, sse=333571.3, rms=nan (nan%)
# 029: dt: 0.5000, sse=333034.9, rms=nan (nan%)
# 030: dt: 0.5000, sse=332811.6, rms=nan (nan%)
# 031: dt: 0.5000, sse=335602.4, rms=nan (nan%)
# 032: dt: 0.5000, sse=340631.7, rms=nan (nan%)
# 033: dt: 0.5000, sse=333796.9, rms=nan (nan%)
# 034: dt: 0.5000, sse=334912.1, rms=nan (nan%)
# 035: dt: 0.5000, sse=340588.4, rms=nan (nan%)
# 036: dt: 0.5000, sse=335151.4, rms=nan (nan%)
# 037: dt: 0.5000, sse=335375.9, rms=nan (nan%)
# 038: dt: 0.5000, sse=336117.0, rms=nan (nan%)
# 039: dt: 0.5000, sse=338126.2, rms=nan (nan%)
# 040: dt: 0.5000, sse=336452.1, rms=nan (nan%)
# 041: dt: 0.5000, sse=340213.3, rms=nan (nan%)
# 042: dt: 0.5000, sse=337038.3, rms=nan (nan%)
# 043: dt: 0.5000, sse=340208.6, rms=nan (nan%)
# 044: dt: 0.5000, sse=338510.2, rms=nan (nan%)
# 045: dt: 0.5000, sse=340709.0, rms=nan (nan%)
# 046: dt: 0.5000, sse=338356.8, rms=nan (nan%)
# 047: dt: 0.5000, sse=339225.9, rms=nan (nan%)
# 048: dt: 0.5000, sse=341423.1, rms=nan (nan%)
# 049: dt: 0.5000, sse=340224.6, rms=nan (nan%)
# 050: dt: 0.5000, sse=342660.6, rms=nan (nan%)
# positioning took 1.3 minutes
# smoothing T1 volume with sigma = 0.500
# vertex spacing 0.79 +- 0.22 (0.03-->2.72) (max @ vno 24034 --> 24051)
# face area 0.28 +- 0.13 (0.00-->1.74)
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.5, host=unkno, nav=1, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=310994.6, rms=nan
# 051: dt: 0.5000, sse=309218.2, rms=nan (nan%)
# 052: dt: 0.5000, sse=308138.4, rms=nan (nan%)
# 053: dt: 0.5000, sse=309201.9, rms=nan (nan%)
# 054: dt: 0.5000, sse=310789.6, rms=nan (nan%)
# 055: dt: 0.5000, sse=310046.9, rms=nan (nan%)
# 056: dt: 0.5000, sse=315143.6, rms=nan (nan%)
# 057: dt: 0.5000, sse=310604.3, rms=nan (nan%)
# 058: dt: 0.5000, sse=311526.8, rms=nan (nan%)
# 059: dt: 0.5000, sse=317419.2, rms=nan (nan%)
# 060: dt: 0.5000, sse=311366.6, rms=nan (nan%)
# 061: dt: 0.5000, sse=315744.8, rms=nan (nan%)
# 062: dt: 0.5000, sse=312432.6, rms=nan (nan%)
# 063: dt: 0.5000, sse=314248.6, rms=nan (nan%)
# 064: dt: 0.5000, sse=314173.2, rms=nan (nan%)
# 065: dt: 0.5000, sse=312873.4, rms=nan (nan%)
# 066: dt: 0.5000, sse=313830.9, rms=nan (nan%)
# 067: dt: 0.5000, sse=319069.7, rms=nan (nan%)
# 068: dt: 0.5000, sse=315629.2, rms=nan (nan%)
# 069: dt: 0.5000, sse=314879.5, rms=nan (nan%)
# 070: dt: 0.5000, sse=316174.5, rms=nan (nan%)
# 071: dt: 0.5000, sse=315358.4, rms=nan (nan%)
# 072: dt: 0.5000, sse=314627.3, rms=nan (nan%)
# 073: dt: 0.5000, sse=318242.5, rms=nan (nan%)
# 074: dt: 0.5000, sse=316593.9, rms=nan (nan%)
# 075: dt: 0.5000, sse=316291.1, rms=nan (nan%)
# positioning took 1.3 minutes
# smoothing T1 volume with sigma = 0.250
# vertex spacing 0.77 +- 0.23 (0.03-->2.57) (max @ vno 24034 --> 24051)
# face area 0.26 +- 0.13 (0.00-->1.89)
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.2, host=unkno, nav=0, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=292782.0, rms=nan
# 076: dt: 0.5000, sse=294785.6, rms=nan (nan%)
# 077: dt: 0.5000, sse=296626.3, rms=nan (nan%)
# 078: dt: 0.5000, sse=293803.8, rms=nan (nan%)
# 079: dt: 0.5000, sse=295644.6, rms=nan (nan%)
# 080: dt: 0.5000, sse=296994.4, rms=nan (nan%)
# 081: dt: 0.5000, sse=297056.3, rms=nan (nan%)
# 082: dt: 0.5000, sse=296620.8, rms=nan (nan%)
# 083: dt: 0.5000, sse=299425.6, rms=nan (nan%)
# 084: dt: 0.5000, sse=297027.3, rms=nan (nan%)
# 085: dt: 0.5000, sse=295170.2, rms=nan (nan%)
# 086: dt: 0.5000, sse=296439.4, rms=nan (nan%)
# 087: dt: 0.5000, sse=297317.3, rms=nan (nan%)
# 088: dt: 0.5000, sse=295709.3, rms=nan (nan%)
# 089: dt: 0.5000, sse=297759.6, rms=nan (nan%)
# 090: dt: 0.5000, sse=300852.0, rms=nan (nan%)
# 091: dt: 0.5000, sse=303120.1, rms=nan (nan%)
# 092: dt: 0.5000, sse=297854.6, rms=nan (nan%)
# 093: dt: 0.5000, sse=302054.6, rms=nan (nan%)
# 094: dt: 0.5000, sse=297638.9, rms=nan (nan%)
# 095: dt: 0.5000, sse=304130.5, rms=nan (nan%)
# 096: dt: 0.5000, sse=301690.0, rms=nan (nan%)
# 097: dt: 0.5000, sse=301240.5, rms=nan (nan%)
# 098: dt: 0.5000, sse=298448.5, rms=nan (nan%)
# 099: dt: 0.5000, sse=303617.9, rms=nan (nan%)
# 100: dt: 0.5000, sse=307507.1, rms=nan (nan%)
# positioning took 1.3 minutes
# writing white matter surface to /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.white...
# writing smoothed curvature to lh.curv
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.curv
# writing smoothed area to lh.area
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.area
# vertex spacing 0.74 +- 0.23 (0.02-->2.28) (max @ vno 66373 --> 66888)
# face area 0.24 +- 0.12 (0.00-->1.72)
# smoothing surface for 5 iterations...
# reading initial pial vertex positions from orig...
# repositioning cortical surface to gray/csf boundary.
# smoothing T1 volume with sigma = 2.000
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# averaging target values for 5 iterations...
# perforing initial smooth deformation to move away from white surface
# tol=1.0e-04, sigma=2.0, host=unkno, nav=16, nbrs=2, l_surf_repulse=1.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.05
# 000: dt: 0.0000, sse=468101.1, rms=nan
# 001: dt: 0.0500, sse=481538.8, rms=nan (nan%)
# 002: dt: 0.0500, sse=494402.0, rms=nan (nan%)
# 003: dt: 0.0500, sse=506488.9, rms=nan (nan%)
# 004: dt: 0.0500, sse=517656.5, rms=nan (nan%)
# 005: dt: 0.0500, sse=527807.8, rms=nan (nan%)
# 006: dt: 0.0500, sse=536899.1, rms=nan (nan%)
# 007: dt: 0.0500, sse=544932.9, rms=nan (nan%)
# 008: dt: 0.0500, sse=551946.5, rms=nan (nan%)
# 009: dt: 0.0500, sse=558005.0, rms=nan (nan%)
# 010: dt: 0.0500, sse=563196.0, rms=nan (nan%)
# positioning took 0.5 minutes
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# tol=1.0e-04, sigma=2.0, host=unkno, nav=16, nbrs=2, l_surf_repulse=1.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.05
# 000: dt: 0.0000, sse=402867.8, rms=nan
# 011: dt: 0.0500, sse=406024.7, rms=nan (nan%)
# 012: dt: 0.0500, sse=408691.4, rms=nan (nan%)
# 013: dt: 0.0500, sse=410938.3, rms=nan (nan%)
# 014: dt: 0.0500, sse=412822.4, rms=nan (nan%)
# 015: dt: 0.0500, sse=414406.9, rms=nan (nan%)
# 016: dt: 0.0500, sse=415722.7, rms=nan (nan%)
# 017: dt: 0.0500, sse=416812.3, rms=nan (nan%)
# 018: dt: 0.0500, sse=417712.8, rms=nan (nan%)
# 019: dt: 0.0500, sse=418453.0, rms=nan (nan%)
# 020: dt: 0.0500, sse=419061.9, rms=nan (nan%)
# positioning took 0.5 minutes
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# tol=1.0e-04, sigma=2.0, host=unkno, nav=16, nbrs=2, l_surf_repulse=1.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.05
# 000: dt: 0.0000, sse=376123.8, rms=nan
# 021: dt: 0.0500, sse=376575.5, rms=nan (nan%)
# 022: dt: 0.0500, sse=376951.8, rms=nan (nan%)
# 023: dt: 0.0500, sse=377267.1, rms=nan (nan%)
# 024: dt: 0.0500, sse=377538.1, rms=nan (nan%)
# 025: dt: 0.0500, sse=377774.3, rms=nan (nan%)
# 026: dt: 0.0500, sse=377983.3, rms=nan (nan%)
# 027: dt: 0.0500, sse=378164.6, rms=nan (nan%)
# 028: dt: 0.0500, sse=378334.3, rms=nan (nan%)
# 029: dt: 0.0500, sse=378486.1, rms=nan (nan%)
# 030: dt: 0.0500, sse=378634.7, rms=nan (nan%)
# positioning took 0.5 minutes
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# tol=1.0e-04, sigma=2.0, host=unkno, nav=16, nbrs=2, l_surf_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=362453.2, rms=nan
# 031: dt: 0.5000, sse=363359.5, rms=nan (nan%)
# 032: dt: 0.5000, sse=364094.2, rms=nan (nan%)
# 033: dt: 0.5000, sse=364889.5, rms=nan (nan%)
# 034: dt: 0.5000, sse=365834.2, rms=nan (nan%)
# 035: dt: 0.5000, sse=366990.9, rms=nan (nan%)
# 036: dt: 0.5000, sse=368148.9, rms=nan (nan%)
# 037: dt: 0.5000, sse=369329.5, rms=nan (nan%)
# 038: dt: 0.5000, sse=370539.6, rms=nan (nan%)
# 039: dt: 0.5000, sse=371934.4, rms=nan (nan%)
# 040: dt: 0.5000, sse=373529.5, rms=nan (nan%)
# 041: dt: 0.5000, sse=375149.8, rms=nan (nan%)
# 042: dt: 0.5000, sse=376851.5, rms=nan (nan%)
# 043: dt: 0.5000, sse=378638.2, rms=nan (nan%)
# 044: dt: 0.5000, sse=380415.6, rms=nan (nan%)
# 045: dt: 0.5000, sse=382190.2, rms=nan (nan%)
# 046: dt: 0.5000, sse=384072.8, rms=nan (nan%)
# 047: dt: 0.5000, sse=385799.4, rms=nan (nan%)
# 048: dt: 0.5000, sse=387671.8, rms=nan (nan%)
# 049: dt: 0.5000, sse=389522.1, rms=nan (nan%)
# 050: dt: 0.5000, sse=391620.8, rms=nan (nan%)
# 051: dt: 0.5000, sse=393778.8, rms=nan (nan%)
# 052: dt: 0.5000, sse=395847.8, rms=nan (nan%)
# 053: dt: 0.5000, sse=397781.0, rms=nan (nan%)
# 054: dt: 0.5000, sse=399711.4, rms=nan (nan%)
# 055: dt: 0.5000, sse=401565.4, rms=nan (nan%)
# 056: dt: 0.5000, sse=403352.0, rms=nan (nan%)
# 057: dt: 0.5000, sse=404865.7, rms=nan (nan%)
# 058: dt: 0.5000, sse=406282.1, rms=nan (nan%)
# 059: dt: 0.5000, sse=407889.7, rms=nan (nan%)
# 060: dt: 0.5000, sse=409185.0, rms=nan (nan%)
# positioning took 2.2 minutes
# smoothing T1 volume with sigma = 1.000
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=1.0, host=unkno, nav=8, nbrs=2, l_surf_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=399763.0, rms=nan
# 061: dt: 0.5000, sse=398252.2, rms=nan (nan%)
# 062: dt: 0.5000, sse=396997.1, rms=nan (nan%)
# 063: dt: 0.5000, sse=396225.1, rms=nan (nan%)
# 064: dt: 0.5000, sse=395190.2, rms=nan (nan%)
# 065: dt: 0.5000, sse=394534.8, rms=nan (nan%)
# 066: dt: 0.5000, sse=394292.2, rms=nan (nan%)
# 067: dt: 0.5000, sse=394185.8, rms=nan (nan%)
# 068: dt: 0.5000, sse=394204.0, rms=nan (nan%)
# 069: dt: 0.5000, sse=394030.9, rms=nan (nan%)
# 070: dt: 0.5000, sse=394306.4, rms=nan (nan%)
# 071: dt: 0.5000, sse=394243.3, rms=nan (nan%)
# 072: dt: 0.5000, sse=394124.1, rms=nan (nan%)
# 073: dt: 0.5000, sse=394564.9, rms=nan (nan%)
# 074: dt: 0.5000, sse=394514.9, rms=nan (nan%)
# 075: dt: 0.5000, sse=394573.3, rms=nan (nan%)
# 076: dt: 0.5000, sse=394436.6, rms=nan (nan%)
# 077: dt: 0.5000, sse=394944.5, rms=nan (nan%)
# 078: dt: 0.5000, sse=394937.2, rms=nan (nan%)
# 079: dt: 0.5000, sse=395010.8, rms=nan (nan%)
# 080: dt: 0.5000, sse=395148.8, rms=nan (nan%)
# 081: dt: 0.5000, sse=395330.8, rms=nan (nan%)
# 082: dt: 0.5000, sse=395377.2, rms=nan (nan%)
# 083: dt: 0.5000, sse=395095.4, rms=nan (nan%)
# 084: dt: 0.5000, sse=395346.7, rms=nan (nan%)
# 085: dt: 0.5000, sse=395278.3, rms=nan (nan%)
# 086: dt: 0.5000, sse=395580.8, rms=nan (nan%)
# 087: dt: 0.5000, sse=395289.0, rms=nan (nan%)
# 088: dt: 0.5000, sse=395450.1, rms=nan (nan%)
# 089: dt: 0.5000, sse=395231.7, rms=nan (nan%)
# 090: dt: 0.5000, sse=395306.6, rms=nan (nan%)
# positioning took 2.5 minutes
# smoothing T1 volume with sigma = 0.500
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.5, host=unkno, nav=4, nbrs=2, l_surf_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=371376.8, rms=nan
# 091: dt: 0.5000, sse=369434.3, rms=nan (nan%)
# 092: dt: 0.5000, sse=367777.8, rms=nan (nan%)
# 093: dt: 0.5000, sse=366401.5, rms=nan (nan%)
# 094: dt: 0.5000, sse=365080.7, rms=nan (nan%)
# 095: dt: 0.5000, sse=364000.5, rms=nan (nan%)
# 096: dt: 0.5000, sse=363166.0, rms=nan (nan%)
# 097: dt: 0.5000, sse=362430.2, rms=nan (nan%)
# 098: dt: 0.5000, sse=361735.4, rms=nan (nan%)
# 099: dt: 0.5000, sse=361330.6, rms=nan (nan%)
# 100: dt: 0.5000, sse=360948.2, rms=nan (nan%)
# 101: dt: 0.5000, sse=360484.2, rms=nan (nan%)
# 102: dt: 0.5000, sse=360333.6, rms=nan (nan%)
# 103: dt: 0.5000, sse=359996.1, rms=nan (nan%)
# 104: dt: 0.5000, sse=360003.6, rms=nan (nan%)
# 105: dt: 0.5000, sse=359773.7, rms=nan (nan%)
# 106: dt: 0.5000, sse=359957.4, rms=nan (nan%)
# 107: dt: 0.5000, sse=359785.3, rms=nan (nan%)
# 108: dt: 0.5000, sse=359713.0, rms=nan (nan%)
# 109: dt: 0.5000, sse=359693.8, rms=nan (nan%)
# 110: dt: 0.5000, sse=359720.8, rms=nan (nan%)
# 111: dt: 0.5000, sse=359710.6, rms=nan (nan%)
# 112: dt: 0.5000, sse=359737.1, rms=nan (nan%)
# 113: dt: 0.5000, sse=359653.8, rms=nan (nan%)
# 114: dt: 0.5000, sse=359748.4, rms=nan (nan%)
# 115: dt: 0.5000, sse=359806.2, rms=nan (nan%)
# 116: dt: 0.5000, sse=359936.4, rms=nan (nan%)
# 117: dt: 0.5000, sse=359833.9, rms=nan (nan%)
# 118: dt: 0.5000, sse=359910.4, rms=nan (nan%)
# 119: dt: 0.5000, sse=359832.9, rms=nan (nan%)
# 120: dt: 0.5000, sse=360063.0, rms=nan (nan%)
# positioning took 2.3 minutes
# smoothing T1 volume with sigma = 0.250
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.2, host=unkno, nav=2, nbrs=2, l_surf_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=339679.2, rms=nan
# 121: dt: 0.5000, sse=339209.8, rms=nan (nan%)
# 122: dt: 0.5000, sse=338813.4, rms=nan (nan%)
# 123: dt: 0.5000, sse=338104.7, rms=nan (nan%)
# 124: dt: 0.5000, sse=337417.6, rms=nan (nan%)
# 125: dt: 0.5000, sse=337179.9, rms=nan (nan%)
# 126: dt: 0.5000, sse=336719.2, rms=nan (nan%)
# 127: dt: 0.5000, sse=336329.5, rms=nan (nan%)
# 128: dt: 0.5000, sse=336050.1, rms=nan (nan%)
# 129: dt: 0.5000, sse=335756.3, rms=nan (nan%)
# 130: dt: 0.5000, sse=335450.3, rms=nan (nan%)
# 131: dt: 0.5000, sse=335274.8, rms=nan (nan%)
# 132: dt: 0.5000, sse=335151.3, rms=nan (nan%)
# 133: dt: 0.5000, sse=334961.7, rms=nan (nan%)
# 134: dt: 0.5000, sse=334891.6, rms=nan (nan%)
# 135: dt: 0.5000, sse=334860.6, rms=nan (nan%)
# 136: dt: 0.5000, sse=334722.2, rms=nan (nan%)
# 137: dt: 0.5000, sse=334739.3, rms=nan (nan%)
# 138: dt: 0.5000, sse=334639.9, rms=nan (nan%)
# 139: dt: 0.5000, sse=334582.5, rms=nan (nan%)
# 140: dt: 0.5000, sse=334544.2, rms=nan (nan%)
# 141: dt: 0.5000, sse=334544.0, rms=nan (nan%)
# 142: dt: 0.5000, sse=334492.8, rms=nan (nan%)
# 143: dt: 0.5000, sse=334480.9, rms=nan (nan%)
# 144: dt: 0.5000, sse=334423.3, rms=nan (nan%)
# 145: dt: 0.5000, sse=334450.1, rms=nan (nan%)
# 146: dt: 0.5000, sse=334383.7, rms=nan (nan%)
# 147: dt: 0.5000, sse=334392.5, rms=nan (nan%)
# 148: dt: 0.5000, sse=334354.3, rms=nan (nan%)
# 149: dt: 0.5000, sse=334325.6, rms=nan (nan%)
# 150: dt: 0.5000, sse=334287.8, rms=nan (nan%)
# positioning took 2.2 minutes
# writing pial surface to /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.pial...
# writing smoothed curvature to lh.curv.pial
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.curv.pial
# writing smoothed area to lh.area.pial
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.area.pial
# vertex spacing 0.80 +- 0.30 (0.04-->18.43) (max @ vno 5367 --> 5368)
# face area 0.27 +- 0.17 (0.00-->11.16)
# measuring cortical thickness...
# 0 of 75586 vertices processed
# 25000 of 75586 vertices processed
# 50000 of 75586 vertices processed
# 75000 of 75586 vertices processed
# 0 of 75586 vertices processed
# 25000 of 75586 vertices processed
# 50000 of 75586 vertices processed
# 75000 of 75586 vertices processed
# thickness calculation complete, 71:144 truncations.
# 51201 vertices at 0 distance
# 42734 vertices at 1 distance
# 26607 vertices at 2 distance
# 14661 vertices at 3 distance
# 7724 vertices at 4 distance
# 4215 vertices at 5 distance
# 2248 vertices at 6 distance
# 1020 vertices at 7 distance
# 433 vertices at 8 distance
# 182 vertices at 9 distance
# 78 vertices at 10 distance
# 30 vertices at 11 distance
# 13 vertices at 12 distance
# 9 vertices at 13 distance
# 6 vertices at 14 distance
# 4 vertices at 15 distance
# 2 vertices at 16 distance
# 1 vertices at 17 distance
# 1 vertices at 18 distance
# 3 vertices at 19 distance
# 0 vertices at 20 distance
# writing cortical thickness estimate to 'thickness' file.
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.thickness
# positioning took 16.8 minutes

# %%
# create surfaces
for xh in ${HEMI[@]}; do
    mris_make_surfaces -noaseg -noaparc -T1 T1 -orig_wm orig ${SUBJ} ${xh}
    mris_sphere ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.sphere
    mris_expand -thickness ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white 0.5 ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid
done
# Out:
# not using aseg volume to prevent surfaces crossing the midline
# not using aparc to prevent surfaces crossing the midline
# using T1 as T1 volume...
# reading original vertex positions from orig
# $Id: mris_make_surfaces.c,v 1.164.2.4 2016/12/13 22:26:32 zkaufman Exp $
# $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/filled.mgz...
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/T1.mgz...
# resampling filled volume to be in voxel register with T1
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/wm.mgz...
# resampling wm volume to be in voxel register with T1
# 315613 bright wm thresholded.
# 916341 bright non-wm voxels segmented.
# reading original surface position from /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.orig...
# computing class statistics...
# border white:    159857 voxels (0.95%)
# border gray      171366 voxels (1.02%)
# WM (109.0): 110.0 +- 0.2 [91.0 --> 110.0]
# GM (91.0) : 89.3 +- 15.6 [30.0 --> 110.0]
# using class modes intead of means, discounting robust sigmas....
# intensity peaks found at WM=110+-0.9,    GM=134+-12.2
# setting MIN_GRAY_AT_WHITE_BORDER to 118.4 (was 70)
# setting MAX_BORDER_WHITE to 110.2 (was 105)
# setting MIN_BORDER_WHITE to 134.0 (was 85)
# setting MAX_CSF to 102.8 (was 40)
# setting MAX_GRAY to 109.8 (was 95)
# setting MAX_GRAY_AT_CSF_BORDER to 118.4 (was 75)
# setting MIN_GRAY_AT_CSF_BORDER to 87.2 (was 40)
# mean inside = 114.6, mean outside = 134.3
# inverted contrast detected....
# smoothing surface for 5 iterations...
# repositioning cortical surface to gray/white boundary
# smoothing T1 volume with sigma = 2.000
# vertex spacing 0.86 +- 0.20 (0.09-->1.63) (max @ vno 17409 --> 17423)
# face area 0.31 +- 0.12 (0.00-->0.95)
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=2.0, host=unkno, nav=4, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# complete_dist_mat 0
# rms 0
# smooth_averages 0
# remove_neg 0
# ico_order 0
# which_surface 0
# target_radius 0.000000
# nfields 0
# scale 0.000000
# desired_rms_height 0.000000
# momentum 0.000000
# nbhd_size 0
# max_nbrs 0
# niterations 25
# nsurfaces 0
# SURFACES 3
# flags 0 (0)
# use curv 0
# no sulc 0
# no rigid align 0
# mris->nsize 2
# mris->hemisphere 0
# randomSeed 0
#
# 000: dt: 0.0000, sse=354302.7, rms=nan
# 001: dt: 0.5000, sse=354412.5, rms=nan (nan%)
# 002: dt: 0.5000, sse=354923.2, rms=nan (nan%)
# 003: dt: 0.5000, sse=355715.2, rms=nan (nan%)
# 004: dt: 0.5000, sse=355720.1, rms=nan (nan%)
# 005: dt: 0.5000, sse=356240.9, rms=nan (nan%)
# 006: dt: 0.5000, sse=358147.9, rms=nan (nan%)
# 007: dt: 0.5000, sse=356655.0, rms=nan (nan%)
# 008: dt: 0.5000, sse=357672.1, rms=nan (nan%)
# 009: dt: 0.5000, sse=358590.1, rms=nan (nan%)
# 010: dt: 0.5000, sse=358083.4, rms=nan (nan%)
# 011: dt: 0.5000, sse=359707.5, rms=nan (nan%)
# 012: dt: 0.5000, sse=358936.1, rms=nan (nan%)
# 013: dt: 0.5000, sse=370568.2, rms=nan (nan%)
# 014: dt: 0.5000, sse=359305.1, rms=nan (nan%)
# 015: dt: 0.5000, sse=359688.5, rms=nan (nan%)
# 016: dt: 0.5000, sse=360772.6, rms=nan (nan%)
# 017: dt: 0.5000, sse=362288.7, rms=nan (nan%)
# 018: dt: 0.5000, sse=362617.8, rms=nan (nan%)
# 019: dt: 0.5000, sse=361596.2, rms=nan (nan%)
# 020: dt: 0.5000, sse=362340.6, rms=nan (nan%)
# 021: dt: 0.5000, sse=362893.7, rms=nan (nan%)
# 022: dt: 0.5000, sse=364677.6, rms=nan (nan%)
# 023: dt: 0.5000, sse=364117.3, rms=nan (nan%)
# 024: dt: 0.5000, sse=363060.9, rms=nan (nan%)
# 025: dt: 0.5000, sse=363460.3, rms=nan (nan%)
# positioning took 1.3 minutes
# smoothing T1 volume with sigma = 1.000
# vertex spacing 0.81 +- 0.22 (0.08-->2.24) (max @ vno 24034 --> 24051)
# face area 0.31 +- 0.14 (0.00-->1.13)
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=1.0, host=unkno, nav=2, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=318541.4, rms=nan
# 026: dt: 0.5000, sse=322848.6, rms=nan (nan%)
# 027: dt: 0.5000, sse=323529.3, rms=nan (nan%)
# 028: dt: 0.5000, sse=320252.4, rms=nan (nan%)
# 029: dt: 0.5000, sse=321593.4, rms=nan (nan%)
# 030: dt: 0.5000, sse=321981.8, rms=nan (nan%)
# 031: dt: 0.5000, sse=322690.2, rms=nan (nan%)
# 032: dt: 0.5000, sse=321894.1, rms=nan (nan%)
# 033: dt: 0.5000, sse=322397.2, rms=nan (nan%)
# 034: dt: 0.5000, sse=324529.0, rms=nan (nan%)
# 035: dt: 0.5000, sse=323684.0, rms=nan (nan%)
# 036: dt: 0.5000, sse=323806.2, rms=nan (nan%)
# 037: dt: 0.5000, sse=325015.6, rms=nan (nan%)
# 038: dt: 0.5000, sse=333358.0, rms=nan (nan%)
# 039: dt: 0.5000, sse=324915.7, rms=nan (nan%)
# 040: dt: 0.5000, sse=328536.0, rms=nan (nan%)
# 041: dt: 0.5000, sse=331250.8, rms=nan (nan%)
# 042: dt: 0.5000, sse=325455.8, rms=nan (nan%)
# 043: dt: 0.5000, sse=326342.1, rms=nan (nan%)
# 044: dt: 0.5000, sse=327380.4, rms=nan (nan%)
# 045: dt: 0.5000, sse=326297.7, rms=nan (nan%)
# 046: dt: 0.5000, sse=327173.9, rms=nan (nan%)
# 047: dt: 0.5000, sse=347944.0, rms=nan (nan%)
# 048: dt: 0.5000, sse=328537.4, rms=nan (nan%)
# 049: dt: 0.5000, sse=330054.1, rms=nan (nan%)
# 050: dt: 0.5000, sse=327844.8, rms=nan (nan%)
# positioning took 1.3 minutes
# smoothing T1 volume with sigma = 0.500
# vertex spacing 0.78 +- 0.22 (0.04-->2.64) (max @ vno 24034 --> 24051)
# face area 0.27 +- 0.13 (0.00-->1.81)
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.5, host=unkno, nav=1, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=299450.8, rms=nan
# 051: dt: 0.5000, sse=301058.3, rms=nan (nan%)
# 052: dt: 0.5000, sse=303182.2, rms=nan (nan%)
# 053: dt: 0.5000, sse=302416.8, rms=nan (nan%)
# 054: dt: 0.5000, sse=306251.1, rms=nan (nan%)
# 055: dt: 0.5000, sse=303445.5, rms=nan (nan%)
# 056: dt: 0.5000, sse=302008.6, rms=nan (nan%)
# 057: dt: 0.5000, sse=310512.9, rms=nan (nan%)
# 058: dt: 0.5000, sse=303130.7, rms=nan (nan%)
# 059: dt: 0.5000, sse=303417.3, rms=nan (nan%)
# 060: dt: 0.5000, sse=304091.5, rms=nan (nan%)
# 061: dt: 0.5000, sse=303474.2, rms=nan (nan%)
# 062: dt: 0.5000, sse=305312.8, rms=nan (nan%)
# 063: dt: 0.5000, sse=304384.5, rms=nan (nan%)
# 064: dt: 0.5000, sse=307082.2, rms=nan (nan%)
# 065: dt: 0.5000, sse=304027.8, rms=nan (nan%)
# 066: dt: 0.5000, sse=305915.6, rms=nan (nan%)
# 067: dt: 0.5000, sse=310424.0, rms=nan (nan%)
# 068: dt: 0.5000, sse=305714.3, rms=nan (nan%)
# 069: dt: 0.5000, sse=306048.8, rms=nan (nan%)
# 070: dt: 0.5000, sse=308281.1, rms=nan (nan%)
# 071: dt: 0.5000, sse=307216.1, rms=nan (nan%)
# 072: dt: 0.5000, sse=308910.2, rms=nan (nan%)
# 073: dt: 0.5000, sse=311989.2, rms=nan (nan%)
# 074: dt: 0.5000, sse=309518.9, rms=nan (nan%)
# 075: dt: 0.5000, sse=307830.4, rms=nan (nan%)
# positioning took 1.3 minutes
# smoothing T1 volume with sigma = 0.250
# vertex spacing 0.75 +- 0.23 (0.03-->2.44) (max @ vno 24034 --> 24051)
# face area 0.25 +- 0.12 (0.00-->1.81)
# mean border=nan, 75586 (75586) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.2, host=unkno, nav=0, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=286306.2, rms=nan
# 076: dt: 0.5000, sse=292752.6, rms=nan (nan%)
# 077: dt: 0.5000, sse=286738.7, rms=nan (nan%)
# 078: dt: 0.5000, sse=287603.3, rms=nan (nan%)
# 079: dt: 0.5000, sse=290979.8, rms=nan (nan%)
# 080: dt: 0.5000, sse=288505.2, rms=nan (nan%)
# 081: dt: 0.5000, sse=287415.0, rms=nan (nan%)
# 082: dt: 0.5000, sse=289935.7, rms=nan (nan%)
# 083: dt: 0.5000, sse=290847.1, rms=nan (nan%)
# 084: dt: 0.5000, sse=289673.5, rms=nan (nan%)
# 085: dt: 0.5000, sse=288627.5, rms=nan (nan%)
# 086: dt: 0.5000, sse=289435.4, rms=nan (nan%)
# 087: dt: 0.5000, sse=292158.9, rms=nan (nan%)
# 088: dt: 0.5000, sse=290767.7, rms=nan (nan%)
# 089: dt: 0.5000, sse=289828.3, rms=nan (nan%)
# 090: dt: 0.5000, sse=290831.7, rms=nan (nan%)
# 091: dt: 0.5000, sse=290154.7, rms=nan (nan%)
# 092: dt: 0.5000, sse=289856.0, rms=nan (nan%)
# 093: dt: 0.5000, sse=292138.9, rms=nan (nan%)
# 094: dt: 0.5000, sse=292874.6, rms=nan (nan%)
# 095: dt: 0.5000, sse=293547.4, rms=nan (nan%)
# 096: dt: 0.5000, sse=294634.2, rms=nan (nan%)
# 097: dt: 0.5000, sse=292913.5, rms=nan (nan%)
# 098: dt: 0.5000, sse=293435.7, rms=nan (nan%)
# 099: dt: 0.5000, sse=295339.9, rms=nan (nan%)
# 100: dt: 0.5000, sse=294831.1, rms=nan (nan%)
# positioning took 1.3 minutes
# writing white matter surface to /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.white...
# writing smoothed curvature to lh.curv
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.curv
# writing smoothed area to lh.area
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.area
# vertex spacing 0.74 +- 0.23 (0.02-->2.27) (max @ vno 14317 --> 14889)
# face area 0.23 +- 0.12 (0.00-->1.66)
# smoothing surface for 5 iterations...
# repositioning cortical surface to gray/csf boundary.
# smoothing T1 volume with sigma = 2.000
# mean border=102.0, 32868 (32868) missing vertices, mean dist 1.7 [0.8 (%48.9)->1.6 (%51.1))]
# %12 local maxima, %43 large gradients and % 2 min vals, 23 gradients ignored
# averaging target values for 5 iterations...
# perforing initial smooth deformation to move away from white surface
# tol=1.0e-04, sigma=2.0, host=unkno, nav=16, nbrs=2, l_surf_repulse=1.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.05
# 000: dt: 0.0000, sse=3183537.2, rms=18.502
# rms = 18.54, time step reduction 1 of 3 to 0.025...
# rms = 18.50, time step reduction 2 of 3 to 0.013...
# 001: dt: 0.0250, sse=3181425.0, rms=18.496 (0.035%)
# rms = 18.45, time step reduction 3 of 3 to 0.006...
# 002: dt: 0.0125, sse=3166151.2, rms=18.450 (0.251%)
# positioning took 0.1 minutes
# mean border=94.4, 4992 (4370) missing vertices, mean dist -0.2 [1.5 (%55.5)->1.5 (%44.5))]
# %54 local maxima, %40 large gradients and % 0 min vals, 28 gradients ignored
# tol=1.0e-04, sigma=2.0, host=unkno, nav=16, nbrs=2, l_surf_repulse=1.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.05
# 000: dt: 0.0000, sse=29633536.0, rms=45.413
# rms = 46.50, time step reduction 1 of 3 to 0.025...
# rms = 45.44, time step reduction 2 of 3 to 0.013...
# rms = 45.41, time step reduction 3 of 3 to 0.006...
# 003: dt: 0.0125, sse=29633936.0, rms=45.413 (-0.001%)
# positioning took 0.1 minutes
# mean border=94.4, 4992 (4370) missing vertices, mean dist -0.2 [1.5 (%55.5)->1.5 (%44.5))]
# %54 local maxima, %40 large gradients and % 0 min vals, 28 gradients ignored
# tol=1.0e-04, sigma=2.0, host=unkno, nav=16, nbrs=2, l_surf_repulse=1.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.05
# 000: dt: 0.0000, sse=29633536.0, rms=45.413
# rms = 46.50, time step reduction 1 of 3 to 0.025...
# rms = 45.44, time step reduction 2 of 3 to 0.013...
# rms = 45.41, time step reduction 3 of 3 to 0.006...
# 004: dt: 0.0125, sse=29633936.0, rms=45.413 (-0.001%)
# positioning took 0.1 minutes
# mean border=94.4, 4992 (4370) missing vertices, mean dist -0.2 [1.5 (%55.5)->1.5 (%44.5))]
# %54 local maxima, %40 large gradients and % 0 min vals, 28 gradients ignored
# tol=1.0e-04, sigma=2.0, host=unkno, nav=16, nbrs=2, l_surf_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=29633536.0, rms=45.413
# rms = 48.97, time step reduction 1 of 3 to 0.250...
# rms = 46.35, time step reduction 2 of 3 to 0.125...
# rms = 45.53, time step reduction 3 of 3 to 0.062...
# 005: dt: 0.1250, sse=29790450.0, rms=45.534 (-0.267%)
# positioning took 0.1 minutes
# smoothing T1 volume with sigma = 1.000
# mean border=102.1, 34719 (4278) missing vertices, mean dist 1.7 [0.8 (%53.0)->1.5 (%47.0))]
# %14 local maxima, %38 large gradients and % 2 min vals, 37 gradients ignored
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=1.0, host=unkno, nav=8, nbrs=2, l_surf_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=29843512.0, rms=45.545
# rms = 49.52, time step reduction 1 of 3 to 0.250...
# rms = 46.58, time step reduction 2 of 3 to 0.125...
# rms = 45.68, time step reduction 3 of 3 to 0.062...
# 006: dt: 0.1250, sse=30015826.0, rms=45.678 (-0.291%)
# positioning took 0.1 minutes
# smoothing T1 volume with sigma = 0.500
# mean border=103.3, 38063 (4253) missing vertices, mean dist 5.0 [0.8 (%61.1)->1.1 (%38.9))]
# %26 local maxima, %22 large gradients and % 2 min vals, 33 gradients ignored
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.5, host=unkno, nav=4, nbrs=2, l_surf_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=30429998.0, rms=45.986
# rms = 50.10, time step reduction 1 of 3 to 0.250...
# rms = 47.05, time step reduction 2 of 3 to 0.125...
# rms = 46.12, time step reduction 3 of 3 to 0.062...
# 007: dt: 0.1250, sse=30608426.0, rms=46.122 (-0.295%)
# positioning took 0.1 minutes
# smoothing T1 volume with sigma = 0.250
# mean border=104.0, 41155 (4236) missing vertices, mean dist 1.2 [0.8 (%66.0)->0.8 (%34.0))]
# %32 local maxima, %12 large gradients and % 2 min vals, 27 gradients ignored
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.2, host=unkno, nav=2, nbrs=2, l_surf_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=30941412.0, rms=46.369
# rms = 50.50, time step reduction 1 of 3 to 0.250...
# rms = 47.42, time step reduction 2 of 3 to 0.125...
# rms = 46.50, time step reduction 3 of 3 to 0.062...
# 008: dt: 0.1250, sse=31118616.0, rms=46.503 (-0.289%)
# positioning took 0.1 minutes
# writing pial surface to /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.pial...
# writing smoothed curvature to lh.curv.pial
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.curv.pial
# writing smoothed area to lh.area.pial
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.area.pial
# vertex spacing 0.72 +- 0.23 (0.08-->2.13) (max @ vno 14317 --> 14889)
# face area 0.21 +- 0.11 (0.00-->1.21)
# measuring cortical thickness...
# 0 of 75586 vertices processed
# 25000 of 75586 vertices processed
# 50000 of 75586 vertices processed
# 75000 of 75586 vertices processed
# 0 of 75586 vertices processed
# 25000 of 75586 vertices processed
# 50000 of 75586 vertices processed
# 75000 of 75586 vertices processed
# thickness calculation complete, 0:0 truncations.
# 149771 vertices at 0 distance
# 1245 vertices at 1 distance
# 154 vertices at 2 distance
# 2 vertices at 3 distance
# 0 vertices at 4 distance
# 0 vertices at 5 distance
# 0 vertices at 6 distance
# 0 vertices at 7 distance
# 0 vertices at 8 distance
# 0 vertices at 9 distance
# 0 vertices at 10 distance
# 0 vertices at 11 distance
# 0 vertices at 12 distance
# 0 vertices at 13 distance
# 0 vertices at 14 distance
# 0 vertices at 15 distance
# 0 vertices at 16 distance
# 0 vertices at 17 distance
# 0 vertices at 18 distance
# 0 vertices at 19 distance
# 0 vertices at 20 distance
# writing cortical thickness estimate to 'thickness' file.
# writing curvature file /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.thickness
# positioning took 7.4 minutes
# using distance as a % of thickness
# expanding surface /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.white by 50.0% of thickness and writing it to /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.graymid
# reading thickness...
# -01: dt=0.0000, 0 negative triangles
# ending sse = 4487.020517
# nrounds = 6
# step 240 of 240
# writing expanded surface to /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/lh.graymid...
# surface expansion took 13 minutes and 30 seconds.
# not using aseg volume to prevent surfaces crossing the midline
# not using aparc to prevent surfaces crossing the midline
# using T1 as T1 volume...
# reading original vertex positions from orig
# $Id: mris_make_surfaces.c,v 1.164.2.4 2016/12/13 22:26:32 zkaufman Exp $
# $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/filled.mgz...
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/T1.mgz...
# resampling filled volume to be in voxel register with T1
# reading volume /Users/chris/Documents/MRI/freesurfer/subjects//Danny/mri/wm.mgz...
# resampling wm volume to be in voxel register with T1
# 315613 bright wm thresholded.
# 916341 bright non-wm voxels segmented.
# reading original surface position from /Users/chris/Documents/MRI/freesurfer/subjects//Danny/surf/rh.orig...
# computing class statistics...
# border white:    159857 voxels (0.95%)
# border gray      171366 voxels (1.02%)
# WM (109.0): 110.0 +- 0.2 [91.0 --> 110.0]
# GM (91.0) : 89.3 +- 15.6 [30.0 --> 110.0]
# using class modes intead of means, discounting robust sigmas....
# intensity peaks found at WM=110+-0.9,    GM=131+-14.8
# setting MIN_GRAY_AT_WHITE_BORDER to 115.4 (was 70)
# setting MAX_BORDER_WHITE to 110.2 (was 105)
# setting MIN_BORDER_WHITE to 131.0 (was 85)
# setting MAX_CSF to 99.8 (was 40)
# setting MAX_GRAY to 109.8 (was 95)
# setting MAX_GRAY_AT_CSF_BORDER to 115.4 (was 75)
# setting MIN_GRAY_AT_CSF_BORDER to 84.2 (was 40)
# mean inside = 114.5, mean outside = 133.7
# inverted contrast detected....
# smoothing surface for 5 iterations...
# repositioning cortical surface to gray/white boundary
# smoothing T1 volume with sigma = 2.000
# vertex spacing 0.86 +- 0.20 (0.06-->1.67) (max @ vno 51820 --> 51829)
# face area 0.31 +- 0.12 (0.00-->0.86)
# mean border=nan, 76798 (76798) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=2.0, host=unkno, nav=4, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# complete_dist_mat 0
# rms 0
# smooth_averages 0
# remove_neg 0
# ico_order 0
# which_surface 0
# target_radius 0.000000
# nfields 0
# scale 0.000000
# desired_rms_height 0.000000
# momentum 0.000000
# nbhd_size 0
# max_nbrs 0
# niterations 25
# nsurfaces 0
# SURFACES 3
# flags 0 (0)
# use curv 0
# no sulc 0
# no rigid align 0
# mris->nsize 2
# mris->hemisphere 1
# randomSeed 0
#
# 000: dt: 0.0000, sse=361674.5, rms=nan
# 001: dt: 0.5000, sse=362405.9, rms=nan (nan%)
# 002: dt: 0.5000, sse=362885.7, rms=nan (nan%)
# 003: dt: 0.5000, sse=361980.4, rms=nan (nan%)
# 004: dt: 0.5000, sse=362257.1, rms=nan (nan%)
# 005: dt: 0.5000, sse=364354.5, rms=nan (nan%)
# 006: dt: 0.5000, sse=363034.8, rms=nan (nan%)
# 007: dt: 0.5000, sse=363981.5, rms=nan (nan%)
# 008: dt: 0.5000, sse=364549.6, rms=nan (nan%)
# 009: dt: 0.5000, sse=364941.9, rms=nan (nan%)
# 010: dt: 0.5000, sse=364998.7, rms=nan (nan%)
# 011: dt: 0.5000, sse=365676.4, rms=nan (nan%)
# 012: dt: 0.5000, sse=367499.6, rms=nan (nan%)
# 013: dt: 0.5000, sse=366376.3, rms=nan (nan%)
# 014: dt: 0.5000, sse=366791.1, rms=nan (nan%)
# 015: dt: 0.5000, sse=366755.2, rms=nan (nan%)
# 016: dt: 0.5000, sse=368445.7, rms=nan (nan%)
# 017: dt: 0.5000, sse=369258.3, rms=nan (nan%)
# 018: dt: 0.5000, sse=374255.4, rms=nan (nan%)
# 019: dt: 0.5000, sse=371507.2, rms=nan (nan%)
# 020: dt: 0.5000, sse=369587.7, rms=nan (nan%)
# 021: dt: 0.5000, sse=370222.6, rms=nan (nan%)
# 022: dt: 0.5000, sse=369653.5, rms=nan (nan%)
# 023: dt: 0.5000, sse=370522.2, rms=nan (nan%)
# 024: dt: 0.5000, sse=370280.2, rms=nan (nan%)
# 025: dt: 0.5000, sse=371572.9, rms=nan (nan%)
# positioning took 1.3 minutes
# smoothing T1 volume with sigma = 1.000
# vertex spacing 0.81 +- 0.22 (0.06-->2.13) (max @ vno 50173 --> 50174)
# face area 0.31 +- 0.14 (0.00-->1.14)
# mean border=nan, 76798 (76798) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=1.0, host=unkno, nav=2, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=324759.8, rms=nan
# 026: dt: 0.5000, sse=324816.1, rms=nan (nan%)
# 027: dt: 0.5000, sse=332681.1, rms=nan (nan%)
# 028: dt: 0.5000, sse=329584.4, rms=nan (nan%)
# 029: dt: 0.5000, sse=335965.4, rms=nan (nan%)
# 030: dt: 0.5000, sse=326516.2, rms=nan (nan%)
# 031: dt: 0.5000, sse=327263.7, rms=nan (nan%)
# 032: dt: 0.5000, sse=327620.7, rms=nan (nan%)
# 033: dt: 0.5000, sse=330522.1, rms=nan (nan%)
# 034: dt: 0.5000, sse=328073.1, rms=nan (nan%)
# 035: dt: 0.5000, sse=329411.3, rms=nan (nan%)
# 036: dt: 0.5000, sse=329842.3, rms=nan (nan%)
# 037: dt: 0.5000, sse=330796.4, rms=nan (nan%)
# 038: dt: 0.5000, sse=334131.3, rms=nan (nan%)
# 039: dt: 0.5000, sse=330890.1, rms=nan (nan%)
# 040: dt: 0.5000, sse=331748.1, rms=nan (nan%)
# 041: dt: 0.5000, sse=330601.4, rms=nan (nan%)
# 042: dt: 0.5000, sse=332251.0, rms=nan (nan%)
# 043: dt: 0.5000, sse=330908.7, rms=nan (nan%)
# 044: dt: 0.5000, sse=335869.6, rms=nan (nan%)
# 045: dt: 0.5000, sse=332996.3, rms=nan (nan%)
# 046: dt: 0.5000, sse=336581.3, rms=nan (nan%)
# 047: dt: 0.5000, sse=341534.4, rms=nan (nan%)
# 048: dt: 0.5000, sse=337079.7, rms=nan (nan%)
# 049: dt: 0.5000, sse=333399.2, rms=nan (nan%)
# 050: dt: 0.5000, sse=342971.8, rms=nan (nan%)
# positioning took 1.3 minutes
# smoothing T1 volume with sigma = 0.500
# vertex spacing 0.78 +- 0.22 (0.02-->2.19) (max @ vno 50173 --> 50174)
# face area 0.27 +- 0.13 (0.00-->1.24)
# mean border=nan, 76798 (76798) missing vertices, mean dist -0.0 [0.0 (%nan)->0.0 (%nan))]
# % 0 local maxima, % 0 large gradients and % 0 min vals, 0 gradients ignored
# mean absolute distance = nan +- nan
# 0 vertices more than 2 sigmas from mean.
# averaging target values for 5 iterations...
# tol=1.0e-04, sigma=0.5, host=unkno, nav=1, nbrs=2, l_repulse=5.000, l_tspring=1.000, l_nspring=0.500, l_intensity=0.200, l_curv=1.000
# mom=0.00, dt=0.50
# 000: dt: 0.0000, sse=313135.2, rms=nan
# 051: dt: 0.5000, sse=305911.6, rms=nan (nan%)
# 052: dt: 0.5000, sse=307985.1, rms=nan (nan%)
# 053: dt: 0.5000, sse=311305.9, rms=nan (nan%)
# 054: dt: 0.5000, sse=307996.4, rms=nan (nan%)
# 055: dt: 0.5000, sse=314786.8, rms=nan (nan%)
# 056: dt: 0.5000, sse=307765.4, rms=nan (nan%)
# 057: dt: 0.5000, sse=307978.6, rms=nan (nan%)
# 058: dt: 0.5000, sse=307955.4, rms=nan (nan%)
# 059: dt: 0.5000, sse=325098.7, rms=nan (nan%)

# %%
# create surfaces
HEMI=(lh rh)
for xh in ${HEMI[@]}; do
    mris_make_surfaces -noaseg -noaparc -T1 brain.finalsurfs -orig_wm orig ${SUBJ} ${xh}
done

# %% [markdown]
# The cells below will load the inflated hemispheres in tksurfer where you can make the cuts to create the flatmaps.
#
# For the full hemisphere make cuts on the medial wall. One cut enclosing the midline and five additional relaxation cuts.
# Mark a point on the part of the surface you want to keep and save patch as `?h.full.patch.3d` (replace '?' with 'l' and 'r' respectively)
#
# ![Cut_full](pics/Cut_full.png)
#
# For an occipital patch make one cut on the medial wall along the calcarine sulcus. Use 3 points to select a coronal cutting plane, and a fourth point to select which part of the surface you want to keep and save as `?h.occip.patch.3d`
#
# ![Cut_occip1](pics/Cut_occip1.png) ![Cut_occip1](pics/Cut_occip2.png)

# %%
# left
tksurfer ${SUBJ} lh inflated -curv

# %%
# right
tksurfer ${SUBJ} rh inflated -curv

# %%
cd ${SUBJECTS_DIR}/${SUBJ}/surf/
for xh in ${HEMI[@]}; do
    mris_flatten -w 0 -distances 20 7 ${xh}.full.patch.3d  ${xh}.full.patch.flat
    mris_flatten -w 0 -distances 20 7 ${xh}.occip.patch.3d  ${xh}.occip.patch.flat
done

# %% [markdown]
# If everything went well, you now have flatmaps of the white matter surface.
# They should look somewhat like this:
# [FULL]
# ![RH_flatmap](pics/RH_Flat_Sulci.png) ![RH_flatmap_gray](pics/RH_Flat_Sulci_gray.png)

# %%
# check your result
tksurfer ${SUBJ} rh inflated -patch rh.full.patch.flat -curv # for a red/green curvature map
#tksurfer ${SUBJ} rh inflated -patch rh.full.patch.flat -gray # for a gray curvature map

# %% [markdown]
# #### Fix the pial surface now

# %%
freeview -v ${SUBJECTS_DIR}/${SUBJ}/mri/T1.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brainmask.mgz \
    -f ${SUBJECTS_DIR}/${SUBJ}/surf/lh.white:edgecolor=yellow \
    ${SUBJECTS_DIR}/${SUBJ}/surf/lh.pial:edgecolor=red \
    ${SUBJECTS_DIR}/${SUBJ}/surf/rh.white:edgecolor=yellow \
    ${SUBJECTS_DIR}/${SUBJ}/surf/rh.pial:edgecolor=red

# %% [markdown]
# #### Copy Freesurfer results back to NMT template folder

# %%
cp -r ${SUBJECTS_DIR}/${SUBJ}/surf ${fsSurf}/surf

# %%
# return to startpath
cd ${startpath}

# %% [markdown]
# ## Step 4: Create additional surfaces using Connectome Workbench.
# This may not be necessary at all. Try the Freesurfer approach and the conversion to gifti with `mris_convert` first (as explained above)
#
# ### Requirements
#   - Connectome Workbench (https://www.humanconnectome.org/software/connectome-workbench)

# %%
# THIS SHOULDN'T BE NECESSARY SINCE WE'RE GETTINGS THESE OUTPUTS ALSO FROM THE FREESURFER PIPELINE !! #

# set path to where you want the results
wbSurf_path=${NMT_path}/single_subject_scans/${SUBJ}/wbSurf

echo 'Extracting surfaces from segmentation'
cd ${wbSurf_path}

# create surfaces
IsoSurface -input ${NMT_ss_path}/NMT_${SUBJ}_process/${SUBJ}_segmentation.nii.gz \
    -isorois -o_gii surf

# rename to something recognizable
mv surf.k2.gii gm.surf.gii # gm surface
mv surf.k3.gii wm.surf.gii # wm surface

# Smooth the surfaces a bit
echo 'Smoothing the surfaces a bit' 
wb_command -surface-smoothing wm.surf.gii 0.5 1 wm_sm.surf.gii
wb_command -surface-smoothing gm.surf.gii 0.5 1 gm_sm.surf.gii

# inflate the surfaces
echo 'Inflating the surfaces'
wb_command -surface-generate-inflated \
    wm_sm.surf.gii infl_wm_sm.surf.gii vinfl_wm_sm.surf.gii
wb_command -surface-generate-inflated \
    gm_sm.surf.gii infl_gm_sm.surf.gii vinfl_gm_sm.surf.gii

# view the result in your favorite viewer
echo 'Inspect the surfaces in a viewer'
freeview -f wm_sm.surf.gii infl_wm_sm.surf.gii vinfl_wm_sm.surf.gii \
    gm_sm.surf.gii infl_gm_sm.surf.gii vinfl_gm_sm.surf.gii
