# %% [markdown]
# # **Create Single Monkey Surfaces**

# %% [markdown]
# This notebook will guide you through the procedure to create single monkey surface representations in four steps (some are optional):
#
# 1. **(OPTIONAL)** Average multiple T1 scans from the same animal. (takes seconds)
# 2. Segment the (averaged) T1 of an individual animal using the NMT template as a prior. (takes many hours)
# 3. Create surfaces and flatmaps using Freesurfer. (takes minutes to hours depending on segmentation quality at the start)
# 4. **(OPTIONAL)** Create additional surfaces with Connectome Workbench. (takes minutes)

# %% [markdown]
# ## Initiate
# Setting a few environment variables here so we can actually run code from this notebook

# %%
SUBJ=Danny  # Name of the animal you are going to process
NMT_path=/NHP_MRI/Template/NMT # path to the template folder
startpath=pwd

# %% [markdown]
# ## **Step 1 (OPTIONAL): Average multiple T1 scans**
# ### Requirements:
# - Freesurfer installation (https://surfer.nmr.mgh.harvard.edu/)
# - NIH Macaque Template (https://github.com/jms290/NMT)
# - One or more high resolution anatomical scans
#
# - The `average_multiple_t1.sh ` script

# %% [markdown]
# ### Procedure
# - Create a folder for your subject in the NIH Macaque Template folder as
#
# `<>/NHP_MRI/Template/NMT/single_subject_scans/<SUBJECT>`
#
# - Inside this folder, create a subfolder with all individual T1 scan for this subject, e.g.
#
# `<>/NHP_MRI/Template/NMT/single_subject_scans/<SUBJECT>/<T1_FLD>/*.nii.gz`
#
# - Copy the script `average_multiple_t1.sh` to the `<SUBJECT>` folder as well.
#
# - Run this script with the name of the `<T1_FLD>` as input:
#
# `$ ./average_multiple_t1.sh <T1_FLD>`
#
#
# - The script will:
#
#     - Correct for having the monkey in the sphinx position
#     - Resample each T1 to 0.5 mm isotropic voxels
#     - Reorient the colume for correct display in FSL (e.g., with FSLEyes)
#     - Normalize the contrast gradient
#     - Average the multiple T1's together using motion correction to account for small differences
#
#
# - When the script is done, there should be a `<SUBJECT>.nii.gz` file in the root `<SUBJECT>` folder.

# %%
NMT_ss_path=${NMT_path}/single_subject_scans/${SUBJ}
mkdir -p ${NMT_ss_path}
mkdir -p ${NMT_path}/single_subject_scans/${SUBJ}/T1s
echo Copy the T1 files to ${NMT_path}/single_subject_scans/${SUBJ}/T1s

# %%
cp ${NMT_path}/single_subject_scans/average_multiple_t1.sh \
    ${NMT_path}/single_subject_scans/${SUBJ}/
cd ${NMT_path}/single_subject_scans/${SUBJ}/
./average_multiple_t1.sh T1s

# %% [markdown]
# ## **Step 2: Segment the single subject anatomy using the NMT template as a prior**
# ### Requirements
#   - NIH Macaque Template (https://github.com/jms290/NMT)
#   - ANTS (http://stnava.github.io/ANTs/)
#   - AFNI (https://afni.nimh.nih.gov/)
#
# ### Procedure
# This will segment and process the single-subject anatomical and warp the D99 atlas (https://afni.nimh.nih.gov/Macaque) to your individual anatomy.
#
# - Navigate to `<>/NHP_MRI/Template/NMT/single_subject_scans` in your terminal
#
# - There should be a folder `<SUBJECT>` containing a T1 named `<SUBJECT>.nii.gz` (Step 1 produces this)
#
# - Run the `align_and_process_singlesubject.sh` script with input `<SUBJECT>`:
#
# - The following 2 steps can be executed together by running: `$ ./create_ss_atlas.sh <SUBJECT>`
#
#     - Extracting single ROI masks from the warped atlas: `./extract_ROI.sh <SUBJECT>`
#
#     - Creating a label-file that makes the warped atlas usable in FSLEyes: `./create_xml.sh <SUBJECT>`

# %%
cd ${NMT_path}/single_subject_scans
./align_and_process_singlesubject.sh ${SUBJ}
./create_ss_atlas ${SUBJ}

# %% [markdown]
# ## **Step 3: Create surfaces and flatmaps using Freesurfer**

# %% [markdown]
# ### Requirements
# - Freesurfer installation (https://surfer.nmr.mgh.harvard.edu/)
# - Segmented individual subject T1

# %% [markdown]
# ### Procedure
# #### Create folders & copy files

# %%
#NMT_src=${NMT_path}/single_subject_scans/${SUBJ}/NMT_${SUBJ}_process 
NMT_src=${NMT_path}/single_subject_scans/${SUBJ}/NMT_${SUBJ}_process/manual_adjust # danny 
# adjust this if you have manually adjusted and saved to a different folder

fsSurf=${NMT_path}/single_subject_scans/${SUBJ}/fsSurf
mkdir -p ${fsSurf}

fsSurf_src=${fsSurf}/src
fsSurf_mgz=${fsSurf}/mgz
fsSurf_temp=${fsSurf}/temp
mkdir -p ${fsSurf_src}
mkdir -p ${fsSurf_mgz}
mkdir -p ${fsSurf_temp}

HEMI=(lh rh) # array to loop over hemispheres

# %%
# source files
cp ${NMT_src}/${SUBJ}_N4.nii.gz ${fsSurf_src}/T1.nii.gz
cp ${NMT_src}/${SUBJ}_brain.nii.gz ${fsSurf_src}/brain.nii.gz
cp ${NMT_src}/${SUBJ}_brain.nii.gz ${fsSurf_src}/brainmask.nii.gz # freesurfer brainmask aren't actually masks
cp ${NMT_src}/${SUBJ}_segmentation_WM.nii.gz ${fsSurf_src}/wm.nii.gz

# copy source files again but keep these original (for others the header will be changed to 'fake' 1 mm voxels)
mkdir -p ${fsSurf_src}/org
cp ${fsSurf_src}/*.nii.gz ${fsSurf_src}/org/

# %% [markdown]
# #### Change headers to mimic 1mm isotropic voxels & make mgz files

# %%
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/T1.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brain.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/brainmask.nii.gz
3drefit -xdel 1.0 -ydel 1.0 -zdel 1.0 -keepcen ${fsSurf_src}/wm.nii.gz

mri_convert -c ${fsSurf_src}/T1.nii.gz ${fsSurf_mgz}/T1.mgz
mri_convert -c ${fsSurf_src}/brain.nii.gz ${fsSurf_mgz}/brain.mgz
mri_convert -c ${fsSurf_src}/brainmask.nii.gz ${fsSurf_mgz}/brainmask.mgz
mri_convert -c ${fsSurf_src}/wm.nii.gz ${fsSurf_mgz}/wm.mgz

mri_mask -T 5 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/brainmask.mgz ${fsSurf_mgz}/brain.finalsurfs.mgz

# %% [markdown]
# #### Get corpus callosum and pons voxel coordinates
# These will later define the cutting planes for the surface generation so make sure that 1) the corpus callosum is in the middle, and 2) the pons coordinates are low enough to not cut through cortex.
#
# Corpus callosum:
# ![CC](pics/CC_coordinates.png)
#
# Pons:
# ![PONS](pics/PONS_coordinates.png)

# %%
# Inspect volume to get voxel coordinates
freeview -v ${fsSurf_mgz}/brain.mgz &

# %%
CC=(127 114 129)
PONS=(124 148 119)

# %% [markdown]
# #### Fill the white matter volume & copy for fixing

# %%
# Fill WM
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/filled.mgz
    
cp ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/wm_nofix.mgz

# %% [markdown]
# #### Tesselate volumes & fix topology (First run)

# %%
# left
mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig.nofix
# right
mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig.nofix

for xh in ${HEMI[@]}; do
    cp ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.orig

    # post-process tesselation
    mris_extract_main_component ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.orig.nofix
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig.nofix ${fsSurf_temp}/${xh}.smoothwm.nofix
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm.nofix ${fsSurf_temp}/${xh}.inflated.nofix
    mris_sphere -q ${fsSurf_temp}/${xh}.inflated.nofix ${fsSurf_temp}/${xh}.qsphere.nofix
    cp ${fsSurf_temp}/${xh}.inflated.nofix ${fsSurf_temp}/${xh}.inflated

    # fix topology
    mris_euler_number ${fsSurf_temp}/${xh}.orig
    mris_remove_intersection ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
done

# %% [markdown]
# #### Iterate manual adjustments and doing tesselation & topology fix again
# Should look something like this. Keep going (adjust wm.mgz using the recon-edit function of Freeview) until you are happy with the result.
#
# ![LH_wm_inflated](pics/LH_wm_inflated.png) ![RH_wm_inflated](pics/RH_in_wm_inflated.png)

# %%
# look at the result and apply fixes in WM definition
freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz \
    -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated \
    ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated &
# Out:
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.white
# MRISreadVertexPosition(white): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.white
# No such file or directory
# could not load surface from white
# No such file or directory
# te): could not open file /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.white
# [1]+  Done                    freeview -v ${fsSurf_mgz}/brain.mgz -v ${fsSurf_mgz}/wm.mgz -f ${fsSurf_temp}/lh.smoothwm ${fsSurf_temp}/lh.inflated ${fsSurf_temp}/rh.smoothwm ${fsSurf_temp}/rh.inflated
# [1] 2526

# %%
# redo the tesselation with the fixed WM volume
mri_fill -CV ${CC[0]} ${CC[1]} ${CC[2]} \
    -PV ${PONS[0]} ${PONS[1]} ${PONS[2]} \
    ${fsSurf_mgz}/wm.mgz ${fsSurf_mgz}/filled.mgz
    
mri_pretess ${fsSurf_mgz}/filled.mgz 255 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess255.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess255.mgz 255 ${fsSurf_temp}/lh.orig
mri_pretess ${fsSurf_mgz}/filled.mgz 127 ${fsSurf_mgz}/brain.mgz ${fsSurf_mgz}/wm_filled-pretess127.mgz
mri_tessellate ${fsSurf_mgz}/wm_filled-pretess127.mgz 127 ${fsSurf_temp}/rh.orig

for xh in ${HEMI[@]}; do
    mris_extract_main_component ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
    mris_sphere -q ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.qsphere
    
    mris_euler_number ${fsSurf_temp}/${xh}.orig
    mris_remove_intersection ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.orig
    mris_smooth -nw ${fsSurf_temp}/${xh}.orig ${fsSurf_temp}/${xh}.smoothwm
    mris_inflate ${fsSurf_temp}/${xh}.smoothwm ${fsSurf_temp}/${xh}.inflated
    mris_curvature -thresh .999 -n -a 5 -w -distances 10 10 ${fsSurf_temp}/${xh}.inflated
    mris_sphere ${fsSurf_temp}/${xh}.inflated ${fsSurf_temp}/${xh}.sphere
done
echo 'TESSELATION DONE!'
# Out:
# using voxel position (127, 114, 129) as corpus callosum seed point
# using voxel position (124, 148, 119) as pons seed point
# reading input volume...done.
# searching for cutting planes...INFO: volume does not have linear_transform set nor lta is given by option.-xform.
# INFO: use identity matrix as the talairach transform.
# INFO: use src volume parameters for the talairach volume.
# voxel to talairach voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Calculated talairach cc position (2.51, 5.66, 145.03)
# Using the seed to calculate the cutting plane
# Looking for area (min, max) = (350, 1400)
# area[0] = 446 (min = 350, max = 1400), aspect = 0.26 (min = 0.10, max = 0.75)
# no need to search
# using seed (127, 114, 129), TAL = (2.5, 5.7, 145.0)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# talairach cc position changed to (2.51, 5.66, 145.03)
# Using voxel pons seed point, calculated talairach pons position (5.51, -4.34, 111.03)
# Looking for area (min, max) = (350, 790)
# area[0] = 553 (min = 350, max = 790), aspect = 0.87 (min = 0.60, max = 1.20)
# no need to search
# using seed (124, 148, 119), TAL = (5.5, -4.3, 111.0)
# talairach voxel to voxel transform
#  1.00000   0.00000   0.00000   0.00000;
#  0.00000   1.00000   0.00000   0.00000;
#  0.00000   0.00000   1.00000   0.00000;
#  0.00000   0.00000   0.00000   1.00000;
# done.
# seed_search_size = 9, min_neighbors = 5
# search rh wm seed point around talairach space:(20.51, 5.66, 145.03) SRC: (109.00, 114.00, 129.00)
# search lh wm seed point around talairach space (-15.49, 5.66, 145.03), SRC: (145.00, 114.00, 129.00)
# filling left hemisphere...
# filling volume: pass 3 of 3...total of 138564 voxels filled...done.
# filling right hemisphere...
# filling volume: pass 3 of 3...total of 138472 voxels filled...done.
# filling degenerate left hemisphere surface locations...
# 102 voxels filled
# 0 voxels filled
# filling degenerate right hemisphere surface locations...
# 105 voxels filled
# 0 voxels filled
# refilling left hemisphere...
# filling volume: pass 3 of 3...total of 138666 voxels filled...done.
# refilling right hemisphere...
# filling volume: pass 3 of 3...total of 138577 voxels filled...done.
# combining hemispheres...
# writing output to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/mgz/filled.mgz...
# filling took 0.1 minutes
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 0 (out of 138667: 0.000000)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1804 vertices, 1904 faces
# slice 70: 5980 vertices, 6142 faces
# slice 80: 11208 vertices, 11352 faces
# slice 90: 16324 vertices, 16532 faces
# slice 100: 22510 vertices, 22701 faces
# slice 110: 29741 vertices, 30018 faces
# slice 120: 38005 vertices, 38289 faces
# slice 130: 45968 vertices, 46239 faces
# slice 140: 53028 vertices, 53269 faces
# slice 150: 59408 vertices, 59640 faces
# slice 160: 64966 vertices, 65130 faces
# slice 170: 69589 vertices, 69738 faces
# slice 180: 72725 vertices, 72820 faces
# slice 190: 74694 vertices, 74751 faces
# slice 200: 75708 vertices, 75730 faces
# slice 210: 75904 vertices, 75904 faces
# slice 220: 75904 vertices, 75904 faces
# slice 230: 75904 vertices, 75904 faces
# slice 240: 75904 vertices, 75904 faces
# slice 250: 75904 vertices, 75904 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.orig
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
# Ambiguous edge configurations...
#
# Iteration Number : 1
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (xz-):   0 found -   1 modified     |    TOTAL:   1
# Iteration Number : 1
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 1
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   1 found -   1 modified     |    TOTAL:   1
# pass   2 (yz+):   0 found -   1 modified     |    TOTAL:   1
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   1
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   1
# Iteration Number : 2
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 2
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (xy+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xy-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (yz-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz+):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (xz-):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+++):   0 found -   0 modified     |    TOTAL:   0
# Iteration Number : 3
# pass   1 (++):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (+-):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (--):   0 found -   0 modified     |    TOTAL:   0
# pass   1 (-+):   0 found -   0 modified     |    TOTAL:   0
#
# Total Number of Modified Voxels = 2 (out of 138580: 0.001443)
#
# mri_pretess done
#
# $Id: mri_tessellate.c,v 1.38.2.1 2016/07/26 18:46:38 zkaufman Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
# slice 60: 1162 vertices, 1231 faces
# slice 70: 4956 vertices, 5108 faces
# slice 80: 10131 vertices, 10295 faces
# slice 90: 15122 vertices, 15341 faces
# slice 100: 21436 vertices, 21645 faces
# slice 110: 28533 vertices, 28818 faces
# slice 120: 36889 vertices, 37196 faces
# slice 130: 45018 vertices, 45291 faces
# slice 140: 52402 vertices, 52654 faces
# slice 150: 58948 vertices, 59189 faces
# slice 160: 64949 vertices, 65110 faces
# slice 170: 69675 vertices, 69839 faces
# slice 180: 73142 vertices, 73246 faces
# slice 190: 75270 vertices, 75346 faces
# slice 200: 76603 vertices, 76637 faces
# slice 210: 76940 vertices, 76944 faces
# slice 220: 76940 vertices, 76944 faces
# slice 230: 76940 vertices, 76944 faces
# slice 240: 76940 vertices, 76944 faces
# slice 250: 76940 vertices, 76944 faces
# using the conformed surface RAS to save vertex points...
# writing /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.orig
# using vox2ras matrix:
# -1.00000   0.00000   0.00000   128.00000;
#  0.00000   0.00000   1.00000  -128.00000;
#  0.00000  -1.00000   0.00000   128.00000;
#  0.00000   0.00000   0.00000   1.00000;
#
# counting number of connected components...
#    75904 voxel in cpt #1: X=0 [v=75904,e=227712,f=151808] located at (-22.938896, -8.559892, 6.747510)
# For the whole surface: X=0 [v=75904,e=227712,f=151808]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.smoothwm
# avg radius = 39.3 mm, total surface area = 44418 mm^2
# step 060: RMS=0.027 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.sulc
# mris_inflate utimesec    14.016891
# mris_inflate stimesec    0.036043
# mris_inflate ru_maxrss   103800
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   24243
# mris_inflate ru_majflt   35
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  8008
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1883
# mris_inflate ru_nivcsw   6
# inflation took 0.2 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.355...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.744, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.488, avgs=0
# 010/300: dt: 0.9000, rms radial error=177.937, avgs=0
# 015/300: dt: 0.9000, rms radial error=177.213, avgs=0
# 020/300: dt: 0.9000, rms radial error=176.389, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.506, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.590, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.659, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.718, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.772, avgs=0
# 050/300: dt: 0.9000, rms radial error=170.826, avgs=0
# 055/300: dt: 0.9000, rms radial error=169.882, avgs=0
# 060/300: dt: 0.9000, rms radial error=168.940, avgs=0
# 065/300: dt: 0.9000, rms radial error=168.002, avgs=0
# 070/300: dt: 0.9000, rms radial error=167.067, avgs=0
# 075/300: dt: 0.9000, rms radial error=166.137, avgs=0
# 080/300: dt: 0.9000, rms radial error=165.211, avgs=0
# 085/300: dt: 0.9000, rms radial error=164.290, avgs=0
# 090/300: dt: 0.9000, rms radial error=163.373, avgs=0
# 095/300: dt: 0.9000, rms radial error=162.460, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.552, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.649, avgs=0
# 110/300: dt: 0.9000, rms radial error=159.750, avgs=0
# 115/300: dt: 0.9000, rms radial error=158.856, avgs=0
# 120/300: dt: 0.9000, rms radial error=157.966, avgs=0
# 125/300: dt: 0.9000, rms radial error=157.081, avgs=0
# 130/300: dt: 0.9000, rms radial error=156.201, avgs=0
# 135/300: dt: 0.9000, rms radial error=155.325, avgs=0
# 140/300: dt: 0.9000, rms radial error=154.454, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.587, avgs=0
# 150/300: dt: 0.9000, rms radial error=152.725, avgs=0
# 155/300: dt: 0.9000, rms radial error=151.867, avgs=0
# 160/300: dt: 0.9000, rms radial error=151.014, avgs=0
# 165/300: dt: 0.9000, rms radial error=150.166, avgs=0
# 170/300: dt: 0.9000, rms radial error=149.322, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.482, avgs=0
# 180/300: dt: 0.9000, rms radial error=147.648, avgs=0
# 185/300: dt: 0.9000, rms radial error=146.817, avgs=0
# 190/300: dt: 0.9000, rms radial error=145.991, avgs=0
# 195/300: dt: 0.9000, rms radial error=145.170, avgs=0
# 200/300: dt: 0.9000, rms radial error=144.354, avgs=0
# 205/300: dt: 0.9000, rms radial error=143.541, avgs=0
# 210/300: dt: 0.9000, rms radial error=142.734, avgs=0
# 215/300: dt: 0.9000, rms radial error=141.930, avgs=0
# 220/300: dt: 0.9000, rms radial error=141.131, avgs=0
# 225/300: dt: 0.9000, rms radial error=140.337, avgs=0
# 230/300: dt: 0.9000, rms radial error=139.547, avgs=0
# 235/300: dt: 0.9000, rms radial error=138.761, avgs=0
# 240/300: dt: 0.9000, rms radial error=137.980, avgs=0
# 245/300: dt: 0.9000, rms radial error=137.203, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.430, avgs=0
# 255/300: dt: 0.9000, rms radial error=135.661, avgs=0
# 260/300: dt: 0.9000, rms radial error=134.897, avgs=0
# 265/300: dt: 0.9000, rms radial error=134.137, avgs=0
# 270/300: dt: 0.9000, rms radial error=133.382, avgs=0
# 275/300: dt: 0.9000, rms radial error=132.630, avgs=0
# 280/300: dt: 0.9000, rms radial error=131.883, avgs=0
# 285/300: dt: 0.9000, rms radial error=131.140, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.401, avgs=0
# 295/300: dt: 0.9000, rms radial error=129.666, avgs=0
# 300/300: dt: 0.9000, rms radial error=128.936, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.34 +- 0.71 (0.02-->7.77) (max @ vno 23546 --> 24249)
# face area 0.04 +- 0.04 (-0.03-->0.85)
# epoch 1 (K=10.0), pass 1, starting sse = 8197.59
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00021
# epoch 2 (K=40.0), pass 1, starting sse = 1143.69
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00039
# epoch 3 (K=160.0), pass 1, starting sse = 95.73
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.20/14 = 0.01397
# epoch 4 (K=640.0), pass 1, starting sse = 3.74
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.50/22 = 0.02277
# final distance error %24.67
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.qsphere
# mris_sphere utimesec    110.625015
# mris_sphere stimesec    0.111964
# mris_sphere ru_maxrss   103908
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   24246
# mris_sphere ru_majflt   37
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  8408
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1478
# mris_sphere ru_nivcsw   1204
# spherical transformation took 0.03 hours
# FSRUNTIME@ mris_sphere  0.0308 hours 1 threads
# euler # = v-e+f = 2g-2: 75904 - 227712 + 151808 = 0 --> 1 holes
#       F =2V-4:          151808 != 151808-4 (-4)
#       2E=3F:            455424 = 455424 (0)
#
# total defect index = 2
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.smoothwm
# avg radius = 39.3 mm, total surface area = 44418 mm^2
# step 060: RMS=0.027 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.sulc
# mris_inflate utimesec    14.158139
# mris_inflate stimesec    0.040039
# mris_inflate ru_maxrss   103692
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   24263
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  0
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1849
# mris_inflate ru_nivcsw   74
# inflation took 0.2 minutes
# thresholding curvature at 99.90% level
# normalizing curvature values.
# averaging curvature patterns 5 times.
# sampling 10 neighbors out to a distance of 10 mm
# 58 vertices thresholded to be in k1 ~ [-0.77 0.70], k2 ~ [-0.26 0.26]
# total integrated curvature = 0.596*4pi (7.490) --> 0 handles
# ICI = 1.4, FI = 9.2, variation=155.205
# 44 vertices thresholded to be in [-0.06 0.08]
# writing Gaussian curvature to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.inflated.K...curvature mean = 0.000, std = 0.003
# 51 vertices thresholded to be in [-0.34 0.33]
# curvature mean = -0.022, std = 0.033
# done.
# writing mean curvature to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.inflated.H...done.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.355...
# surface projected - minimizing metric distortion...
# MRISunfold() max_passes = 1 -------
# tol=5.0e-01, sigma=0.0, host=x86_6, nav=1024, nbrs=2, l_area=1.000, l_dist=1.000
# using quadratic fit line minimization
# complete_dist_mat 0
# rms 0
# smooth_averages 0
# remove_neg 0
# ico_order 0
# which_surface 0
# target_radius 0.000000
# nfields 0
# scale 1.000000
# desired_rms_height -1.000000
# momentum 0.900000
# nbhd_size 7
# max_nbrs 8
# niterations 25
# nsurfaces 0
# SURFACES 3
# flags 0 (0)
# use curv 0
# no sulc 0
# no rigid align 0
# mris->nsize 2
# mris->hemisphere 0
# randomSeed 0
#
# --------------------
#   mrisRemoveNegativeArea()
# pass 1: epoch 1 of 3 starting distance error %18.74
# pass 1: epoch 2 of 3 starting distance error %18.73
# unfolding complete - removing small folds...
# starting distance error %18.62
# removing remaining folds...
# final distance error %18.66
# MRISunfold() return, current seed -1550683600
# -01: dt=0.0000, 38 negative triangles
# 236: dt=0.9900, 38 negative triangles
# 237: dt=0.9900, 15 negative triangles
# 238: dt=0.9900, 14 negative triangles
# 239: dt=0.9900, 13 negative triangles
# 240: dt=0.9900, 13 negative triangles
# 241: dt=0.9900, 12 negative triangles
# 242: dt=0.9900, 12 negative triangles
# 243: dt=0.9900, 12 negative triangles
# 244: dt=0.9900, 12 negative triangles
# 245: dt=0.9900, 12 negative triangles
# 246: dt=0.9900, 12 negative triangles
# 247: dt=0.9900, 12 negative triangles
# 248: dt=0.9900, 12 negative triangles
# 249: dt=0.9900, 12 negative triangles
# 250: dt=0.9900, 12 negative triangles
# 251: dt=0.9405, 12 negative triangles
# 252: dt=0.9405, 12 negative triangles
# 253: dt=0.9405, 12 negative triangles
# 254: dt=0.9405, 12 negative triangles
# 255: dt=0.9405, 12 negative triangles
# 256: dt=0.9405, 12 negative triangles
# 257: dt=0.9405, 12 negative triangles
# 258: dt=0.9405, 12 negative triangles
# 259: dt=0.9405, 12 negative triangles
# 260: dt=0.9405, 12 negative triangles
# 261: dt=0.8935, 12 negative triangles
# 262: dt=0.8935, 12 negative triangles
# 263: dt=0.8935, 12 negative triangles
# 264: dt=0.8935, 12 negative triangles
# 265: dt=0.8935, 12 negative triangles
# 266: dt=0.8935, 12 negative triangles
# 267: dt=0.8935, 12 negative triangles
# expanding nbhd size to 1
# 268: dt=0.9900, 12 negative triangles
# 269: dt=0.9900, 12 negative triangles
# 270: dt=0.9900, 15 negative triangles
# 271: dt=0.9405, 15 negative triangles
# 272: dt=0.9405, 15 negative triangles
# 273: dt=0.9405, 15 negative triangles
# 274: dt=0.9405, 15 negative triangles
# 275: dt=0.9405, 15 negative triangles
# 276: dt=0.9405, 15 negative triangles
# 277: dt=0.9405, 15 negative triangles
# 278: dt=0.9405, 15 negative triangles
# 279: dt=0.9405, 15 negative triangles
# 280: dt=0.9405, 15 negative triangles
# 281: dt=0.8935, 15 negative triangles
# 282: dt=0.8935, 15 negative triangles
# 283: dt=0.8935, 15 negative triangles
# 284: dt=0.8935, 15 negative triangles
# 285: dt=0.8935, 15 negative triangles
# 286: dt=0.8935, 15 negative triangles
# 287: dt=0.8935, 15 negative triangles
# 288: dt=0.8935, 15 negative triangles
# 289: dt=0.8935, 15 negative triangles
# 290: dt=0.8935, 15 negative triangles
# 291: dt=0.8488, 15 negative triangles
# 292: dt=0.8488, 15 negative triangles
# 293: dt=0.8488, 15 negative triangles
# 294: dt=0.8488, 15 negative triangles
# 295: dt=0.8488, 15 negative triangles
# 296: dt=0.8488, 15 negative triangles
# 297: dt=0.8488, 15 negative triangles
# 298: dt=0.8488, 15 negative triangles
# 299: dt=0.8488, 15 negative triangles
# 300: dt=0.8488, 15 negative triangles
# 301: dt=0.8064, 15 negative triangles
# 302: dt=0.8064, 15 negative triangles
# 303: dt=0.8064, 15 negative triangles
# 304: dt=0.8064, 15 negative triangles
# 305: dt=0.8064, 15 negative triangles
# 306: dt=0.8064, 15 negative triangles
# 307: dt=0.8064, 15 negative triangles
# 308: dt=0.8064, 15 negative triangles
# 309: dt=0.8064, 15 negative triangles
# 310: dt=0.8064, 15 negative triangles
# 311: dt=0.7660, 15 negative triangles
# 312: dt=0.7660, 15 negative triangles
# 313: dt=0.7660, 15 negative triangles
# 314: dt=0.7660, 15 negative triangles
# 315: dt=0.7660, 15 negative triangles
# 316: dt=0.7660, 15 negative triangles
# 317: dt=0.7660, 15 negative triangles
# 318: dt=0.7660, 15 negative triangles
# 319: dt=0.7660, 15 negative triangles
# 320: dt=0.7660, 15 negative triangles
# 321: dt=0.7277, 15 negative triangles
# 322: dt=0.7277, 15 negative triangles
# 323: dt=0.7277, 15 negative triangles
# 324: dt=0.7277, 15 negative triangles
# 325: dt=0.7277, 15 negative triangles
# 326: dt=0.7277, 15 negative triangles
# 327: dt=0.7277, 15 negative triangles
# 328: dt=0.7277, 15 negative triangles
# 329: dt=0.7277, 15 negative triangles
# 330: dt=0.7277, 15 negative triangles
# 331: dt=0.6914, 15 negative triangles
# 332: dt=0.6914, 15 negative triangles
# 333: dt=0.6914, 15 negative triangles
# 334: dt=0.6914, 15 negative triangles
# 335: dt=0.6914, 15 negative triangles
# 336: dt=0.6914, 15 negative triangles
# 337: dt=0.6914, 15 negative triangles
# 338: dt=0.6914, 15 negative triangles
# 339: dt=0.6914, 15 negative triangles
# 340: dt=0.6914, 15 negative triangles
# 341: dt=0.6568, 15 negative triangles
# 342: dt=0.6568, 15 negative triangles
# 343: dt=0.6568, 15 negative triangles
# 344: dt=0.6568, 15 negative triangles
# 345: dt=0.6568, 15 negative triangles
# 346: dt=0.6568, 15 negative triangles
# 347: dt=0.6568, 15 negative triangles
# 348: dt=0.6568, 15 negative triangles
# 349: dt=0.6568, 15 negative triangles
# 350: dt=0.6568, 15 negative triangles
# 351: dt=0.6239, 15 negative triangles
# 352: dt=0.6239, 15 negative triangles
# 353: dt=0.6239, 15 negative triangles
# 354: dt=0.6239, 15 negative triangles
# 355: dt=0.6239, 15 negative triangles
# 356: dt=0.6239, 15 negative triangles
# 357: dt=0.6239, 15 negative triangles
# 358: dt=0.6239, 15 negative triangles
# 359: dt=0.6239, 15 negative triangles
# 360: dt=0.6239, 15 negative triangles
# 361: dt=0.5927, 15 negative triangles
# 362: dt=0.5927, 15 negative triangles
# 363: dt=0.5927, 15 negative triangles
# 364: dt=0.5927, 15 negative triangles
# 365: dt=0.5927, 15 negative triangles
# 366: dt=0.5927, 15 negative triangles
# 367: dt=0.5927, 15 negative triangles
# 368: dt=0.5927, 15 negative triangles
# 369: dt=0.5927, 15 negative triangles
# 370: dt=0.5927, 15 negative triangles
# 371: dt=0.5631, 15 negative triangles
# 372: dt=0.5631, 15 negative triangles
# 373: dt=0.5631, 15 negative triangles
# 374: dt=0.5631, 15 negative triangles
# 375: dt=0.5631, 15 negative triangles
# 376: dt=0.5631, 15 negative triangles
# 377: dt=0.5631, 15 negative triangles
# 378: dt=0.5631, 15 negative triangles
# 379: dt=0.5631, 15 negative triangles
# 380: dt=0.5631, 15 negative triangles
# 381: dt=0.5350, 15 negative triangles
# 382: dt=0.5350, 15 negative triangles
# 383: dt=0.5350, 15 negative triangles
# 384: dt=0.5350, 15 negative triangles
# 385: dt=0.5350, 15 negative triangles
# 386: dt=0.5350, 15 negative triangles
# 387: dt=0.5350, 15 negative triangles
# 388: dt=0.5350, 15 negative triangles
# 389: dt=0.5350, 15 negative triangles
# 390: dt=0.5350, 15 negative triangles
# 391: dt=0.5082, 15 negative triangles
# 392: dt=0.5082, 15 negative triangles
# 393: dt=0.5082, 15 negative triangles
# 394: dt=0.5082, 15 negative triangles
# 395: dt=0.5082, 15 negative triangles
# 396: dt=0.5082, 15 negative triangles
# 397: dt=0.5082, 15 negative triangles
# 398: dt=0.5082, 15 negative triangles
# 399: dt=0.5082, 15 negative triangles
# 400: dt=0.5082, 15 negative triangles
# 401: dt=0.4828, 15 negative triangles
# 402: dt=0.4828, 15 negative triangles
# 403: dt=0.4828, 15 negative triangles
# 404: dt=0.4828, 15 negative triangles
# 405: dt=0.4828, 15 negative triangles
# 406: dt=0.4828, 15 negative triangles
# 407: dt=0.4828, 15 negative triangles
# 408: dt=0.4828, 15 negative triangles
# 409: dt=0.4828, 15 negative triangles
# 410: dt=0.4828, 15 negative triangles
# 411: dt=0.4587, 15 negative triangles
# 412: dt=0.4587, 15 negative triangles
# 413: dt=0.4587, 15 negative triangles
# 414: dt=0.4587, 15 negative triangles
# 415: dt=0.4587, 15 negative triangles
# 416: dt=0.4587, 15 negative triangles
# 417: dt=0.4587, 15 negative triangles
# 418: dt=0.4587, 15 negative triangles
# 419: dt=0.4587, 15 negative triangles
# 420: dt=0.4587, 15 negative triangles
# 421: dt=0.4357, 15 negative triangles
# 422: dt=0.4357, 15 negative triangles
# 423: dt=0.4357, 15 negative triangles
# 424: dt=0.4357, 15 negative triangles
# 425: dt=0.4357, 15 negative triangles
# 426: dt=0.4357, 15 negative triangles
# 427: dt=0.4357, 15 negative triangles
# 428: dt=0.4357, 15 negative triangles
# 429: dt=0.4357, 15 negative triangles
# 430: dt=0.4357, 15 negative triangles
# 431: dt=0.4139, 15 negative triangles
# 432: dt=0.4139, 15 negative triangles
# 433: dt=0.4139, 15 negative triangles
# 434: dt=0.4139, 15 negative triangles
# 435: dt=0.4139, 15 negative triangles
# 436: dt=0.4139, 15 negative triangles
# 437: dt=0.4139, 15 negative triangles
# 438: dt=0.4139, 15 negative triangles
# 439: dt=0.4139, 15 negative triangles
# 440: dt=0.4139, 15 negative triangles
# 441: dt=0.3932, 15 negative triangles
# 442: dt=0.3932, 15 negative triangles
# 443: dt=0.3932, 15 negative triangles
# 444: dt=0.3932, 15 negative triangles
# 445: dt=0.3932, 15 negative triangles
# 446: dt=0.3932, 15 negative triangles
# 447: dt=0.3932, 15 negative triangles
# 448: dt=0.3932, 15 negative triangles
# 449: dt=0.3932, 15 negative triangles
# 450: dt=0.3932, 15 negative triangles
# 451: dt=0.3736, 15 negative triangles
# 452: dt=0.3736, 15 negative triangles
# 453: dt=0.3736, 15 negative triangles
# 454: dt=0.3736, 15 negative triangles
# 455: dt=0.3736, 15 negative triangles
# 456: dt=0.3736, 15 negative triangles
# 457: dt=0.3736, 15 negative triangles
# 458: dt=0.3736, 15 negative triangles
# 459: dt=0.3736, 15 negative triangles
# 460: dt=0.3736, 15 negative triangles
# 461: dt=0.3549, 15 negative triangles
# 462: dt=0.3549, 15 negative triangles
# 463: dt=0.3549, 15 negative triangles
# 464: dt=0.3549, 15 negative triangles
# 465: dt=0.3549, 15 negative triangles
# 466: dt=0.3549, 15 negative triangles
# 467: dt=0.3549, 15 negative triangles
# 468: dt=0.3549, 15 negative triangles
# 469: dt=0.3549, 15 negative triangles
# 470: dt=0.3549, 15 negative triangles
# 471: dt=0.3372, 15 negative triangles
# 472: dt=0.3372, 15 negative triangles
# 473: dt=0.3372, 15 negative triangles
# 474: dt=0.3372, 15 negative triangles
# 475: dt=0.3372, 15 negative triangles
# 476: dt=0.3372, 15 negative triangles
# 477: dt=0.3372, 15 negative triangles
# 478: dt=0.3372, 15 negative triangles
# 479: dt=0.3372, 15 negative triangles
# 480: dt=0.3372, 15 negative triangles
# 481: dt=0.3203, 15 negative triangles
# 482: dt=0.3203, 15 negative triangles
# 483: dt=0.3203, 15 negative triangles
# 484: dt=0.3203, 15 negative triangles
# 485: dt=0.3203, 15 negative triangles
# 486: dt=0.3203, 15 negative triangles
# 487: dt=0.3203, 15 negative triangles
# 488: dt=0.3203, 15 negative triangles
# 489: dt=0.3203, 15 negative triangles
# 490: dt=0.3203, 15 negative triangles
# 491: dt=0.3043, 15 negative triangles
# 492: dt=0.3043, 15 negative triangles
# 493: dt=0.3043, 15 negative triangles
# 494: dt=0.3043, 15 negative triangles
# 495: dt=0.3043, 15 negative triangles
# 496: dt=0.3043, 15 negative triangles
# 497: dt=0.3043, 15 negative triangles
# 498: dt=0.3043, 15 negative triangles
# 499: dt=0.3043, 15 negative triangles
# 500: dt=0.3043, 15 negative triangles
# 501: dt=0.2891, 15 negative triangles
# 502: dt=0.2891, 15 negative triangles
# 503: dt=0.2891, 15 negative triangles
# 504: dt=0.2891, 15 negative triangles
# 505: dt=0.2891, 15 negative triangles
# 506: dt=0.2891, 15 negative triangles
# 507: dt=0.2891, 15 negative triangles
# 508: dt=0.2891, 15 negative triangles
# 509: dt=0.2891, 15 negative triangles
# 510: dt=0.2891, 15 negative triangles
# 511: dt=0.2746, 15 negative triangles
# 512: dt=0.2746, 15 negative triangles
# 513: dt=0.2746, 15 negative triangles
# 514: dt=0.2746, 15 negative triangles
# 515: dt=0.2746, 15 negative triangles
# 516: dt=0.2746, 15 negative triangles
# 517: dt=0.2746, 15 negative triangles
# 518: dt=0.2746, 15 negative triangles
# 519: dt=0.2746, 15 negative triangles
# 520: dt=0.2746, 15 negative triangles
# 521: dt=0.2609, 15 negative triangles
# 522: dt=0.2609, 15 negative triangles
# 523: dt=0.2609, 15 negative triangles
# 524: dt=0.2609, 15 negative triangles
# 525: dt=0.2609, 15 negative triangles
# 526: dt=0.2609, 15 negative triangles
# 527: dt=0.2609, 15 negative triangles
# 528: dt=0.2609, 15 negative triangles
# 529: dt=0.2609, 15 negative triangles
# 530: dt=0.2609, 15 negative triangles
# 531: dt=0.2478, 15 negative triangles
# 532: dt=0.2478, 15 negative triangles
# 533: dt=0.2478, 15 negative triangles
# 534: dt=0.2478, 15 negative triangles
# 535: dt=0.2478, 15 negative triangles
# 536: dt=0.2478, 15 negative triangles
# 537: dt=0.2478, 15 negative triangles
# 538: dt=0.2478, 15 negative triangles
# 539: dt=0.2478, 15 negative triangles
# 540: dt=0.2478, 15 negative triangles
# 541: dt=0.2354, 15 negative triangles
# 542: dt=0.2354, 15 negative triangles
# 543: dt=0.2354, 15 negative triangles
# 544: dt=0.2354, 15 negative triangles
# 545: dt=0.2354, 15 negative triangles
# 546: dt=0.2354, 15 negative triangles
# 547: dt=0.2354, 15 negative triangles
# 548: dt=0.2354, 15 negative triangles
# 549: dt=0.2354, 15 negative triangles
# 550: dt=0.2354, 15 negative triangles
# 551: dt=0.2237, 15 negative triangles
# 552: dt=0.2237, 15 negative triangles
# 553: dt=0.2237, 15 negative triangles
# 554: dt=0.2237, 15 negative triangles
# 555: dt=0.2237, 15 negative triangles
# 556: dt=0.2237, 15 negative triangles
# 557: dt=0.2237, 15 negative triangles
# 558: dt=0.2237, 15 negative triangles
# 559: dt=0.2237, 15 negative triangles
# 560: dt=0.2237, 15 negative triangles
# 561: dt=0.2125, 15 negative triangles
# 562: dt=0.2125, 15 negative triangles
# 563: dt=0.2125, 15 negative triangles
# 564: dt=0.2125, 15 negative triangles
# 565: dt=0.2125, 15 negative triangles
# 566: dt=0.2125, 15 negative triangles
# 567: dt=0.2125, 15 negative triangles
# 568: dt=0.2125, 15 negative triangles
# 569: dt=0.2125, 15 negative triangles
# 570: dt=0.2125, 15 negative triangles
# 571: dt=0.2019, 15 negative triangles
# 572: dt=0.2019, 15 negative triangles
# 573: dt=0.2019, 15 negative triangles
# 574: dt=0.2019, 15 negative triangles
# 575: dt=0.2019, 15 negative triangles
# 576: dt=0.2019, 15 negative triangles
# 577: dt=0.2019, 15 negative triangles
# 578: dt=0.2019, 15 negative triangles
# 579: dt=0.2019, 15 negative triangles
# 580: dt=0.2019, 15 negative triangles
# 581: dt=0.1918, 15 negative triangles
# 582: dt=0.1918, 15 negative triangles
# 583: dt=0.1918, 15 negative triangles
# 584: dt=0.1918, 15 negative triangles
# 585: dt=0.1918, 15 negative triangles
# 586: dt=0.1918, 15 negative triangles
# 587: dt=0.1918, 15 negative triangles
# 588: dt=0.1918, 15 negative triangles
# 589: dt=0.1918, 15 negative triangles
# 590: dt=0.1918, 15 negative triangles
# 591: dt=0.1822, 15 negative triangles
# 592: dt=0.1822, 15 negative triangles
# 593: dt=0.1822, 15 negative triangles
# 594: dt=0.1822, 15 negative triangles
# 595: dt=0.1822, 15 negative triangles
# 596: dt=0.1822, 15 negative triangles
# 597: dt=0.1822, 15 negative triangles
# 598: dt=0.1822, 15 negative triangles
# 599: dt=0.1822, 15 negative triangles
# 600: dt=0.1822, 15 negative triangles
# 601: dt=0.1731, 15 negative triangles
# 602: dt=0.1731, 15 negative triangles
# 603: dt=0.1731, 15 negative triangles
# 604: dt=0.1731, 15 negative triangles
# 605: dt=0.1731, 15 negative triangles
# 606: dt=0.1731, 15 negative triangles
# 607: dt=0.1731, 15 negative triangles
# 608: dt=0.1731, 15 negative triangles
# 609: dt=0.1731, 15 negative triangles
# 610: dt=0.1731, 15 negative triangles
# 611: dt=0.1644, 15 negative triangles
# 612: dt=0.1644, 15 negative triangles
# 613: dt=0.1644, 15 negative triangles
# 614: dt=0.1644, 15 negative triangles
# 615: dt=0.1644, 15 negative triangles
# 616: dt=0.1644, 15 negative triangles
# 617: dt=0.1644, 15 negative triangles
# 618: dt=0.1644, 15 negative triangles
# 619: dt=0.1644, 15 negative triangles
# 620: dt=0.1644, 15 negative triangles
# 621: dt=0.1562, 15 negative triangles
# 622: dt=0.1562, 15 negative triangles
# 623: dt=0.1562, 15 negative triangles
# 624: dt=0.1562, 15 negative triangles
# 625: dt=0.1562, 15 negative triangles
# 626: dt=0.1562, 15 negative triangles
# 627: dt=0.1562, 15 negative triangles
# 628: dt=0.1562, 15 negative triangles
# 629: dt=0.1562, 15 negative triangles
# 630: dt=0.1562, 15 negative triangles
# 631: dt=0.1484, 15 negative triangles
# 632: dt=0.1484, 15 negative triangles
# 633: dt=0.1484, 15 negative triangles
# 634: dt=0.1484, 15 negative triangles
# 635: dt=0.1484, 15 negative triangles
# 636: dt=0.1484, 15 negative triangles
# 637: dt=0.1484, 15 negative triangles
# 638: dt=0.1484, 15 negative triangles
# 639: dt=0.1484, 15 negative triangles
# 640: dt=0.1484, 15 negative triangles
# 641: dt=0.1410, 15 negative triangles
# 642: dt=0.1410, 15 negative triangles
# 643: dt=0.1410, 15 negative triangles
# 644: dt=0.1410, 15 negative triangles
# 645: dt=0.1410, 15 negative triangles
# 646: dt=0.1410, 15 negative triangles
# 647: dt=0.1410, 15 negative triangles
# 648: dt=0.1410, 15 negative triangles
# 649: dt=0.1410, 15 negative triangles
# 650: dt=0.1410, 15 negative triangles
# 651: dt=0.1339, 15 negative triangles
# 652: dt=0.1339, 15 negative triangles
# 653: dt=0.1339, 15 negative triangles
# 654: dt=0.1339, 15 negative triangles
# 655: dt=0.1339, 15 negative triangles
# 656: dt=0.1339, 15 negative triangles
# 657: dt=0.1339, 15 negative triangles
# 658: dt=0.1339, 15 negative triangles
# 659: dt=0.1339, 15 negative triangles
# 660: dt=0.1339, 15 negative triangles
# 661: dt=0.1272, 15 negative triangles
# 662: dt=0.1272, 15 negative triangles
# 663: dt=0.1272, 15 negative triangles
# 664: dt=0.1272, 15 negative triangles
# 665: dt=0.1272, 15 negative triangles
# 666: dt=0.1272, 15 negative triangles
# 667: dt=0.1272, 15 negative triangles
# 668: dt=0.1272, 15 negative triangles
# 669: dt=0.1272, 15 negative triangles
# 670: dt=0.1272, 15 negative triangles
# 671: dt=0.1209, 15 negative triangles
# 672: dt=0.1209, 15 negative triangles
# 673: dt=0.1209, 15 negative triangles
# 674: dt=0.1209, 15 negative triangles
# 675: dt=0.1209, 15 negative triangles
# 676: dt=0.1209, 15 negative triangles
# 677: dt=0.1209, 15 negative triangles
# 678: dt=0.1209, 15 negative triangles
# 679: dt=0.1209, 15 negative triangles
# 680: dt=0.1209, 15 negative triangles
# 681: dt=0.1148, 15 negative triangles
# 682: dt=0.1148, 15 negative triangles
# 683: dt=0.1148, 15 negative triangles
# 684: dt=0.1148, 15 negative triangles
# 685: dt=0.1148, 15 negative triangles
# 686: dt=0.1148, 15 negative triangles
# 687: dt=0.1148, 15 negative triangles
# 688: dt=0.1148, 15 negative triangles
# 689: dt=0.1148, 15 negative triangles
# 690: dt=0.1148, 15 negative triangles
# 691: dt=0.1091, 15 negative triangles
# 692: dt=0.1091, 15 negative triangles
# 693: dt=0.1091, 15 negative triangles
# 694: dt=0.1091, 15 negative triangles
# 695: dt=0.1091, 15 negative triangles
# 696: dt=0.1091, 15 negative triangles
# 697: dt=0.1091, 15 negative triangles
# 698: dt=0.1091, 15 negative triangles
# 699: dt=0.1091, 15 negative triangles
# 700: dt=0.1091, 15 negative triangles
# 701: dt=0.1036, 15 negative triangles
# 702: dt=0.1036, 15 negative triangles
# 703: dt=0.1036, 15 negative triangles
# 704: dt=0.1036, 15 negative triangles
# 705: dt=0.1036, 15 negative triangles
# 706: dt=0.1036, 15 negative triangles
# 707: dt=0.1036, 15 negative triangles
# 708: dt=0.1036, 15 negative triangles
# 709: dt=0.1036, 15 negative triangles
# 710: dt=0.1036, 15 negative triangles
# 711: dt=0.0984, 15 negative triangles
# 712: dt=0.0984, 15 negative triangles
# 713: dt=0.0984, 15 negative triangles
# 714: dt=0.0984, 15 negative triangles
# 715: dt=0.0984, 15 negative triangles
# 716: dt=0.0984, 15 negative triangles
# 717: dt=0.0984, 15 negative triangles
# 718: dt=0.0984, 15 negative triangles
# 719: dt=0.0984, 15 negative triangles
# 720: dt=0.0984, 15 negative triangles
# 721: dt=0.0935, 15 negative triangles
# 722: dt=0.0935, 15 negative triangles
# 723: dt=0.0935, 15 negative triangles
# 724: dt=0.0935, 15 negative triangles
# 725: dt=0.0935, 15 negative triangles
# 726: dt=0.0935, 15 negative triangles
# 727: dt=0.0935, 15 negative triangles
# 728: dt=0.0935, 15 negative triangles
# 729: dt=0.0935, 15 negative triangles
# 730: dt=0.0935, 15 negative triangles
# 731: dt=0.0888, 15 negative triangles
# 732: dt=0.0888, 15 negative triangles
# 733: dt=0.0888, 15 negative triangles
# 734: dt=0.0888, 15 negative triangles
# 735: dt=0.0888, 15 negative triangles
# 736: dt=0.0888, 15 negative triangles
# 737: dt=0.0888, 15 negative triangles
# 738: dt=0.0888, 15 negative triangles
# 739: dt=0.0888, 15 negative triangles
# 740: dt=0.0888, 15 negative triangles
# 741: dt=0.0844, 15 negative triangles
# 742: dt=0.0844, 15 negative triangles
# 743: dt=0.0844, 15 negative triangles
# 744: dt=0.0844, 15 negative triangles
# 745: dt=0.0844, 15 negative triangles
# 746: dt=0.0844, 15 negative triangles
# 747: dt=0.0844, 15 negative triangles
# 748: dt=0.0844, 15 negative triangles
# 749: dt=0.0844, 15 negative triangles
# 750: dt=0.0844, 15 negative triangles
# 751: dt=0.0802, 15 negative triangles
# 752: dt=0.0802, 15 negative triangles
# 753: dt=0.0802, 15 negative triangles
# 754: dt=0.0802, 15 negative triangles
# 755: dt=0.0802, 15 negative triangles
# 756: dt=0.0802, 15 negative triangles
# 757: dt=0.0802, 15 negative triangles
# 758: dt=0.0802, 15 negative triangles
# 759: dt=0.0802, 15 negative triangles
# 760: dt=0.0802, 15 negative triangles
# 761: dt=0.0762, 15 negative triangles
# 762: dt=0.0762, 15 negative triangles
# 763: dt=0.0762, 15 negative triangles
# 764: dt=0.0762, 15 negative triangles
# 765: dt=0.0762, 15 negative triangles
# 766: dt=0.0762, 15 negative triangles
# 767: dt=0.0762, 15 negative triangles
# 768: dt=0.0762, 15 negative triangles
# 769: dt=0.0762, 15 negative triangles
# 770: dt=0.0762, 15 negative triangles
# 771: dt=0.0724, 15 negative triangles
# 772: dt=0.0724, 15 negative triangles
# 773: dt=0.0724, 15 negative triangles
# 774: dt=0.0724, 15 negative triangles
# 775: dt=0.0724, 15 negative triangles
# 776: dt=0.0724, 15 negative triangles
# 777: dt=0.0724, 15 negative triangles
# 778: dt=0.0724, 15 negative triangles
# 779: dt=0.0724, 15 negative triangles
# 780: dt=0.0724, 15 negative triangles
# 781: dt=0.0687, 15 negative triangles
# 782: dt=0.0687, 15 negative triangles
# 783: dt=0.0687, 15 negative triangles
# 784: dt=0.0687, 15 negative triangles
# 785: dt=0.0687, 15 negative triangles
# 786: dt=0.0687, 15 negative triangles
# 787: dt=0.0687, 15 negative triangles
# 788: dt=0.0687, 15 negative triangles
# 789: dt=0.0687, 15 negative triangles
# 790: dt=0.0687, 15 negative triangles
# 791: dt=0.0653, 15 negative triangles
# 792: dt=0.0653, 15 negative triangles
# 793: dt=0.0653, 15 negative triangles
# 794: dt=0.0653, 15 negative triangles
# 795: dt=0.0653, 15 negative triangles
# 796: dt=0.0653, 15 negative triangles
# 797: dt=0.0653, 15 negative triangles
# 798: dt=0.0653, 15 negative triangles
# 799: dt=0.0653, 15 negative triangles
# 800: dt=0.0653, 15 negative triangles
# 801: dt=0.0620, 15 negative triangles
# 802: dt=0.0620, 15 negative triangles
# 803: dt=0.0620, 15 negative triangles
# 804: dt=0.0620, 15 negative triangles
# 805: dt=0.0620, 15 negative triangles
# 806: dt=0.0620, 15 negative triangles
# 807: dt=0.0620, 15 negative triangles
# 808: dt=0.0620, 15 negative triangles
# 809: dt=0.0620, 15 negative triangles
# 810: dt=0.0620, 15 negative triangles
# 811: dt=0.0589, 15 negative triangles
# 812: dt=0.0589, 15 negative triangles
# 813: dt=0.0589, 15 negative triangles
# 814: dt=0.0589, 15 negative triangles
# 815: dt=0.0589, 15 negative triangles
# 816: dt=0.0589, 15 negative triangles
# 817: dt=0.0589, 15 negative triangles
# 818: dt=0.0589, 15 negative triangles
# 819: dt=0.0589, 15 negative triangles
# 820: dt=0.0589, 15 negative triangles
# 821: dt=0.0560, 15 negative triangles
# 822: dt=0.0560, 15 negative triangles
# 823: dt=0.0560, 15 negative triangles
# 824: dt=0.0560, 15 negative triangles
# 825: dt=0.0560, 15 negative triangles
# 826: dt=0.0560, 15 negative triangles
# 827: dt=0.0560, 15 negative triangles
# 828: dt=0.0560, 15 negative triangles
# 829: dt=0.0560, 15 negative triangles
# 830: dt=0.0560, 15 negative triangles
# 831: dt=0.0532, 15 negative triangles
# 832: dt=0.0532, 15 negative triangles
# 833: dt=0.0532, 15 negative triangles
# 834: dt=0.0532, 15 negative triangles
# 835: dt=0.0532, 15 negative triangles
# 836: dt=0.0532, 15 negative triangles
# 837: dt=0.0532, 15 negative triangles
# 838: dt=0.0532, 15 negative triangles
# 839: dt=0.0532, 15 negative triangles
# 840: dt=0.0532, 15 negative triangles
# 841: dt=0.0505, 15 negative triangles
# 842: dt=0.0505, 15 negative triangles
# 843: dt=0.0505, 15 negative triangles
# 844: dt=0.0505, 15 negative triangles
# 845: dt=0.0505, 15 negative triangles
# 846: dt=0.0505, 15 negative triangles
# 847: dt=0.0505, 15 negative triangles
# 848: dt=0.0505, 15 negative triangles
# 849: dt=0.0505, 15 negative triangles
# 850: dt=0.0505, 15 negative triangles
# 851: dt=0.0480, 15 negative triangles
# 852: dt=0.0480, 15 negative triangles
# 853: dt=0.0480, 15 negative triangles
# 854: dt=0.0480, 15 negative triangles
# 855: dt=0.0480, 15 negative triangles
# 856: dt=0.0480, 15 negative triangles
# 857: dt=0.0480, 15 negative triangles
# 858: dt=0.0480, 15 negative triangles
# 859: dt=0.0480, 15 negative triangles
# 860: dt=0.0480, 15 negative triangles
# 861: dt=0.0456, 15 negative triangles
# 862: dt=0.0456, 15 negative triangles
# 863: dt=0.0456, 15 negative triangles
# 864: dt=0.0456, 15 negative triangles
# 865: dt=0.0456, 15 negative triangles
# 866: dt=0.0456, 15 negative triangles
# 867: dt=0.0456, 15 negative triangles
# 868: dt=0.0456, 15 negative triangles
# 869: dt=0.0456, 15 negative triangles
# 870: dt=0.0456, 15 negative triangles
# 871: dt=0.0433, 15 negative triangles
# 872: dt=0.0433, 15 negative triangles
# 873: dt=0.0433, 15 negative triangles
# 874: dt=0.0433, 15 negative triangles
# 875: dt=0.0433, 15 negative triangles
# 876: dt=0.0433, 15 negative triangles
# 877: dt=0.0433, 15 negative triangles
# 878: dt=0.0433, 15 negative triangles
# 879: dt=0.0433, 15 negative triangles
# 880: dt=0.0433, 15 negative triangles
# 881: dt=0.0412, 15 negative triangles
# 882: dt=0.0412, 15 negative triangles
# 883: dt=0.0412, 15 negative triangles
# 884: dt=0.0412, 15 negative triangles
# 885: dt=0.0412, 15 negative triangles
# 886: dt=0.0412, 15 negative triangles
# 887: dt=0.0412, 15 negative triangles
# 888: dt=0.0412, 15 negative triangles
# 889: dt=0.0412, 15 negative triangles
# 890: dt=0.0412, 15 negative triangles
# 891: dt=0.0391, 15 negative triangles
# 892: dt=0.0391, 15 negative triangles
# 893: dt=0.0391, 15 negative triangles
# 894: dt=0.0391, 15 negative triangles
# 895: dt=0.0391, 15 negative triangles
# 896: dt=0.0391, 15 negative triangles
# 897: dt=0.0391, 15 negative triangles
# 898: dt=0.0391, 15 negative triangles
# 899: dt=0.0391, 15 negative triangles
# 900: dt=0.0391, 15 negative triangles
# 901: dt=0.0371, 15 negative triangles
# 902: dt=0.0371, 15 negative triangles
# 903: dt=0.0371, 15 negative triangles
# 904: dt=0.0371, 15 negative triangles
# 905: dt=0.0371, 15 negative triangles
# 906: dt=0.0371, 15 negative triangles
# 907: dt=0.0371, 15 negative triangles
# 908: dt=0.0371, 15 negative triangles
# 909: dt=0.0371, 15 negative triangles
# 910: dt=0.0371, 15 negative triangles
# 911: dt=0.0353, 15 negative triangles
# 912: dt=0.0353, 15 negative triangles
# 913: dt=0.0353, 15 negative triangles
# 914: dt=0.0353, 15 negative triangles
# 915: dt=0.0353, 15 negative triangles
# 916: dt=0.0353, 15 negative triangles
# 917: dt=0.0353, 15 negative triangles
# 918: dt=0.0353, 15 negative triangles
# 919: dt=0.0353, 15 negative triangles
# 920: dt=0.0353, 15 negative triangles
# 921: dt=0.0335, 15 negative triangles
# 922: dt=0.0335, 15 negative triangles
# 923: dt=0.0335, 15 negative triangles
# 924: dt=0.0335, 15 negative triangles
# 925: dt=0.0335, 15 negative triangles
# 926: dt=0.0335, 15 negative triangles
# 927: dt=0.0335, 15 negative triangles
# 928: dt=0.0335, 15 negative triangles
# 929: dt=0.0335, 15 negative triangles
# 930: dt=0.0335, 15 negative triangles
# 931: dt=0.0319, 15 negative triangles
# 932: dt=0.0319, 15 negative triangles
# 933: dt=0.0319, 15 negative triangles
# 934: dt=0.0319, 15 negative triangles
# 935: dt=0.0319, 15 negative triangles
# 936: dt=0.0319, 15 negative triangles
# 937: dt=0.0319, 15 negative triangles
# 938: dt=0.0319, 15 negative triangles
# 939: dt=0.0319, 15 negative triangles
# 940: dt=0.0319, 15 negative triangles
# 941: dt=0.0303, 15 negative triangles
# 942: dt=0.0303, 15 negative triangles
# 943: dt=0.0303, 15 negative triangles
# 944: dt=0.0303, 15 negative triangles
# 945: dt=0.0303, 15 negative triangles
# 946: dt=0.0303, 15 negative triangles
# 947: dt=0.0303, 15 negative triangles
# 948: dt=0.0303, 15 negative triangles
# 949: dt=0.0303, 15 negative triangles
# 950: dt=0.0303, 15 negative triangles
# 951: dt=0.0287, 15 negative triangles
# 952: dt=0.0287, 15 negative triangles
# 953: dt=0.0287, 15 negative triangles
# 954: dt=0.0287, 15 negative triangles
# 955: dt=0.0287, 15 negative triangles
# 956: dt=0.0287, 15 negative triangles
# 957: dt=0.0287, 15 negative triangles
# 958: dt=0.0287, 15 negative triangles
# 959: dt=0.0287, 15 negative triangles
# 960: dt=0.0287, 15 negative triangles
# 961: dt=0.0273, 15 negative triangles
# 962: dt=0.0273, 15 negative triangles
# 963: dt=0.0273, 15 negative triangles
# 964: dt=0.0273, 15 negative triangles
# 965: dt=0.0273, 15 negative triangles
# 966: dt=0.0273, 15 negative triangles
# 967: dt=0.0273, 15 negative triangles
# 968: dt=0.0273, 15 negative triangles
# 969: dt=0.0273, 15 negative triangles
# 970: dt=0.0273, 15 negative triangles
# 971: dt=0.0259, 15 negative triangles
# 972: dt=0.0259, 15 negative triangles
# 973: dt=0.0259, 15 negative triangles
# 974: dt=0.0259, 15 negative triangles
# 975: dt=0.0259, 15 negative triangles
# 976: dt=0.0259, 15 negative triangles
# 977: dt=0.0259, 15 negative triangles
# 978: dt=0.0259, 15 negative triangles
# 979: dt=0.0259, 15 negative triangles
# 980: dt=0.0259, 15 negative triangles
# 981: dt=0.0246, 15 negative triangles
# 982: dt=0.0246, 15 negative triangles
# 983: dt=0.0246, 15 negative triangles
# 984: dt=0.0246, 15 negative triangles
# 985: dt=0.0246, 15 negative triangles
# 986: dt=0.0246, 15 negative triangles
# 987: dt=0.0246, 15 negative triangles
# 988: dt=0.0246, 15 negative triangles
# 989: dt=0.0246, 15 negative triangles
# 990: dt=0.0246, 15 negative triangles
# 991: dt=0.0234, 15 negative triangles
# 992: dt=0.0234, 15 negative triangles
# 993: dt=0.0234, 15 negative triangles
# 994: dt=0.0234, 15 negative triangles
# 995: dt=0.0234, 15 negative triangles
# 996: dt=0.0234, 15 negative triangles
# 997: dt=0.0234, 15 negative triangles
# 998: dt=0.0234, 15 negative triangles
# 999: dt=0.0234, 15 negative triangles
# 1000: dt=0.0234, 15 negative triangles
# 1001: dt=0.0222, 15 negative triangles
# 1002: dt=0.0222, 15 negative triangles
# 1003: dt=0.0222, 15 negative triangles
# 1004: dt=0.0222, 15 negative triangles
# ...
# 1085: dt=0.0148, 15 negative triangles
# 1086: dt=0.0148, 15 negative triangles
# 1087: dt=0.0148, 15 negative triangles
# 1088: dt=0.0148, 15 negative triangles
# 1089: dt=0.0148, 15 negative triangles
# 1090: dt=0.0148, 15 negative triangles
# 1091: dt=0.0140, 15 negative triangles
# 1092: dt=0.0140, 15 negative triangles
# 1093: dt=0.0140, 15 negative triangles
# 1094: dt=0.0140, 15 negative triangles
# 1095: dt=0.0140, 15 negative triangles
# 1096: dt=0.0140, 15 negative triangles
# 1097: dt=0.0140, 15 negative triangles
# 1098: dt=0.0140, 15 negative triangles
# 1099: dt=0.0140, 15 negative triangles
# 1100: dt=0.0140, 15 negative triangles
# 1101: dt=0.0133, 15 negative triangles
# 1102: dt=0.0133, 15 negative triangles
# 1103: dt=0.0133, 15 negative triangles
# 1104: dt=0.0133, 15 negative triangles
# 1105: dt=0.0133, 15 negative triangles
# 1106: dt=0.0133, 15 negative triangles
# 1107: dt=0.0133, 15 negative triangles
# 1108: dt=0.0133, 15 negative triangles
# 1109: dt=0.0133, 15 negative triangles
# 1110: dt=0.0133, 15 negative triangles
# 1111: dt=0.0127, 15 negative triangles
# 1112: dt=0.0127, 15 negative triangles
# 1113: dt=0.0127, 15 negative triangles
# 1114: dt=0.0127, 15 negative triangles
# 1115: dt=0.0127, 15 negative triangles
# 1116: dt=0.0127, 15 negative triangles
# 1117: dt=0.0127, 15 negative triangles
# 1118: dt=0.0127, 15 negative triangles
# 1119: dt=0.0127, 15 negative triangles
# 1120: dt=0.0127, 15 negative triangles
# 1121: dt=0.0120, 15 negative triangles
# 1122: dt=0.0120, 15 negative triangles
# 1123: dt=0.0120, 15 negative triangles
# 1124: dt=0.0120, 15 negative triangles
# 1125: dt=0.0120, 15 negative triangles
# 1126: dt=0.0120, 15 negative triangles
# 1127: dt=0.0120, 15 negative triangles
# 1128: dt=0.0120, 15 negative triangles
# 1129: dt=0.0120, 15 negative triangles
# 1130: dt=0.0120, 15 negative triangles
# 1131: dt=0.0114, 15 negative triangles
# 1132: dt=0.0114, 15 negative triangles
# 1133: dt=0.0114, 15 negative triangles
# 1134: dt=0.0114, 15 negative triangles
# 1135: dt=0.0114, 15 negative triangles
# 1136: dt=0.0114, 15 negative triangles
# 1137: dt=0.0114, 15 negative triangles
# 1138: dt=0.0114, 15 negative triangles
# 1139: dt=0.0114, 15 negative triangles
# 1140: dt=0.0114, 15 negative triangles
# 1141: dt=0.0108, 15 negative triangles
# 1142: dt=0.0108, 15 negative triangles
# 1143: dt=0.0108, 15 negative triangles
# 1144: dt=0.0108, 15 negative triangles
# 1145: dt=0.0108, 15 negative triangles
# 1146: dt=0.0108, 15 negative triangles
# 1147: dt=0.0108, 15 negative triangles
# 1148: dt=0.0108, 15 negative triangles
# 1149: dt=0.0108, 15 negative triangles
# 1150: dt=0.0108, 15 negative triangles
# 1151: dt=0.0103, 15 negative triangles
# 1152: dt=0.0103, 15 negative triangles
# 1153: dt=0.0103, 15 negative triangles
# 1154: dt=0.0103, 15 negative triangles
# 1155: dt=0.0103, 15 negative triangles
# 1156: dt=0.0103, 15 negative triangles
# 1157: dt=0.0103, 15 negative triangles
# 1158: dt=0.0103, 15 negative triangles
# 1159: dt=0.0103, 15 negative triangles
# 1160: dt=0.0103, 15 negative triangles
# 1161: dt=0.0098, 15 negative triangles
# 1162: dt=0.0098, 15 negative triangles
# 1163: dt=0.0098, 15 negative triangles
# 1164: dt=0.0098, 15 negative triangles
# 1165: dt=0.0098, 15 negative triangles
# 1166: dt=0.0098, 15 negative triangles
# 1167: dt=0.0098, 15 negative triangles
# 1168: dt=0.0098, 15 negative triangles
# 1169: dt=0.0098, 15 negative triangles
# 1170: dt=0.0098, 15 negative triangles
# 1171: dt=0.0098, 15 negative triangles
# 1172: dt=0.0098, 15 negative triangles
# 1173: dt=0.0098, 15 negative triangles
# 1174: dt=0.0098, 15 negative triangles
# 1175: dt=0.0098, 15 negative triangles
# 1176: dt=0.0098, 15 negative triangles
# 1177: dt=0.0098, 15 negative triangles
# 1178: dt=0.0098, 15 negative triangles
# 1179: dt=0.0098, 15 negative triangles
# 1180: dt=0.0098, 15 negative triangles
# 1181: dt=0.0098, 15 negative triangles
# 1182: dt=0.0098, 15 negative triangles
# 1183: dt=0.0098, 15 negative triangles
# 1184: dt=0.0098, 15 negative triangles
# 1185: dt=0.0098, 15 negative triangles
# 1186: dt=0.0098, 15 negative triangles
# 1187: dt=0.0098, 15 negative triangles
# 1188: dt=0.0098, 15 negative triangles
# 1189: dt=0.0098, 15 negative triangles
# 1190: dt=0.0098, 15 negative triangles
# 1191: dt=0.0098, 15 negative triangles
# 1192: dt=0.0098, 15 negative triangles
# 1193: dt=0.0098, 15 negative triangles
# 1194: dt=0.0098, 15 negative triangles
# 1195: dt=0.0098, 15 negative triangles
# 1196: dt=0.0098, 15 negative triangles
# 1197: dt=0.0098, 15 negative triangles
# 1198: dt=0.0098, 15 negative triangles
# 1199: dt=0.0098, 15 negative triangles
# 1200: dt=0.0098, 15 negative triangles
# 1201: dt=0.0098, 15 negative triangles
# 1202: dt=0.0098, 15 negative triangles
# 1203: dt=0.0098, 15 negative triangles
# 1204: dt=0.0098, 15 negative triangles
# 1205: dt=0.0098, 15 negative triangles
# 1206: dt=0.0098, 15 negative triangles
# 1207: dt=0.0098, 15 negative triangles
# 1208: dt=0.0098, 15 negative triangles
# 1209: dt=0.0098, 15 negative triangles
# 1210: dt=0.0098, 15 negative triangles
# 1211: dt=0.0098, 15 negative triangles
# 1212: dt=0.0098, 15 negative triangles
# 1213: dt=0.0098, 15 negative triangles
# 1214: dt=0.0098, 15 negative triangles
# 1215: dt=0.0098, 15 negative triangles
# 1216: dt=0.0098, 15 negative triangles
# 1217: dt=0.0098, 15 negative triangles
# 1218: dt=0.0098, 15 negative triangles
# 1219: dt=0.0098, 15 negative triangles
# 1220: dt=0.0098, 15 negative triangles
# 1221: dt=0.0098, 15 negative triangles
# 1222: dt=0.0098, 15 negative triangles
# 1223: dt=0.0098, 15 negative triangles
# 1224: dt=0.0098, 15 negative triangles
# 1225: dt=0.0098, 15 negative triangles
# 1226: dt=0.0098, 15 negative triangles
# 1227: dt=0.0098, 15 negative triangles
# 1228: dt=0.0098, 15 negative triangles
# 1229: dt=0.0098, 15 negative triangles
# 1230: dt=0.0098, 15 negative triangles
# 1231: dt=0.0098, 15 negative triangles
# 1232: dt=0.0098, 15 negative triangles
# 1233: dt=0.0098, 15 negative triangles
# 1234: dt=0.0098, 15 negative triangles
# 1235: dt=0.0098, 15 negative triangles
# 1236: dt=0.0098, 15 negative triangles
# 1237: 15 negative triangles
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/lh.sphere
# mris_sphere utimesec    2305.777154
# mris_sphere stimesec    1.003998
# mris_sphere ru_maxrss   140916
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   33409
# mris_sphere ru_majflt   0
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1468
# mris_sphere ru_nivcsw   5086
# spherical transformation took 0.64 hours
# FSRUNTIME@ mris_sphere  0.6408 hours 1 threads
#
# counting number of connected components...
#    76940 voxel in cpt #1: X=-4 [v=76940,e=230832,f=153888] located at (26.313257, -6.405134, 7.681856)
# For the whole surface: X=-4 [v=76940,e=230832,f=153888]
# One single component has been found
# nothing to do
# done
#
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.smoothwm
# avg radius = 39.1 mm, total surface area = 45133 mm^2
# step 060: RMS=0.031 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.sulc
# mris_inflate utimesec    16.263544
# mris_inflate stimesec    0.424301
# mris_inflate ru_maxrss   105016
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   24586
# mris_inflate ru_majflt   0
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  80
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1867
# mris_inflate ru_nivcsw   360
# inflation took 0.3 minutes
# doing quick spherical unfolding.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.355...
# inflating to sphere (rms error < 2.00)
# 000: dt: 0.0000, rms radial error=178.678, avgs=0
# 005/300: dt: 0.9000, rms radial error=178.421, avgs=0
# 010/300: dt: 0.9000, rms radial error=177.871, avgs=0
# 015/300: dt: 0.9000, rms radial error=177.148, avgs=0
# 020/300: dt: 0.9000, rms radial error=176.324, avgs=0
# 025/300: dt: 0.9000, rms radial error=175.443, avgs=0
# 030/300: dt: 0.9000, rms radial error=174.528, avgs=0
# 035/300: dt: 0.9000, rms radial error=173.597, avgs=0
# 040/300: dt: 0.9000, rms radial error=172.656, avgs=0
# 045/300: dt: 0.9000, rms radial error=171.711, avgs=0
# 050/300: dt: 0.9000, rms radial error=170.765, avgs=0
# 055/300: dt: 0.9000, rms radial error=169.822, avgs=0
# 060/300: dt: 0.9000, rms radial error=168.881, avgs=0
# 065/300: dt: 0.9000, rms radial error=167.945, avgs=0
# 070/300: dt: 0.9000, rms radial error=167.012, avgs=0
# 075/300: dt: 0.9000, rms radial error=166.083, avgs=0
# 080/300: dt: 0.9000, rms radial error=165.158, avgs=0
# 085/300: dt: 0.9000, rms radial error=164.237, avgs=0
# 090/300: dt: 0.9000, rms radial error=163.321, avgs=0
# 095/300: dt: 0.9000, rms radial error=162.410, avgs=0
# 100/300: dt: 0.9000, rms radial error=161.503, avgs=0
# 105/300: dt: 0.9000, rms radial error=160.600, avgs=0
# 110/300: dt: 0.9000, rms radial error=159.702, avgs=0
# 115/300: dt: 0.9000, rms radial error=158.809, avgs=0
# 120/300: dt: 0.9000, rms radial error=157.920, avgs=0
# 125/300: dt: 0.9000, rms radial error=157.036, avgs=0
# 130/300: dt: 0.9000, rms radial error=156.157, avgs=0
# 135/300: dt: 0.9000, rms radial error=155.282, avgs=0
# 140/300: dt: 0.9000, rms radial error=154.411, avgs=0
# 145/300: dt: 0.9000, rms radial error=153.545, avgs=0
# 150/300: dt: 0.9000, rms radial error=152.684, avgs=0
# 155/300: dt: 0.9000, rms radial error=151.827, avgs=0
# 160/300: dt: 0.9000, rms radial error=150.975, avgs=0
# 165/300: dt: 0.9000, rms radial error=150.128, avgs=0
# 170/300: dt: 0.9000, rms radial error=149.285, avgs=0
# 175/300: dt: 0.9000, rms radial error=148.446, avgs=0
# 180/300: dt: 0.9000, rms radial error=147.612, avgs=0
# 185/300: dt: 0.9000, rms radial error=146.783, avgs=0
# 190/300: dt: 0.9000, rms radial error=145.958, avgs=0
# 195/300: dt: 0.9000, rms radial error=145.138, avgs=0
# 200/300: dt: 0.9000, rms radial error=144.322, avgs=0
# 205/300: dt: 0.9000, rms radial error=143.511, avgs=0
# 210/300: dt: 0.9000, rms radial error=142.704, avgs=0
# 215/300: dt: 0.9000, rms radial error=141.901, avgs=0
# 220/300: dt: 0.9000, rms radial error=141.103, avgs=0
# 225/300: dt: 0.9000, rms radial error=140.309, avgs=0
# 230/300: dt: 0.9000, rms radial error=139.519, avgs=0
# 235/300: dt: 0.9000, rms radial error=138.734, avgs=0
# 240/300: dt: 0.9000, rms radial error=137.954, avgs=0
# 245/300: dt: 0.9000, rms radial error=137.177, avgs=0
# 250/300: dt: 0.9000, rms radial error=136.405, avgs=0
# 255/300: dt: 0.9000, rms radial error=135.637, avgs=0
# 260/300: dt: 0.9000, rms radial error=134.873, avgs=0
# 265/300: dt: 0.9000, rms radial error=134.114, avgs=0
# 270/300: dt: 0.9000, rms radial error=133.359, avgs=0
# 275/300: dt: 0.9000, rms radial error=132.608, avgs=0
# 280/300: dt: 0.9000, rms radial error=131.861, avgs=0
# 285/300: dt: 0.9000, rms radial error=131.119, avgs=0
# 290/300: dt: 0.9000, rms radial error=130.380, avgs=0
# 295/300: dt: 0.9000, rms radial error=129.646, avgs=0
# 300/300: dt: 0.9000, rms radial error=128.916, avgs=0
#
# spherical inflation complete.
# surface projected - minimizing metric distortion...
# vertex spacing 1.34 +- 0.72 (0.00-->6.12) (max @ vno 60239 --> 61044)
# face area 0.04 +- 0.04 (-0.05-->0.57)
# epoch 1 (K=10.0), pass 1, starting sse = 8303.20
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00026
# epoch 2 (K=40.0), pass 1, starting sse = 1157.66
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.00/10 = 0.00042
# epoch 3 (K=160.0), pass 1, starting sse = 96.24
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.18/14 = 0.01293
# epoch 4 (K=640.0), pass 1, starting sse = 4.17
# taking momentum steps...
# taking momentum steps...
# taking momentum steps...
# pass 1 complete, delta sse/iter = 0.39/23 = 0.01705
# final distance error %24.81
# writing spherical brain to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.qsphere
# mris_sphere utimesec    122.637836
# mris_sphere stimesec    0.675855
# mris_sphere ru_maxrss   105420
# mris_sphere ru_ixrss    0
# mris_sphere ru_idrss    0
# mris_sphere ru_isrss    0
# mris_sphere ru_minflt   24589
# mris_sphere ru_majflt   0
# mris_sphere ru_nswap    0
# mris_sphere ru_inblock  0
# mris_sphere ru_oublock  0
# mris_sphere ru_msgsnd   0
# mris_sphere ru_msgrcv   0
# mris_sphere ru_nsignals 0
# mris_sphere ru_nvcsw    1338
# mris_sphere ru_nivcsw   6265
# spherical transformation took 0.03 hours
# FSRUNTIME@ mris_sphere  0.0343 hours 1 threads
# euler # = v-e+f = 2g-2: 76940 - 230832 + 153888 = -4 --> 3 holes
#       F =2V-4:          153888 != 153880-4 (-12)
#       2E=3F:            461664 = 461664 (0)
#
# total defect index = 6
# removing intersecting faces
# writing corrected surface to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.orig
# intersection removal took 0.00 hours
# smoothing surface tessellation for 10 iterations...
# smoothing complete - recomputing first and second fundamental forms...
# Reading /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.smoothwm
# avg radius = 39.1 mm, total surface area = 45133 mm^2
# step 060: RMS=0.031 (target=0.015)
# inflation complete.
# writing inflated surface to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.inflated
# writing sulcal depths to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.sulc
# mris_inflate utimesec    15.019215
# mris_inflate stimesec    0.040040
# mris_inflate ru_maxrss   105236
# mris_inflate ru_ixrss    0
# mris_inflate ru_idrss    0
# mris_inflate ru_isrss    0
# mris_inflate ru_minflt   24586
# mris_inflate ru_majflt   3
# mris_inflate ru_nswap    0
# mris_inflate ru_inblock  232
# mris_inflate ru_oublock  0
# mris_inflate ru_msgsnd   0
# mris_inflate ru_msgrcv   0
# mris_inflate ru_nsignals 0
# mris_inflate ru_nvcsw    1869
# mris_inflate ru_nivcsw   23
# inflation took 0.3 minutes
# thresholding curvature at 99.90% level
# normalizing curvature values.
# averaging curvature patterns 5 times.
# sampling 10 neighbors out to a distance of 10 mm
# 47 vertices thresholded to be in k1 ~ [-2.15 1.56], k2 ~ [-0.37 0.23]
# total integrated curvature = 0.546*4pi (6.866) --> 0 handles
# ICI = 1.5, FI = 9.4, variation=161.580
# 49 vertices thresholded to be in [-0.14 0.14]
# writing Gaussian curvature to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.inflated.K...curvature mean = 0.000, std = 0.005
# 40 vertices thresholded to be in [-0.63 0.49]
# curvature mean = -0.022, std = 0.034
# done.
# writing mean curvature to /NHP_MRI/Template/NMT/single_subject_scans/Danny/fsSurf/temp/rh.inflated.H...done.
# $Id: mris_sphere.c,v 1.61 2016/01/20 23:42:15 greve Exp $
#   $Id: mrisurf.c,v 1.781.2.6 2016/12/27 16:47:14 zkaufman Exp $
#
# == Number of threads available to mris_sphere for OpenMP = 1 ==
# reading original vertex positions...
# unfolding cortex into spherical form...
# scaling brain by 0.355...
# surface projected - minimizing metric distortion...
# MRISunfold() max_passes = 1 -------
# tol=5.0e-01, sigma=0.0, host=x86_6, nav=1024, nbrs=2, l_area=1.000, l_dist=1.000
# using quadratic fit line minimization
# complete_dist_mat 0
# rms 0
# smooth_averages 0
# remove_neg 0
# ico_order 0
# which_surface 0
# target_radius 0.000000
# nfields 0
# scale 1.000000
# desired_rms_height -1.000000
# momentum 0.900000
# nbhd_size 7
# max_nbrs 8
# niterations 25
# nsurfaces 0
# SURFACES 3
# flags 0 (0)
# use curv 0
# no sulc 0
# no rigid align 0
# mris->nsize 2
# mris->hemisphere 1
# randomSeed 0
#
# --------------------
#   mrisRemoveNegativeArea()

# %% [markdown]
# #### Create a subject directory in your freesurfer subject directory

# %%
# create a freesurfer SUBJECT with the correct folder structure
# NB! $SUBJECTS_DIR should be defined in your ~/.bashrc as the Freesurfer subjects directory
echo 'Creating a subject directory for '${SUBJ}'in:'
echo ${SUBJECTS_DIR}/${SUBJ}
mksubjdirs ${SUBJECTS_DIR}/${SUBJ}

# %% [markdown]
# #### Move files to the Freesurfer subjects directory

# %%
# copy the necessary files for cutting to the subject directory
for xh in ${HEMI[@]}; do
    cp ${fsSurf_temp}/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.smoothwm ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.orig ${SUBJECTS_DIR}/${SUBJ}/surf/
    cp ${fsSurf_temp}/${xh}.qsphere ${SUBJECTS_DIR}/${SUBJ}/surf/
done

cp ${fsSurf_mgz}/T1.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/T1.mgz
cp ${fsSurf_mgz}/filled.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/filled.mgz
cp ${fsSurf_mgz}/wm.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/wm.mgz
cp ${fsSurf_mgz}/brain.finalsurfs.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brain.finalsurfs.mgz
cp ${fsSurf_mgz}/brainmask.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brainmask.mgz

# %% [markdown]
# Before we can start making the final surfaces we need a little trick to compensate for the low grey/white matter contrast in monkeys. Now that we have a white matter volume we are happy with (if not go back and fix it) we can use it to enhance the contrast artificially.

# %% [markdown]
# #### Make a contrast-enhanced brain volume to aid in getting the pial surface

# %%
mkdir -p $fsSurf/enh
mri_convert ${fsSurf_mgz}/brain.mgz $fsSurf/enh/brain.nii.gz
mri_convert ${fsSurf_mgz}/wm.mgz $fsSurf/enh/wm.nii.gz

# binarize the wm volume
fslmaths $fsSurf/enh/wm.nii.gz -bin $fsSurf/enh/wm_bin.nii.gz
# divide the voxel value in the original brain volume by some value and add another value to the white matter only 
# which values you choose is up to you but we want to end with white matter ~110 and grey matter ~60-80
fslmaths $fsSurf/enh/brain.nii.gz -div 2 $fsSurf/enh/brain2.nii.gz
fslmaths $fsSurf/enh/wm_bin.nii.gz -mul 20 $fsSurf/enh/wm_add.nii.gz
fslmaths $fsSurf/enh/brain2.nii.gz -add $fsSurf/enh/wm_add.nii.gz $fsSurf/enh/brain_enh.nii.gz

# convert back to mgz
mri_convert $fsSurf/enh/brain_enh.nii.gz ${fsSurf_mgz}/brain_enh.mgz

# %% [markdown]
# #### Create the surfaces

# %%
# create surfaces
for xh in ${HEMI[@]}; do
    mris_make_surfaces -noaseg -noaparc -T1 brain_enh -orig_wm orig ${SUBJ} ${xh}
    mris_sphere ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.inflated ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.sphere
done

# %%
# check and edit the pial surface
mkdir -p ${SUBJECTS_DIR}/${SUBJ}/pial_edits
cp -R ${SUBJECTS_DIR}/${SUBJ}/mri ${SUBJECTS_DIR}/${SUBJ}/pial_edits/
cp -R ${SUBJECTS_DIR}/${SUBJ}/surf ${SUBJECTS_DIR}/${SUBJ}/pial_edits/

# %%
freeview -v ${SUBJECTS_DIR}/${SUBJ}/pial_edits/mri/T1.mgz \
    ${SUBJECTS_DIR}/${SUBJ}/pial_edits/mri/brainmask.mgz \
    -f ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/lh.white:edgecolor=yellow \
    ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/lh.pial:edgecolor=red \
    ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/rh.white:edgecolor=yellow \
    ${SUBJECTS_DIR}/${SUBJ}/pial_edits/surf/rh.pial:edgecolor=red

# %%
# regenerate the pial surface
for xh in ${HEMI[@]}; do
    mris_make_surfaces  -noaseg -noaparc -orig_white white -orig_pial white -nowhite -mgz -T1 brain_enh ${SUBJ} ${xh}
done

# %%
# create midcortical surface
for xh in ${HEMI[@]}; do
    mris_expand -thickness ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.white 0.5 ${SUBJECTS_DIR}/${SUBJ}/surf/${xh}.graymid
done

# %% [markdown]
# #### Cut surfaces and create flatmaps
#
# The cells below will load the inflated hemispheres in tksurfer where you can make the cuts to create the flatmaps.
#
# For the full hemisphere make cuts on the medial wall. One cut enclosing the midline and five additional relaxation cuts.
# Mark a point on the part of the surface you want to keep and save patch as `?h.full.patch.3d` (replace '?' with 'l' and 'r' respectively)
#
# ![Cut_full](pics/Cut_full.png)
#
# For an occipital patch make one cut on the medial wall along the calcarine sulcus. Use 3 points to select a coronal cutting plane, and a fourth point to select which part of the surface you want to keep and save as `?h.occip.patch.3d`
#
# ![Cut_occip1](pics/Cut_occip1.png) ![Cut_occip1](pics/Cut_occip2.png)

# %%
# left
tksurfer ${SUBJ} lh inflated -curv

# %%
# right
tksurfer ${SUBJ} rh inflated -curv

# %%
cd ${SUBJECTS_DIR}/${SUBJ}/surf/
for xh in ${HEMI[@]}; do
    mris_flatten -w 0 -distances 20 7 ${xh}.full.patch.3d  ${xh}.full.patch.flat
    mris_flatten -w 0 -distances 20 7 ${xh}.occip.patch.3d  ${xh}.occip.patch.flat
done

# %% [markdown]
# If everything went well, you now have flatmaps of the white matter surface.
# They should look somewhat like this:
# [FULL]
# ![RH_flatmap](pics/RH_Flat_Sulci.png) ![RH_flatmap_gray](pics/RH_Flat_Sulci_gray.png)

# %%
# check your result
tksurfer ${SUBJ} rh inflated -patch rh.full.patch.flat -curv # for a red/green curvature map
#tksurfer ${SUBJ} rh inflated -patch rh.full.patch.flat -gray # for a gray curvature map

# %% [markdown]
# #### Fix the pial surface now

# %%
freeview -v ${SUBJECTS_DIR}/${SUBJ}/mri/T1.mgz ${SUBJECTS_DIR}/${SUBJ}/mri/brainmask.mgz \
    -f ${SUBJECTS_DIR}/${SUBJ}/surf/lh.white:edgecolor=yellow \
    ${SUBJECTS_DIR}/${SUBJ}/surf/lh.pial:edgecolor=red \
    ${SUBJECTS_DIR}/${SUBJ}/surf/rh.white:edgecolor=yellow \
    ${SUBJECTS_DIR}/${SUBJ}/surf/rh.pial:edgecolor=red

# %% [markdown]
# #### Copy Freesurfer results back to NMT template folder

# %%
cp -r ${SUBJECTS_DIR}/${SUBJ}/surf ${fsSurf}/surf

# %%
# return to startpath
cd ${startpath}

# %% [markdown]
# ## **Step 4 (OPTIONAL): Create additional surfaces using Connectome Workbench.**
# This may not be necessary at all. Try the Freesurfer approach and the conversion to gifti with `mris_convert` first (as explained above)
#
# ### Requirements
#   - Connectome Workbench (https://www.humanconnectome.org/software/connectome-workbench)

# %%
# THIS SHOULDN'T BE NECESSARY SINCE WE'RE GETTINGS THESE OUTPUTS ALSO FROM THE FREESURFER PIPELINE !! #

# set path to where you want the results
wbSurf_path=${NMT_path}/single_subject_scans/${SUBJ}/wbSurf

echo 'Extracting surfaces from segmentation'
cd ${wbSurf_path}

# create surfaces
IsoSurface -input ${NMT_ss_path}/NMT_${SUBJ}_process/${SUBJ}_segmentation.nii.gz \
    -isorois -o_gii surf

# rename to something recognizable
mv surf.k2.gii gm.surf.gii # gm surface
mv surf.k3.gii wm.surf.gii # wm surface

# Smooth the surfaces a bit
echo 'Smoothing the surfaces a bit' 
wb_command -surface-smoothing wm.surf.gii 0.5 1 wm_sm.surf.gii
wb_command -surface-smoothing gm.surf.gii 0.5 1 gm_sm.surf.gii

# inflate the surfaces
echo 'Inflating the surfaces'
wb_command -surface-generate-inflated \
    wm_sm.surf.gii infl_wm_sm.surf.gii vinfl_wm_sm.surf.gii
wb_command -surface-generate-inflated \
    gm_sm.surf.gii infl_gm_sm.surf.gii vinfl_gm_sm.surf.gii

# view the result in your favorite viewer
echo 'Inspect the surfaces in a viewer'
freeview -f wm_sm.surf.gii infl_wm_sm.surf.gii vinfl_wm_sm.surf.gii \
    gm_sm.surf.gii infl_gm_sm.surf.gii vinfl_gm_sm.surf.gii
